# %% [markdown]
# https://github.com/jiechuanjiang/pytorch_DGN/blob/main/Surviving/DGN%2BATOC/config.py

# %%
import numpy as np
np.random.seed(14)
import math, random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd 
import torch.nn.functional as F
import copy
import os,sys
from torch.utils import tensorboard as tb

# %%
# hidden_dim = 64
# max_step = 5000 #originally 500
# GAMMA = 0.99
# n_episode = 1000 #originally 800
# i_episode = 0
# buffer_size = 65000 #change back to 65000
# batch_size = 64 #change back to 64
# n_epoch = 100 #orginally 25
# epsilon = 0.7 #originally 0.9
# score = 0
# tau = 0.98

GRID_DIM = 50 # TODO: Tune this
NUM_TASKS = 2 # TODO: Tune this
ADJ_THRESHOLD = GRID_DIM / 4 # TODO: Tune this
USE_CUDA = torch.cuda.is_available()
Variable = lambda *args, **kwargs: autograd.Variable(*args, **kwargs).cuda() if USE_CUDA else autograd.Variable(*args, **kwargs)

def is_legal(x,y):
    return (x>=0)&(x<GRID_DIM)&(y>=0)&(y<=GRID_DIM)

# %% [markdown]
# https://github.com/jiechuanjiang/pytorch_DGN/blob/main/Surviving/DGN%2BATOC/buffer.py

# %%
class ReplayBufferGCare(object):
    """
    Replay buffer for storing the agent's experiences
    """

    def __init__(self, buffer_size, obs_space, n_action, n_tasks):
        """
        Initialize the replay buffer
        
        Params:
        buffer_size:
        obs_space:
        n_action:
        n_tasks:
        """
        self.buffer_size = buffer_size
        self.n_tasks = n_tasks
        self.pointer = 0
        self.len = 0
        self.actions = np.zeros((self.buffer_size,1),dtype = np.int32)
        self.rewards = np.zeros((self.buffer_size, 1))
        self.dones = np.zeros((self.buffer_size,1))
        self.obs = np.zeros((self.buffer_size,n_tasks,obs_space))
        self.next_obs = np.zeros((self.buffer_size,n_tasks,obs_space))
        self.matrix = np.zeros((self.buffer_size,self.n_tasks,self.n_tasks))
        self.next_matrix = np.zeros((self.buffer_size,self.n_tasks,self.n_tasks))

    def getBatch(self, batch_size):
        """
        Sample a batch of random entries from the replay buffer
        
        Params:
        batch_size:
        
        Returns:
        obs:
        action:
        reward
        next_obs:
        matrix:
        next_matrix:
        done:
        """
        index = np.random.choice(self.len, batch_size, replace=False)
        return self.obs[index], self.actions[index], self.rewards[index], self.next_obs[index], self.matrix[index], self.next_matrix[index], self.dones[index]

    def add(self, obs, action, reward, next_obs, matrix, next_matrix, done):
        """
        Add to the replay buffer
        
        Params:
        obs:
        action:
        reward:
        next_obs:
        matrix:
        next_matrix:
        done:
        """
        self.obs[self.pointer] = obs
        self.actions[self.pointer] = action
        self.rewards[self.pointer] = reward
        self.next_obs[self.pointer] = next_obs
        self.matrix[self.pointer] = matrix
        self.next_matrix[self.pointer] = next_matrix
        self.dones[self.pointer] = done
        self.pointer = (self.pointer + 1)%self.buffer_size
        self.len = min(self.len + 1, self.buffer_size)

# %% [markdown]
# https://github.com/jiechuanjiang/pytorch_DGN/blob/main/Surviving/DGN%2BATOC/model.py

# %%
class MTRL_ATT(nn.Module):
    """
    """
    def __init__(self, din):
        super(MTRL_ATT, self).__init__()
        self.fc1 = nn.Linear(din, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, 1)

    def forward(self, x):
        y = F.relu(self.fc1(x))
        y = F.relu(self.fc2(y))
        y = F.sigmoid(self.fc3(y))
        return y

class MTRL_Encoder(nn.Module): # TODO: Need to make it a CNN for higher dim obs space like MetaWorld
    """
    """
    def __init__(self, din=32, hidden_dim=128):
        super(MTRL_Encoder, self).__init__()
        self.fc = nn.Linear(din, hidden_dim)


    def forward(self, x):
        embedding = F.tanh(self.fc(x))
        return embedding

class MTRL_AttModel(nn.Module):
    """
    """
    def __init__(self, n_node, din, hidden_dim, dout):
        super(MTRL_AttModel, self).__init__()
        self.fcv = nn.Linear(din, hidden_dim)
        self.fck = nn.Linear(din, hidden_dim)
        self.fcq = nn.Linear(din, hidden_dim)
        self.fcout = nn.Linear(hidden_dim, dout)

    def forward(self, x, mask):
        v = F.tanh(self.fcv(x))
        q = F.tanh(self.fcq(x))
        k = F.tanh(self.fck(x)).permute(0,2,1)
        att = F.softmax(torch.mul(torch.bmm(q,k), mask) - 9e15*(1 - mask),dim=2)
        # Note: Order of applying adj matrix is different than that in paper. Don't get confused!
        out = torch.bmm(att,v)
        return out

class MTRL_Q_Net(nn.Module):
    """
    """
    def __init__(self, hidden_dim, dout):
        super(MTRL_Q_Net, self).__init__()
        # NOTE: This is now modified to have both h vectors from both of the attention layers
        # concatenated - originally it was only getting the h vector of the last layer
        # so the input dim of the linear layer was hidden_dim
        self.fc = nn.Linear(hidden_dim*2, dout)

    def forward(self, x):
        q = F.relu(self.fc(x))
        return q

    
class MTRL_DGN(nn.Module):
    """
    """
    def __init__(self,n_tasks,num_inputs,hidden_dim,num_actions):
        super(MTRL_DGN, self).__init__()

        self.encoder = MTRL_Encoder(num_inputs,hidden_dim)
        # TODO: Try both single encoder and mix of encoder settings
        # Will remain same for MTRL
        self.att_1 = MTRL_AttModel(n_tasks,hidden_dim,hidden_dim,hidden_dim)
        self.att_2 = MTRL_AttModel(n_tasks,hidden_dim,hidden_dim,hidden_dim)
        self.q_net = MTRL_Q_Net(hidden_dim,num_actions)
        # Q Net remains same for MTRL

    def forward(self, x, mask):
        h1 = self.encoder(x)
        h2 = self.att_1(h1, mask)
        h3 = self.att_2(h2, mask) 
        # TODO: try concatentation for MTRL
        
        h4 = torch.cat((h2,h3),dim=2)
        q = self.q_net(h4)
        # Note: No concatenation done. Output of last attention head used directly
        # Note: 2 attention heads used
        return q

# %% [markdown]
# https://github.com/jiechuanjiang/pytorch_DGN/blob/main/Surviving/DGN%2BATOC/surviving.py

# %%
class GridWorldWithCare(object):
    
    def __init__(self, n_tasks):
        """
        Initialize the gridworld
        
        Params:
        n_tasks:
        """
        super(GridWorldWithCare, self).__init__()
        self.n_action = 4
        self.n_tasks = n_tasks
        # TODO: maybe include food as part of task, reach dest with > 0 food or something
        self.tasks = [0]*self.n_tasks
        self.agent = [-1, -1]
        self.build_env()

        self.dones = np.zeros(self.n_tasks) # Array to indicate whether each task is done or not -- used to calculate rewards
        self.steps = 0
#         self.len_obs = (self.n_tasks+1)*2
        self.len_obs = self.n_tasks + 2

    def reset(self):
        """
        Reset the gridworld
        
        Returns:
        obs:
        adj:
        """

        self.build_env()
        self.dones = np.zeros(self.n_tasks)
        self.steps = 0
        return self.get_obs(), self.get_adj()

    def build_env(self):
        """
        Build the gridworld
        """
        for i in range(self.n_tasks):
            x = np.random.randint(0, GRID_DIM)
            y = np.random.randint(0, GRID_DIM)
            self.tasks[i] = [x, y]
            print("TASK NUMBER ", i, " DEST: ", x, y)
        self.agent[0] = np.random.randint(0, GRID_DIM)
        self.agent[1] = np.random.randint(0, GRID_DIM)

    def get_obs(self):
        """
        Get observations
        
        Returns:
        obs:
        """
        # TODO: change this for MTRL 
        obs = []
        
        x_agent = self.agent[0]
        y_agent = self.agent[1]

        obs.append(x_agent/GRID_DIM)
        obs.append(y_agent/GRID_DIM)

#         for i in range(self.n_tasks):
#             obs.append((self.tasks[i][0]-x_agent)/GRID_DIM)
#             obs.append((self.tasks[i][1]-y_agent)/GRID_DIM)
            
        for i in range(self.n_tasks):
            obs.append(math.sqrt((self.tasks[i][0]-x_agent)**2 + (self.tasks[i][1]-y_agent)**2)/GRID_DIM)

        # TODO: 1. if we include maze state or not, and if we do, we would need to figure out
        # how to effectively send that along with task destinations
        
        #Idea: use distance between agent and task as obs
        
        return obs

    def get_adj(self): # TODO: Change this to use task description encoding. 
        # In this case task description is the location of the destination.
        """
        Get adjacency matrix
        
        Returns:
        adj:
        """
        adj = np.zeros((self.n_tasks, self.n_tasks))

        # Calculate adjacency regarding to the distances of the tasks respect to the agent
        x_agent, y_agent = self.agent[0], self.agent[1]

        # HARD ATTENTION
        # Traverse through the tasks and calculate the Euclidean distance between them and the agent
#         for i in range(self.n_tasks):
#             x_task_i, y_task_i = self.tasks[i][0] - x_agent, self.tasks[i][1] - y_agent
#             for j in range(self.n_tasks):
#                 x_task_j, y_task_j = self.tasks[j][0] - x_agent, self.tasks[j][1] - y_agent
#                 task_dist = math.sqrt((x_task_j - x_task_i)**2 + (y_task_i - y_task_j)**2)
#                 if task_dist <= ADJ_THRESHOLD:
#                     adj[i,j] = 1
#                     adj[j,i] = 1
                    
        # SOFT ATTENTION
#         adj = np.ones((self.n_tasks, self.n_tasks)) # NOTE: 
        for i in range(self.n_tasks):
            x_task_i, y_task_i = self.tasks[i][0]-x_agent, self.tasks[i][1]-y_agent
            for j in range(self.n_tasks):
                x_task_j, y_task_j = self.tasks[j][0]-x_agent, self.tasks[j][1]-y_agent
                # Instead of having 1 or 0s, have their vectoral positions according to each other
                task_dist = math.sqrt((x_task_j - x_task_i)**2 + (y_task_j - y_task_i)**2)
                
#                 print('x_task_i: {}, y_task_i: {}, x_task_j: {}, y_task_j: {}, task_dist: {}'.format(
#                         x_task_i, y_task_i, x_task_j, y_task_j, task_dist
#                 ))
                
                # Set this distance / GRID_DIM
                adj[i,j] = 1 - float(task_dist)/GRID_DIM # Extract from 1 bc the closer the better
                adj[j,i] = 1 - float(task_dist)/GRID_DIM
                
        
                
#         print("ADJACENCY: {}".format(adj))

#         print('x_agent: {}, y_agent: {}'.format(x_agent, y_agent))

        return adj



    def step(self, action):
        """
        Take one step in the gridworld according to the given actions
        
        Params:
        action:
        
        Returns:
        obs:
        adj:
        reward:
        all_tasks_done:
        """

        # There are 4 different actions for the agent
        # If there is any place to go in the maze then the agent will go 
        # 0: Move up, 1: Move down, 2: Move left, 3: Move right

        self.steps += 1
        x_agent, y_agent = self.agent[0], self.agent[1]
#         print("AGENT LOCATION: ", agent_x, agent_y)
#         print("ACTION: ", action)
        if action == 0: # Move up (decrease x by one)
            if is_legal(x_agent-1, y_agent):
                # Change the agent and the maze
                self.agent[0] -= 1

        elif action == 1: # Move down (increase x by one)
            if is_legal(x_agent+1, y_agent):
                # Change the agent and the maze
                self.agent[0] += 1

        elif action == 2: # Move left (decrease y by one)
            if is_legal(x_agent, y_agent-1):
                # Change the agent and the maze
                self.agent[1] -= 1

        elif action == 3: # Move right (increase y by one)
            if is_legal(x_agent, y_agent+1):
                # Change the agent and the maze
                self.agent[1] += 1
                
        # Calculate the rewards for each task
        rewards = [0] * self.n_tasks
        total_reward = 0

        # Check if you reached to any destinations here
        new_agent_x, new_agent_y = self.agent[0], self.agent[1]
        for i in range(self.n_tasks):
            if self.tasks[i][0] == new_agent_x and self.tasks[i][1] == new_agent_y:
                if self.dones[i] == 0:
                    self.dones[i] = 1
                    rewards[i] = 1
                    total_reward += 1
                    print("Task ", i, " completed at step ", self.steps)
            else:
                total_reward += 1.0/float((math.sqrt((self.tasks[i][0]-new_agent_x)**2 + (self.tasks[i][1]-new_agent_y)**2)))
                

        # Only if all the tasks are done, then the episode is done
        all_tasks_done = not (0 in self.dones)



        return self.get_obs(), self.get_adj(), total_reward, all_tasks_done

# %%
# Class for making the training with different set of hyper parameters
class Training:
    """
    This class trains the model and holds the highest scores and the hyper parameter combination that gave us that
    highest score. 
    Prints tryout_index -> highest_score_in_that_tryout for each tryout to the file
    
    params:
    test_results_file: name of the file to hold the results
    vizier: boolean to indicate whether to do hyper parameter search
    """
    def __init__(self, file_name, vizier=False): # vizier indicates whether to do hyper param research
        self.file_name = file_name
        self.file = open(file_name, "w+")
        self.vizier = vizier # if vizier is true then the class makes 

        if self.vizier:

            # Dictionary to give us all options for hyper parameters
            self.hyper_params = {
                'hidden_dim': [64], # 2
                'max_step': [5000], # 1
                'gamma': [0.99], # 1
                'n_episode': [800], # 1
                'buffer_size': [100000, 10000000], # 3
                'batch_size': [128], # 1
                'n_epoch': [100], # 2
                'epsilon': [0.5, 0.7, 0.9], # 3
                'tau': [0.95], # 2
                'learning_rate': [0.0005, 0.001, 0.005] # 3
            }

            self.tryouts = []
            for key, value in self.hyper_params.items():
                tryouts_len = len(self.tryouts)
                if tryouts_len == 0:
                    for param in value:
                        self.tryouts.append({key : param})

                else:
                    params_len = len(value)
                    for i in range(params_len-1):
                        for j in range(tryouts_len):
                            self.tryouts.append(copy.deepcopy(self.tryouts[j]))

                    for j in range(params_len):
                        for i in range(tryouts_len):
                            self.tryouts[j*tryouts_len+i][key] = value[j]

            print('len(tryouts): {}'.format(len(self.tryouts)))
            self.num_tryout = len(self.tryouts)
            
        else: 
            
            self.hidden_dim = 64
            self.max_step = 5000 #originally 500
            self.gamma = 0.99
            self.n_episode = 1000 #originally 800
            self.buffer_size = 1000000 #change back to 65000
            self.batch_size = 64 #change back to 64
            self.n_epoch = 100 #orginally 25
            self.epsilon = 0.7 #originally 0.9
            self.tau = 0.98
            self.learning_rate = 0.001
            
            self.num_tryout = 1
            
        self.highest_scores = [0] * self.num_tryout # This will hold the highest score in each try out
        
        
            
    def train(self):
        env = GridWorldWithCare(NUM_TASKS)
        observation_space = env.len_obs
        n_actions = env.n_action
        n_tasks = env.n_tasks
        
        # Set the hyper parameters 
        for tryout_index in range(self.num_tryout):
            if self.vizier:
                self.hidden_dim = self.tryouts[tryout_index]['hidden_dim']
                self.max_step = self.tryouts[tryout_index]['max_step']
                self.gamma = self.tryouts[tryout_index]['gamma']
                self.n_episode = self.tryouts[tryout_index]['n_episode']
                self.buffer_size = self.tryouts[tryout_index]['buffer_size']
                self.batch_size = self.tryouts[tryout_index]['batch_size']
                self.n_epoch = self.tryouts[tryout_index]['n_epoch']
                self.epsilon = self.tryouts[tryout_index]['epsilon']
                self.tau = self.tryouts[tryout_index]['tau']
                self.learning_rate = self.tryouts[tryout_index]['learning_rate']
                
            print('-------\nTRYOUT[{}]: (hidden_dim={}, max_step={}, gamma={}, n_episode={}, buffer_size={}, batch_size={}, n_epoch={}, epsilon={}, tau={}, learning_rate={})'.format(
                tryout_index, self.hidden_dim, self.max_step, self.gamma, self.n_episode, self.buffer_size, self.batch_size, self.n_epoch, self.epsilon, self.tau, self.learning_rate
            ))
                
                
            buff = ReplayBufferGCare(self.buffer_size, observation_space, n_actions, n_tasks)
            model = MTRL_DGN(n_tasks, observation_space, self.hidden_dim, n_actions).cuda()
            model_tar = MTRL_DGN(n_tasks, observation_space, self.hidden_dim, n_actions).cuda()
            optimizer = optim.Adam(model.parameters(), lr = self.learning_rate)
            criterion = nn.BCELoss()
            
            M_Null = torch.Tensor(np.array([np.eye(n_tasks)] * self.batch_size)).cuda()
            M_ZERO = torch.Tensor(np.zeros((self.batch_size, n_tasks, n_tasks))).cuda()
        
            i_episode = 0
            score = 0
            
            while i_episode < self.n_episode:
                if i_episode > 40:
                    self.epsilon -= 0.001
                    if self.epsilon < 0.01:
                        self.epsilon = 0.01
                i_episode+=1
                steps = 0
                obs, adj = env.reset()
                obs = np.resize(obs, (n_tasks, observation_space))
                
                if not self.vizier:
                    log_file_name = self.file_name+str(i_episode)+"Episode"
                    episode_summary_writer = tb.SummaryWriter(log_dir='./TB-Logs/'+log_file_name)
                    episode_epoch_count = 0
                
                while steps < self.max_step:
                    steps+=1 
                    # Get the action with forward prop and add the obs, adjs to replay buffer
                    q = model(torch.Tensor(np.array([obs])).cuda(), torch.Tensor(np.array([adj])).cuda())[0,0,:]
                    if np.random.rand() < self.epsilon:
                        action = np.random.randint(n_actions)
                    else:
                        action = q.argmax().item()
                    next_obs, next_adj, reward, terminated = env.step(action)
                    next_obs = np.resize(next_obs, (n_tasks, observation_space))
                    buff.add(np.array(obs),action,reward,np.array(next_obs),adj,next_adj,terminated)

                    obs = next_obs
                    adj = next_adj
                    score += reward

                if i_episode%20==0:
                    print(score)
                    if not self.vizier:
                        episode_summary_writer.add_scalar("Score/Episode", score, i_episode)
                    if score > self.highest_scores[tryout_index]:
                        self.highest_scores[tryout_index] = score
                    score = 0
                
                # Train the model
                for e in range(self.n_epoch):
                    O,A,R,Next_O,Matrix,Next_Matrix,D = buff.getBatch(self.batch_size)
                    O = torch.Tensor(O).cuda()
                    Matrix = torch.Tensor(Matrix).cuda()
                    Next_O = torch.Tensor(Next_O).cuda()
                    Next_Matrix = torch.Tensor(Next_Matrix).cuda()

                    q_values = model(O, Matrix)
                    q_values = model(O, Matrix)[:,0, :]
                    target_q_values = model_tar(Next_O, Next_Matrix).max(dim = 2)[0][:,0]
                    target_q_values = np.array(target_q_values.cpu().data)
                    expected_q = np.array(q_values.cpu().data)

                    for j in range(self.batch_size):
                        expected_q[j][A[j][0]] = R[j][0] + (1-D[j][0])*self.gamma*target_q_values[j]

                    loss = (q_values - torch.Tensor(expected_q).cuda()).pow(2).mean()
                    if not self.vizier:
                        episode_summary_writer.add_scalar('Loss', loss, episode_epoch_count)
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                    if e%10 == 0:
                        with torch.no_grad():
                            for p, p_targ in zip(model.parameters(), model_tar.parameters()):
                                p_targ.data.mul_(self.tau)
                                p_targ.data.add_((1 - self.tau) * p.data)
    
            # Print the highest score to the file
            self.file.write('Tryout[{}]: (hidden_dim={}, max_step={}, gamma={}, n_episode={}, buffer_size={}, batch_size={}, n_epoch={}, epsilon={}, tau={}, learning_rate={}): \t ---> \t Highest Score: {}\n'.format(
                tryout_index, self.hidden_dim, self.max_step, self.gamma, self.n_episode, self.buffer_size, self.batch_size, self.n_epoch, self.epsilon, self.tau, self.learning_rate, self.highest_scores[tryout_index]
            ))
            
            self.file.flush()

# %%
training = Training('OBS_DIST_MAX.txt', False)
training.train()
# Out:
# TASK NUMBER  0  DEST:  25 28
# TASK NUMBER  1  DEST:  6 31
# -------
# TRYOUT[0]: (hidden_dim=64, max_step=5000, gamma=0.99, n_episode=1000, buffer_size=1000000, batch_size=64, n_epoch=100, epsilon=0.7, tau=0.98, learning_rate=0.001)
# TASK NUMBER  0  DEST:  15 48
# TASK NUMBER  1  DEST:  39 8
# TASK NUMBER  0  DEST:  30 26
# TASK NUMBER  1  DEST:  31 24
# TASK NUMBER  0  DEST:  46 25
# TASK NUMBER  1  DEST:  4 42
# Task  0  completed at step  355
# TASK NUMBER  0  DEST:  48 2
# TASK NUMBER  1  DEST:  48 19
# Task  1  completed at step  560
# Task  0  completed at step  1774
# TASK NUMBER  0  DEST:  4 33
# TASK NUMBER  1  DEST:  0 3
# TASK NUMBER  0  DEST:  9 26
# TASK NUMBER  1  DEST:  24 35
# TASK NUMBER  0  DEST:  0 39
# TASK NUMBER  1  DEST:  12 41
# TASK NUMBER  0  DEST:  0 30
# TASK NUMBER  1  DEST:  32 37
# Task  1  completed at step  13
# TASK NUMBER  0  DEST:  22 9
# TASK NUMBER  1  DEST:  25 47
# TASK NUMBER  0  DEST:  11 18
# TASK NUMBER  1  DEST:  4 34
# TASK NUMBER  0  DEST:  11 41
# TASK NUMBER  1  DEST:  26 41
# TASK NUMBER  0  DEST:  32 37
# TASK NUMBER  1  DEST:  35 2
# TASK NUMBER  0  DEST:  36 0
# TASK NUMBER  1  DEST:  5 29
# TASK NUMBER  0  DEST:  11 31
# TASK NUMBER  1  DEST:  20 6
# Task  1  completed at step  74
# TASK NUMBER  0  DEST:  7 40
# TASK NUMBER  1  DEST:  14 43
# Task  0  completed at step  533
# TASK NUMBER  0  DEST:  45 30
# TASK NUMBER  1  DEST:  4 45
# TASK NUMBER  0  DEST:  32 16
# TASK NUMBER  1  DEST:  34 33
# Task  1  completed at step  1709
# TASK NUMBER  0  DEST:  18 36
# TASK NUMBER  1  DEST:  42 22
# TASK NUMBER  0  DEST:  10 10
# TASK NUMBER  1  DEST:  12 17
# TASK NUMBER  0  DEST:  27 41
# TASK NUMBER  1  DEST:  38 21
# 12126.405293224214
# TASK NUMBER  0  DEST:  30 44
# TASK NUMBER  1  DEST:  11 10
# TASK NUMBER  0  DEST:  40 46
# TASK NUMBER  1  DEST:  19 30
# TASK NUMBER  0  DEST:  38 47
# TASK NUMBER  1  DEST:  32 38
# TASK NUMBER  0  DEST:  19 4
# TASK NUMBER  1  DEST:  23 22
# TASK NUMBER  0  DEST:  5 3
# TASK NUMBER  1  DEST:  23 33
# TASK NUMBER  0  DEST:  31 8
# TASK NUMBER  1  DEST:  39 26
# TASK NUMBER  0  DEST:  9 34
# TASK NUMBER  1  DEST:  27 24
# TASK NUMBER  0  DEST:  23 11
# TASK NUMBER  1  DEST:  45 30
# TASK NUMBER  0  DEST:  38 27
# TASK NUMBER  1  DEST:  10 26
# TASK NUMBER  0  DEST:  41 39
# TASK NUMBER  1  DEST:  27 39
# TASK NUMBER  0  DEST:  1 31
# TASK NUMBER  1  DEST:  17 31
# TASK NUMBER  0  DEST:  41 28
# TASK NUMBER  1  DEST:  38 15
# TASK NUMBER  0  DEST:  41 10
# TASK NUMBER  1  DEST:  38 10
# TASK NUMBER  0  DEST:  43 14
# TASK NUMBER  1  DEST:  33 7
# TASK NUMBER  0  DEST:  27 24
# TASK NUMBER  1  DEST:  0 6
# TASK NUMBER  0  DEST:  18 28
# TASK NUMBER  1  DEST:  33 8
# TASK NUMBER  0  DEST:  26 10
# TASK NUMBER  1  DEST:  18 8
# Task  0  completed at step  3229
# Task  1  completed at step  3994
# TASK NUMBER  0  DEST:  22 4
# TASK NUMBER  1  DEST:  5 29
# TASK NUMBER  0  DEST:  13 8
# TASK NUMBER  1  DEST:  49 20
# TASK NUMBER  0  DEST:  42 15
# TASK NUMBER  1  DEST:  48 38
# 9537.230461553112
# TASK NUMBER  0  DEST:  15 27
# TASK NUMBER  1  DEST:  30 2
# TASK NUMBER  0  DEST:  15 30
# TASK NUMBER  1  DEST:  0 17
# Task  1  completed at step  347
# TASK NUMBER  0  DEST:  37 41
# TASK NUMBER  1  DEST:  35 24
# TASK NUMBER  0  DEST:  1 33
# TASK NUMBER  1  DEST:  46 17
# TASK NUMBER  0  DEST:  20 19
# TASK NUMBER  1  DEST:  37 12
# Task  0  completed at step  1982
# TASK NUMBER  0  DEST:  22 32
# TASK NUMBER  1  DEST:  35 11
# TASK NUMBER  0  DEST:  42 11
# TASK NUMBER  1  DEST:  37 11
# TASK NUMBER  0  DEST:  40 1
# TASK NUMBER  1  DEST:  24 26
# TASK NUMBER  0  DEST:  3 36
# TASK NUMBER  1  DEST:  14 39
# Task  1  completed at step  1056
# TASK NUMBER  0  DEST:  12 4
# TASK NUMBER  1  DEST:  42 48
# TASK NUMBER  0  DEST:  0 20
# TASK NUMBER  1  DEST:  15 42
# TASK NUMBER  0  DEST:  18 22
# TASK NUMBER  1  DEST:  23 46
# Task  0  completed at step  71
# TASK NUMBER  0  DEST:  33 33
# TASK NUMBER  1  DEST:  6 45
# TASK NUMBER  0  DEST:  48 47
# TASK NUMBER  1  DEST:  6 5
# TASK NUMBER  0  DEST:  3 32
# TASK NUMBER  1  DEST:  49 22
# TASK NUMBER  0  DEST:  16 2
# TASK NUMBER  1  DEST:  10 35
# Task  1  completed at step  2849
# TASK NUMBER  0  DEST:  5 17
# TASK NUMBER  1  DEST:  12 22
# TASK NUMBER  0  DEST:  6 38
# TASK NUMBER  1  DEST:  42 31
# Task  1  completed at step  863
# TASK NUMBER  0  DEST:  6 3
# TASK NUMBER  1  DEST:  35 14
# TASK NUMBER  0  DEST:  2 16
# TASK NUMBER  1  DEST:  38 3
# 12752.014948203941
# TASK NUMBER  0  DEST:  4 45
# TASK NUMBER  1  DEST:  33 43
# TASK NUMBER  0  DEST:  34 47
# TASK NUMBER  1  DEST:  25 40
# TASK NUMBER  0  DEST:  29 9
# TASK NUMBER  1  DEST:  28 28
# TASK NUMBER  0  DEST:  26 31
# TASK NUMBER  1  DEST:  10 36
# Task  0  completed at step  64
# TASK NUMBER  0  DEST:  6 21
# TASK NUMBER  1  DEST:  6 44
# Task  0  completed at step  4390
# TASK NUMBER  0  DEST:  1 15
# TASK NUMBER  1  DEST:  0 44
# Task  1  completed at step  1028
# TASK NUMBER  0  DEST:  34 32
# TASK NUMBER  1  DEST:  40 12
# TASK NUMBER  0  DEST:  3 31
# TASK NUMBER  1  DEST:  35 20
# TASK NUMBER  0  DEST:  18 15
# TASK NUMBER  1  DEST:  27 24
# TASK NUMBER  0  DEST:  33 4
# TASK NUMBER  1  DEST:  48 16
# TASK NUMBER  0  DEST:  3 18
# TASK NUMBER  1  DEST:  28 7
# TASK NUMBER  0  DEST:  41 35
# TASK NUMBER  1  DEST:  19 21
# Task  1  completed at step  57
# TASK NUMBER  0  DEST:  30 24
# TASK NUMBER  1  DEST:  30 16
# TASK NUMBER  0  DEST:  24 24
# TASK NUMBER  1  DEST:  25 30
# TASK NUMBER  0  DEST:  46 40
# TASK NUMBER  1  DEST:  33 17
# TASK NUMBER  0  DEST:  4 41
# TASK NUMBER  1  DEST:  45 6
# TASK NUMBER  0  DEST:  18 18
# TASK NUMBER  1  DEST:  9 2
# TASK NUMBER  0  DEST:  21 6
# TASK NUMBER  1  DEST:  14 4
# TASK NUMBER  0  DEST:  30 26
# TASK NUMBER  1  DEST:  21 38
# TASK NUMBER  0  DEST:  3 37
# TASK NUMBER  1  DEST:  20 43
# 12918.758879441968
# TASK NUMBER  0  DEST:  49 25
# TASK NUMBER  1  DEST:  49 45
# TASK NUMBER  0  DEST:  17 26
# TASK NUMBER  1  DEST:  9 24
# TASK NUMBER  0  DEST:  44 38
# TASK NUMBER  1  DEST:  17 29
# TASK NUMBER  0  DEST:  45 13
# TASK NUMBER  1  DEST:  30 20
# TASK NUMBER  0  DEST:  44 8
# TASK NUMBER  1  DEST:  31 29
# TASK NUMBER  0  DEST:  26 32
# TASK NUMBER  1  DEST:  18 48
# TASK NUMBER  0  DEST:  0 7
# TASK NUMBER  1  DEST:  41 11
# TASK NUMBER  0  DEST:  19 36
# TASK NUMBER  1  DEST:  24 20
# TASK NUMBER  0  DEST:  18 1
# TASK NUMBER  1  DEST:  1 12
# TASK NUMBER  0  DEST:  30 6
# TASK NUMBER  1  DEST:  26 12
# TASK NUMBER  0  DEST:  49 10
# TASK NUMBER  1  DEST:  7 19
# TASK NUMBER  0  DEST:  21 20
# TASK NUMBER  1  DEST:  29 40
# TASK NUMBER  0  DEST:  30 17
# TASK NUMBER  1  DEST:  25 41
# TASK NUMBER  0  DEST:  42 17
# TASK NUMBER  1  DEST:  47 26
# TASK NUMBER  0  DEST:  43 44
# TASK NUMBER  1  DEST:  1 12
# Task  0  completed at step  5
# TASK NUMBER  0  DEST:  16 1
# TASK NUMBER  1  DEST:  2 40
# TASK NUMBER  0  DEST:  5 10
# TASK NUMBER  1  DEST:  19 44
# TASK NUMBER  0  DEST:  19 4
# TASK NUMBER  1  DEST:  40 32
# TASK NUMBER  0  DEST:  24 5
# TASK NUMBER  1  DEST:  7 7
# TASK NUMBER  0  DEST:  23 5
# TASK NUMBER  1  DEST:  19 43
# Task  0  completed at step  58
# 11296.239359045385
# TASK NUMBER  0  DEST:  2 47
# TASK NUMBER  1  DEST:  17 49
# TASK NUMBER  0  DEST:  31 3
# TASK NUMBER  1  DEST:  21 49
# TASK NUMBER  0  DEST:  1 43
# TASK NUMBER  1  DEST:  38 16
# TASK NUMBER  0  DEST:  10 41
# TASK NUMBER  1  DEST:  26 43
# TASK NUMBER  0  DEST:  22 49
# TASK NUMBER  1  DEST:  40 2
# TASK NUMBER  0  DEST:  23 14
# TASK NUMBER  1  DEST:  11 34
# Task  1  completed at step  60
# TASK NUMBER  0  DEST:  48 33
# TASK NUMBER  1  DEST:  5 47
# TASK NUMBER  0  DEST:  15 17
# TASK NUMBER  1  DEST:  18 0
# TASK NUMBER  0  DEST:  9 41
# TASK NUMBER  1  DEST:  3 49
# TASK NUMBER  0  DEST:  48 0
# TASK NUMBER  1  DEST:  47 25
# TASK NUMBER  0  DEST:  27 38
# TASK NUMBER  1  DEST:  27 34
# TASK NUMBER  0  DEST:  45 2
# TASK NUMBER  1  DEST:  30 38
# TASK NUMBER  0  DEST:  37 8
# TASK NUMBER  1  DEST:  19 48
# TASK NUMBER  0  DEST:  33 44
# TASK NUMBER  1  DEST:  33 21
# TASK NUMBER  0  DEST:  37 33
# TASK NUMBER  1  DEST:  12 31
# TASK NUMBER  0  DEST:  49 19
# TASK NUMBER  1  DEST:  29 29
# TASK NUMBER  0  DEST:  18 1
# TASK NUMBER  1  DEST:  9 9
# TASK NUMBER  0  DEST:  5 20
# TASK NUMBER  1  DEST:  22 23
# TASK NUMBER  0  DEST:  46 1
# TASK NUMBER  1  DEST:  24 22
# TASK NUMBER  0  DEST:  17 8
# TASK NUMBER  1  DEST:  9 43
# 11549.848582791938
# TASK NUMBER  0  DEST:  20 37
# TASK NUMBER  1  DEST:  23 21
# Task  1  completed at step  491
# TASK NUMBER  0  DEST:  46 26
# TASK NUMBER  1  DEST:  40 18
# TASK NUMBER  0  DEST:  15 36
# TASK NUMBER  1  DEST:  29 46
# TASK NUMBER  0  DEST:  37 41
# TASK NUMBER  1  DEST:  38 10
# TASK NUMBER  0  DEST:  15 39
# TASK NUMBER  1  DEST:  8 14
# TASK NUMBER  0  DEST:  18 13
# TASK NUMBER  1  DEST:  36 49
# TASK NUMBER  0  DEST:  20 0
# TASK NUMBER  1  DEST:  25 43
# TASK NUMBER  0  DEST:  28 38
# TASK NUMBER  1  DEST:  46 7
# TASK NUMBER  0  DEST:  34 7
# TASK NUMBER  1  DEST:  9 21
# TASK NUMBER  0  DEST:  47 49
# TASK NUMBER  1  DEST:  27 20
# TASK NUMBER  0  DEST:  28 41
# TASK NUMBER  1  DEST:  1 2
# TASK NUMBER  0  DEST:  8 46
# TASK NUMBER  1  DEST:  28 23
# Task  1  completed at step  267
# TASK NUMBER  0  DEST:  22 4
# TASK NUMBER  1  DEST:  29 41
# TASK NUMBER  0  DEST:  14 38
# TASK NUMBER  1  DEST:  45 14
# TASK NUMBER  0  DEST:  18 39
# TASK NUMBER  1  DEST:  15 6
# TASK NUMBER  0  DEST:  9 2
# TASK NUMBER  1  DEST:  29 13
# TASK NUMBER  0  DEST:  43 15
# TASK NUMBER  1  DEST:  6 14
# TASK NUMBER  0  DEST:  23 45
# TASK NUMBER  1  DEST:  34 12
# TASK NUMBER  0  DEST:  35 44
# TASK NUMBER  1  DEST:  45 43
# TASK NUMBER  0  DEST:  12 14
# TASK NUMBER  1  DEST:  42 47
# 11920.743310046946
# TASK NUMBER  0  DEST:  1 11
# TASK NUMBER  1  DEST:  37 22
# TASK NUMBER  0  DEST:  43 16
# TASK NUMBER  1  DEST:  29 33
# TASK NUMBER  0  DEST:  5 24
# TASK NUMBER  1  DEST:  46 42
# TASK NUMBER  0  DEST:  15 24
# TASK NUMBER  1  DEST:  33 38
# TASK NUMBER  0  DEST:  9 23
# TASK NUMBER  1  DEST:  0 14
# TASK NUMBER  0  DEST:  2 43
# TASK NUMBER  1  DEST:  22 0
# TASK NUMBER  0  DEST:  25 16
# TASK NUMBER  1  DEST:  40 5
# TASK NUMBER  0  DEST:  5 15
# TASK NUMBER  1  DEST:  20 3
# TASK NUMBER  0  DEST:  26 30
# TASK NUMBER  1  DEST:  39 12
# Task  0  completed at step  178
# TASK NUMBER  0  DEST:  15 1
# TASK NUMBER  1  DEST:  29 46
# TASK NUMBER  0  DEST:  43 41
# TASK NUMBER  1  DEST:  10 29
# TASK NUMBER  0  DEST:  25 1
# TASK NUMBER  1  DEST:  18 25
# TASK NUMBER  0  DEST:  8 1
# TASK NUMBER  1  DEST:  26 33
# TASK NUMBER  0  DEST:  7 20
# TASK NUMBER  1  DEST:  0 30
# TASK NUMBER  0  DEST:  22 1
# TASK NUMBER  1  DEST:  21 19
# TASK NUMBER  0  DEST:  5 34
# TASK NUMBER  1  DEST:  28 19
# TASK NUMBER  0  DEST:  34 6
# TASK NUMBER  1  DEST:  30 14
# Task  1  completed at step  360
# TASK NUMBER  0  DEST:  2 0
# TASK NUMBER  1  DEST:  12 34
# TASK NUMBER  0  DEST:  43 46
# TASK NUMBER  1  DEST:  15 9
# TASK NUMBER  0  DEST:  18 39
# TASK NUMBER  1  DEST:  8 31
# 14119.438474303932
# TASK NUMBER  0  DEST:  10 5
# TASK NUMBER  1  DEST:  40 20
# TASK NUMBER  0  DEST:  36 20
# TASK NUMBER  1  DEST:  26 4
# TASK NUMBER  0  DEST:  9 31
# TASK NUMBER  1  DEST:  15 25
# TASK NUMBER  0  DEST:  46 19
# TASK NUMBER  1  DEST:  38 0
# TASK NUMBER  0  DEST:  3 4
# TASK NUMBER  1  DEST:  39 12
# TASK NUMBER  0  DEST:  14 14
# TASK NUMBER  1  DEST:  27 22
# TASK NUMBER  0  DEST:  17 49
# TASK NUMBER  1  DEST:  12 45
# TASK NUMBER  0  DEST:  20 18
# TASK NUMBER  1  DEST:  18 41
# TASK NUMBER  0  DEST:  14 44
# TASK NUMBER  1  DEST:  25 8
# TASK NUMBER  0  DEST:  46 16
# TASK NUMBER  1  DEST:  25 6
# TASK NUMBER  0  DEST:  35 45
# TASK NUMBER  1  DEST:  40 31
# TASK NUMBER  0  DEST:  24 36
# TASK NUMBER  1  DEST:  6 32
# TASK NUMBER  0  DEST:  17 22
# TASK NUMBER  1  DEST:  42 21
# TASK NUMBER  0  DEST:  42 15
# TASK NUMBER  1  DEST:  25 9
# TASK NUMBER  0  DEST:  23 0
# TASK NUMBER  1  DEST:  19 7
# TASK NUMBER  0  DEST:  49 46
# TASK NUMBER  1  DEST:  25 35
# TASK NUMBER  0  DEST:  28 0
# TASK NUMBER  1  DEST:  5 36
# TASK NUMBER  0  DEST:  6 32
# TASK NUMBER  1  DEST:  12 46
# Task  1  completed at step  1041
# TASK NUMBER  0  DEST:  35 38
# TASK NUMBER  1  DEST:  26 4
# TASK NUMBER  0  DEST:  2 49
# TASK NUMBER  1  DEST:  45 46
# 11773.73661172161
# TASK NUMBER  0  DEST:  33 7
# TASK NUMBER  1  DEST:  11 6
# TASK NUMBER  0  DEST:  6 34
# TASK NUMBER  1  DEST:  27 32
# TASK NUMBER  0  DEST:  27 3
# TASK NUMBER  1  DEST:  38 12
# TASK NUMBER  0  DEST:  18 43
# TASK NUMBER  1  DEST:  35 6
# TASK NUMBER  0  DEST:  13 44
# TASK NUMBER  1  DEST:  42 14
# TASK NUMBER  0  DEST:  43 43
# TASK NUMBER  1  DEST:  38 24
# TASK NUMBER  0  DEST:  0 12
# TASK NUMBER  1  DEST:  33 36
# TASK NUMBER  0  DEST:  2 24
# TASK NUMBER  1  DEST:  26 4
# TASK NUMBER  0  DEST:  3 20
# TASK NUMBER  1  DEST:  14 5
# TASK NUMBER  0  DEST:  37 48
# TASK NUMBER  1  DEST:  49 30
# TASK NUMBER  0  DEST:  22 15
# TASK NUMBER  1  DEST:  4 21
# Task  1  completed at step  246
# TASK NUMBER  0  DEST:  43 17
# TASK NUMBER  1  DEST:  25 47
# TASK NUMBER  0  DEST:  42 1
# TASK NUMBER  1  DEST:  37 24
# TASK NUMBER  0  DEST:  11 10
# TASK NUMBER  1  DEST:  5 48
# TASK NUMBER  0  DEST:  20 11
# TASK NUMBER  1  DEST:  12 17
# TASK NUMBER  0  DEST:  9 29
# TASK NUMBER  1  DEST:  30 24
# TASK NUMBER  0  DEST:  0 11
# TASK NUMBER  1  DEST:  38 36
# TASK NUMBER  0  DEST:  13 42
# TASK NUMBER  1  DEST:  16 4
# TASK NUMBER  0  DEST:  7 47
# TASK NUMBER  1  DEST:  26 17
# Task  1  completed at step  412
# TASK NUMBER  0  DEST:  44 46
# TASK NUMBER  1  DEST:  13 43
# 12600.359229622869
# TASK NUMBER  0  DEST:  8 18
# TASK NUMBER  1  DEST:  28 25
# TASK NUMBER  0  DEST:  21 2
# TASK NUMBER  1  DEST:  29 8
# TASK NUMBER  0  DEST:  7 37
# TASK NUMBER  1  DEST:  28 11
# TASK NUMBER  0  DEST:  30 5
# TASK NUMBER  1  DEST:  45 46
# TASK NUMBER  0  DEST:  48 43
# TASK NUMBER  1  DEST:  39 21
# TASK NUMBER  0  DEST:  29 45
# TASK NUMBER  1  DEST:  24 7
# Task  1  completed at step  76
# TASK NUMBER  0  DEST:  46 0
# TASK NUMBER  1  DEST:  46 7
# TASK NUMBER  0  DEST:  13 23
# TASK NUMBER  1  DEST:  19 21
# TASK NUMBER  0  DEST:  6 20
# TASK NUMBER  1  DEST:  49 49
# TASK NUMBER  0  DEST:  14 5
# TASK NUMBER  1  DEST:  39 44
# TASK NUMBER  0  DEST:  39 40
# TASK NUMBER  1  DEST:  46 17
# TASK NUMBER  0  DEST:  40 36
# TASK NUMBER  1  DEST:  5 0
# TASK NUMBER  0  DEST:  35 44
# TASK NUMBER  1  DEST:  38 37
# TASK NUMBER  0  DEST:  0 39
# TASK NUMBER  1  DEST:  8 35
# TASK NUMBER  0  DEST:  8 7
# TASK NUMBER  1  DEST:  1 12
# TASK NUMBER  0  DEST:  49 36
# TASK NUMBER  1  DEST:  39 37
# TASK NUMBER  0  DEST:  41 1
# TASK NUMBER  1  DEST:  17 47
# TASK NUMBER  0  DEST:  37 5
# TASK NUMBER  1  DEST:  2 2
# TASK NUMBER  0  DEST:  8 12
# TASK NUMBER  1  DEST:  47 31
# TASK NUMBER  0  DEST:  20 28
# TASK NUMBER  1  DEST:  37 2
# 11406.118531696111
# TASK NUMBER  0  DEST:  9 23
# TASK NUMBER  1  DEST:  9 46
# TASK NUMBER  0  DEST:  32 39
# TASK NUMBER  1  DEST:  15 44
# TASK NUMBER  0  DEST:  27 7
# TASK NUMBER  1  DEST:  38 30
# TASK NUMBER  0  DEST:  21 14
# TASK NUMBER  1  DEST:  32 16
# TASK NUMBER  0  DEST:  35 25
# TASK NUMBER  1  DEST:  1 36
# TASK NUMBER  0  DEST:  40 32
# TASK NUMBER  1  DEST:  21 48
# TASK NUMBER  0  DEST:  43 24
# TASK NUMBER  1  DEST:  35 38
# TASK NUMBER  0  DEST:  33 35
# TASK NUMBER  1  DEST:  39 31
# TASK NUMBER  0  DEST:  38 33
# TASK NUMBER  1  DEST:  16 43
# TASK NUMBER  0  DEST:  31 42
# TASK NUMBER  1  DEST:  25 19
# TASK NUMBER  0  DEST:  27 21
# TASK NUMBER  1  DEST:  16 42
# TASK NUMBER  0  DEST:  38 33
# TASK NUMBER  1  DEST:  49 14
# TASK NUMBER  0  DEST:  13 43
# TASK NUMBER  1  DEST:  6 4
# TASK NUMBER  0  DEST:  6 30
# TASK NUMBER  1  DEST:  19 11
# TASK NUMBER  0  DEST:  48 1
# TASK NUMBER  1  DEST:  20 27
# TASK NUMBER  0  DEST:  33 29
# TASK NUMBER  1  DEST:  16 37
# TASK NUMBER  0  DEST:  33 38
# TASK NUMBER  1  DEST:  14 0
# TASK NUMBER  0  DEST:  18 41
# TASK NUMBER  1  DEST:  35 0
# TASK NUMBER  0  DEST:  48 26
# TASK NUMBER  1  DEST:  43 18
# TASK NUMBER  0  DEST:  9 4
# TASK NUMBER  1  DEST:  10 23
# 10768.055745198722
# TASK NUMBER  0  DEST:  40 9
# TASK NUMBER  1  DEST:  14 18
# TASK NUMBER  0  DEST:  10 40
# TASK NUMBER  1  DEST:  25 49
# TASK NUMBER  0  DEST:  9 7
# TASK NUMBER  1  DEST:  20 3
# TASK NUMBER  0  DEST:  13 8
# TASK NUMBER  1  DEST:  36 10
# TASK NUMBER  0  DEST:  18 10
# TASK NUMBER  1  DEST:  34 48
# TASK NUMBER  0  DEST:  29 20
# TASK NUMBER  1  DEST:  4 27
# TASK NUMBER  0  DEST:  48 20
# TASK NUMBER  1  DEST:  0 37
# TASK NUMBER  0  DEST:  39 34
# TASK NUMBER  1  DEST:  42 43
# Task  0  completed at step  1999
# TASK NUMBER  0  DEST:  15 10
# TASK NUMBER  1  DEST:  37 24
# TASK NUMBER  0  DEST:  45 7
# TASK NUMBER  1  DEST:  10 15
# TASK NUMBER  0  DEST:  10 49
# TASK NUMBER  1  DEST:  10 27
# TASK NUMBER  0  DEST:  23 34
# TASK NUMBER  1  DEST:  47 20
# TASK NUMBER  0  DEST:  23 8
# TASK NUMBER  1  DEST:  21 22
# TASK NUMBER  0  DEST:  4 28
# TASK NUMBER  1  DEST:  19 1
# TASK NUMBER  0  DEST:  35 18
# TASK NUMBER  1  DEST:  24 36
# TASK NUMBER  0  DEST:  8 25
# TASK NUMBER  1  DEST:  33 10
# Task  1  completed at step  1174
# TASK NUMBER  0  DEST:  10 22
# TASK NUMBER  1  DEST:  30 46
# TASK NUMBER  0  DEST:  28 45
# TASK NUMBER  1  DEST:  4 1
# TASK NUMBER  0  DEST:  26 9
# TASK NUMBER  1  DEST:  42 16
# TASK NUMBER  0  DEST:  21 32
# TASK NUMBER  1  DEST:  42 31
# 9821.557053815013
# TASK NUMBER  0  DEST:  37 11
# TASK NUMBER  1  DEST:  40 9
# TASK NUMBER  0  DEST:  11 37
# TASK NUMBER  1  DEST:  47 14
# TASK NUMBER  0  DEST:  44 13
# TASK NUMBER  1  DEST:  11 31
# TASK NUMBER  0  DEST:  13 26
# TASK NUMBER  1  DEST:  19 33
# Task  0  completed at step  148
# TASK NUMBER  0  DEST:  25 23
# TASK NUMBER  1  DEST:  27 7
# TASK NUMBER  0  DEST:  4 35
# TASK NUMBER  1  DEST:  12 26
# TASK NUMBER  0  DEST:  25 47
# TASK NUMBER  1  DEST:  14 28
# TASK NUMBER  0  DEST:  30 5
# TASK NUMBER  1  DEST:  17 27
# TASK NUMBER  0  DEST:  36 23
# TASK NUMBER  1  DEST:  29 26
# TASK NUMBER  0  DEST:  46 2
# TASK NUMBER  1  DEST:  21 29
# TASK NUMBER  0  DEST:  1 7
# TASK NUMBER  1  DEST:  0 17
# TASK NUMBER  0  DEST:  49 31
# TASK NUMBER  1  DEST:  37 15
# TASK NUMBER  0  DEST:  47 39
# TASK NUMBER  1  DEST:  18 16
# TASK NUMBER  0  DEST:  32 27
# TASK NUMBER  1  DEST:  43 13
# TASK NUMBER  0  DEST:  7 37
# TASK NUMBER  1  DEST:  30 45
# TASK NUMBER  0  DEST:  6 19
# TASK NUMBER  1  DEST:  2 40
# TASK NUMBER  0  DEST:  48 22
# TASK NUMBER  1  DEST:  12 48
# TASK NUMBER  0  DEST:  38 39
# TASK NUMBER  1  DEST:  25 6
# TASK NUMBER  0  DEST:  35 5
# TASK NUMBER  1  DEST:  17 47
# TASK NUMBER  0  DEST:  15 11
# TASK NUMBER  1  DEST:  37 37
# 10081.629336257305
# TASK NUMBER  0  DEST:  34 5
# TASK NUMBER  1  DEST:  33 1
# Task  1  completed at step  1402
# TASK NUMBER  0  DEST:  14 24
# TASK NUMBER  1  DEST:  6 43
# TASK NUMBER  0  DEST:  28 13
# TASK NUMBER  1  DEST:  42 5
# TASK NUMBER  0  DEST:  18 37
# TASK NUMBER  1  DEST:  18 49
# TASK NUMBER  0  DEST:  36 35
# TASK NUMBER  1  DEST:  0 37
# TASK NUMBER  0  DEST:  48 40
# TASK NUMBER  1  DEST:  40 47
# TASK NUMBER  0  DEST:  28 23
# TASK NUMBER  1  DEST:  32 42
# TASK NUMBER  0  DEST:  40 40
# TASK NUMBER  1  DEST:  43 32
# TASK NUMBER  0  DEST:  6 23
# TASK NUMBER  1  DEST:  2 24
# TASK NUMBER  0  DEST:  39 11
# TASK NUMBER  1  DEST:  34 8
# TASK NUMBER  0  DEST:  33 17
# TASK NUMBER  1  DEST:  40 13
# TASK NUMBER  0  DEST:  21 44
# TASK NUMBER  1  DEST:  2 1
# TASK NUMBER  0  DEST:  10 46
# TASK NUMBER  1  DEST:  7 7
# TASK NUMBER  0  DEST:  18 1
# TASK NUMBER  1  DEST:  49 25
# TASK NUMBER  0  DEST:  11 46
# TASK NUMBER  1  DEST:  2 27
# TASK NUMBER  0  DEST:  45 39
# TASK NUMBER  1  DEST:  19 20
# TASK NUMBER  0  DEST:  31 31
# TASK NUMBER  1  DEST:  37 22
# TASK NUMBER  0  DEST:  48 2
# TASK NUMBER  1  DEST:  26 28
# TASK NUMBER  0  DEST:  17 46
# TASK NUMBER  1  DEST:  2 35
# TASK NUMBER  0  DEST:  24 17
# TASK NUMBER  1  DEST:  33 34
# 11608.573011981458
# TASK NUMBER  0  DEST:  22 34
# TASK NUMBER  1  DEST:  24 13
# TASK NUMBER  0  DEST:  17 35
# TASK NUMBER  1  DEST:  45 23
# TASK NUMBER  0  DEST:  35 39
# TASK NUMBER  1  DEST:  46 13
# TASK NUMBER  0  DEST:  36 12
# TASK NUMBER  1  DEST:  39 38
# TASK NUMBER  0  DEST:  19 17
# TASK NUMBER  1  DEST:  20 39
# TASK NUMBER  0  DEST:  12 39
# TASK NUMBER  1  DEST:  9 17
# TASK NUMBER  0  DEST:  9 35
# TASK NUMBER  1  DEST:  27 44
# Task  0  completed at step  1539
# TASK NUMBER  0  DEST:  30 29
# TASK NUMBER  1  DEST:  29 27
# TASK NUMBER  0  DEST:  46 25
# TASK NUMBER  1  DEST:  27 42
# TASK NUMBER  0  DEST:  34 19
# TASK NUMBER  1  DEST:  38 40
# TASK NUMBER  0  DEST:  44 36
# TASK NUMBER  1  DEST:  6 4
# TASK NUMBER  0  DEST:  17 2
# TASK NUMBER  1  DEST:  37 19
# TASK NUMBER  0  DEST:  49 34
# TASK NUMBER  1  DEST:  0 22
# TASK NUMBER  0  DEST:  17 38
# TASK NUMBER  1  DEST:  35 44
# TASK NUMBER  0  DEST:  4 2
# TASK NUMBER  1  DEST:  5 49
# TASK NUMBER  0  DEST:  4 40
# TASK NUMBER  1  DEST:  16 31
# TASK NUMBER  0  DEST:  44 7
# TASK NUMBER  1  DEST:  26 9
# TASK NUMBER  0  DEST:  30 48
# TASK NUMBER  1  DEST:  1 14
# TASK NUMBER  0  DEST:  28 37
# TASK NUMBER  1  DEST:  5 6
# TASK NUMBER  0  DEST:  12 17
# TASK NUMBER  1  DEST:  46 37
# 9899.420768855061
# TASK NUMBER  0  DEST:  14 47
# TASK NUMBER  1  DEST:  24 33
# TASK NUMBER  0  DEST:  7 25
# TASK NUMBER  1  DEST:  48 19
# TASK NUMBER  0  DEST:  9 39
# TASK NUMBER  1  DEST:  39 36
# TASK NUMBER  0  DEST:  12 31
# TASK NUMBER  1  DEST:  20 18
# TASK NUMBER  0  DEST:  47 17
# TASK NUMBER  1  DEST:  7 29
# TASK NUMBER  0  DEST:  22 35
# TASK NUMBER  1  DEST:  34 19
# TASK NUMBER  0  DEST:  26 5
# TASK NUMBER  1  DEST:  14 38
# TASK NUMBER  0  DEST:  8 47
# TASK NUMBER  1  DEST:  45 27
# TASK NUMBER  0  DEST:  31 44
# TASK NUMBER  1  DEST:  1 6
# TASK NUMBER  0  DEST:  30 2
# TASK NUMBER  1  DEST:  46 30
# TASK NUMBER  0  DEST:  31 37
# TASK NUMBER  1  DEST:  34 8
# TASK NUMBER  0  DEST:  36 23
# TASK NUMBER  1  DEST:  36 37
# TASK NUMBER  0  DEST:  11 37
# TASK NUMBER  1  DEST:  32 32
# TASK NUMBER  0  DEST:  26 42
# TASK NUMBER  1  DEST:  5 19
# TASK NUMBER  0  DEST:  37 29
# TASK NUMBER  1  DEST:  16 0
# TASK NUMBER  0  DEST:  3 0
# TASK NUMBER  1  DEST:  23 14
# TASK NUMBER  0  DEST:  20 24
# TASK NUMBER  1  DEST:  8 48
# TASK NUMBER  0  DEST:  23 41
# TASK NUMBER  1  DEST:  21 21
# TASK NUMBER  0  DEST:  5 10
# TASK NUMBER  1  DEST:  19 49
# TASK NUMBER  0  DEST:  46 27
# TASK NUMBER  1  DEST:  33 22
# 11943.128372743808
# TASK NUMBER  0  DEST:  39 45
# TASK NUMBER  1  DEST:  19 8
# TASK NUMBER  0  DEST:  11 23
# TASK NUMBER  1  DEST:  19 12
# TASK NUMBER  0  DEST:  37 12
# TASK NUMBER  1  DEST:  29 5
# TASK NUMBER  0  DEST:  1 47
# TASK NUMBER  1  DEST:  13 0
# TASK NUMBER  0  DEST:  2 31
# TASK NUMBER  1  DEST:  14 7
# TASK NUMBER  0  DEST:  17 25
# TASK NUMBER  1  DEST:  45 10
# TASK NUMBER  0  DEST:  23 40
# TASK NUMBER  1  DEST:  29 43
# TASK NUMBER  0  DEST:  3 15
# TASK NUMBER  1  DEST:  19 7
# TASK NUMBER  0  DEST:  41 31
# TASK NUMBER  1  DEST:  7 38
# TASK NUMBER  0  DEST:  21 25
# TASK NUMBER  1  DEST:  42 40
# TASK NUMBER  0  DEST:  18 0
# TASK NUMBER  1  DEST:  29 15
# TASK NUMBER  0  DEST:  30 28
# TASK NUMBER  1  DEST:  28 5
# Task  0  completed at step  2802
# TASK NUMBER  0  DEST:  16 27
# TASK NUMBER  1  DEST:  8 14
# TASK NUMBER  0  DEST:  28 8
# TASK NUMBER  1  DEST:  28 16
# TASK NUMBER  0  DEST:  47 30
# TASK NUMBER  1  DEST:  8 0
# TASK NUMBER  0  DEST:  3 18
# TASK NUMBER  1  DEST:  34 2
# TASK NUMBER  0  DEST:  30 31
# TASK NUMBER  1  DEST:  20 20
# TASK NUMBER  0  DEST:  7 18
# TASK NUMBER  1  DEST:  28 43
# TASK NUMBER  0  DEST:  38 39
# TASK NUMBER  1  DEST:  27 23
# TASK NUMBER  0  DEST:  11 46
# TASK NUMBER  1  DEST:  9 35
# 8954.011384743475
# TASK NUMBER  0  DEST:  49 19
# TASK NUMBER  1  DEST:  29 47
# TASK NUMBER  0  DEST:  19 3
# TASK NUMBER  1  DEST:  7 16
# TASK NUMBER  0  DEST:  17 38
# TASK NUMBER  1  DEST:  39 47
# TASK NUMBER  0  DEST:  17 19
# TASK NUMBER  1  DEST:  14 42
# TASK NUMBER  0  DEST:  19 8
# TASK NUMBER  1  DEST:  12 10
# TASK NUMBER  0  DEST:  37 49
# TASK NUMBER  1  DEST:  18 28
# TASK NUMBER  0  DEST:  31 29
# TASK NUMBER  1  DEST:  24 17
# TASK NUMBER  0  DEST:  20 18
# TASK NUMBER  1  DEST:  21 47
# TASK NUMBER  0  DEST:  23 48
# TASK NUMBER  1  DEST:  49 38
# TASK NUMBER  0  DEST:  47 27
# TASK NUMBER  1  DEST:  32 37
# TASK NUMBER  0  DEST:  40 44
# TASK NUMBER  1  DEST:  0 28
# TASK NUMBER  0  DEST:  47 21
# TASK NUMBER  1  DEST:  4 17
# TASK NUMBER  0  DEST:  27 21
# TASK NUMBER  1  DEST:  31 28
# TASK NUMBER  0  DEST:  9 13
# TASK NUMBER  1  DEST:  17 47
# TASK NUMBER  0  DEST:  6 2
# TASK NUMBER  1  DEST:  17 37
# Task  0  completed at step  333
# TASK NUMBER  0  DEST:  3 32
# TASK NUMBER  1  DEST:  25 30
# TASK NUMBER  0  DEST:  10 40
# TASK NUMBER  1  DEST:  15 0
# TASK NUMBER  0  DEST:  1 44
# TASK NUMBER  1  DEST:  46 16
# TASK NUMBER  0  DEST:  43 35
# TASK NUMBER  1  DEST:  4 5
# TASK NUMBER  0  DEST:  25 45
# TASK NUMBER  1  DEST:  14 13
# 12049.590316338254
# TASK NUMBER  0  DEST:  30 28
# TASK NUMBER  1  DEST:  36 15
# TASK NUMBER  0  DEST:  37 33
# TASK NUMBER  1  DEST:  29 44
# TASK NUMBER  0  DEST:  19 12
# TASK NUMBER  1  DEST:  42 29
# TASK NUMBER  0  DEST:  49 23
# TASK NUMBER  1  DEST:  32 2
# TASK NUMBER  0  DEST:  40 39
# TASK NUMBER  1  DEST:  30 42
# TASK NUMBER  0  DEST:  0 33
# TASK NUMBER  1  DEST:  49 24
# TASK NUMBER  0  DEST:  9 29
# TASK NUMBER  1  DEST:  19 22
# TASK NUMBER  0  DEST:  10 4
# TASK NUMBER  1  DEST:  28 40
# TASK NUMBER  0  DEST:  21 0
# TASK NUMBER  1  DEST:  43 25
# TASK NUMBER  0  DEST:  10 15
# TASK NUMBER  1  DEST:  34 35
# TASK NUMBER  0  DEST:  39 29
# TASK NUMBER  1  DEST:  37 34
# TASK NUMBER  0  DEST:  23 37
# TASK NUMBER  1  DEST:  44 49
# TASK NUMBER  0  DEST:  27 28
# TASK NUMBER  1  DEST:  25 11
# Task  0  completed at step  147
# TASK NUMBER  0  DEST:  3 7
# TASK NUMBER  1  DEST:  42 13
# TASK NUMBER  0  DEST:  48 30
# TASK NUMBER  1  DEST:  36 47
# TASK NUMBER  0  DEST:  22 1
# TASK NUMBER  1  DEST:  30 0
# TASK NUMBER  0  DEST:  47 25
# TASK NUMBER  1  DEST:  19 11
# TASK NUMBER  0  DEST:  40 8
# TASK NUMBER  1  DEST:  47 40
# TASK NUMBER  0  DEST:  32 25
# TASK NUMBER  1  DEST:  1 40
# Task  0  completed at step  3986
# TASK NUMBER  0  DEST:  13 34
# TASK NUMBER  1  DEST:  14 13
# 9747.324498718746
# TASK NUMBER  0  DEST:  34 44
# TASK NUMBER  1  DEST:  3 26
# TASK NUMBER  0  DEST:  26 11
# TASK NUMBER  1  DEST:  47 28
# Task  0  completed at step  3940
# TASK NUMBER  0  DEST:  1 4
# TASK NUMBER  1  DEST:  7 0
# TASK NUMBER  0  DEST:  41 16
# TASK NUMBER  1  DEST:  14 28
# TASK NUMBER  0  DEST:  46 6
# TASK NUMBER  1  DEST:  20 47
# TASK NUMBER  0  DEST:  3 37
# TASK NUMBER  1  DEST:  2 13
# TASK NUMBER  0  DEST:  22 12
# TASK NUMBER  1  DEST:  20 10
# TASK NUMBER  0  DEST:  27 46
# TASK NUMBER  1  DEST:  11 32
# TASK NUMBER  0  DEST:  28 49
# TASK NUMBER  1  DEST:  0 14
# TASK NUMBER  0  DEST:  15 4
# TASK NUMBER  1  DEST:  29 43
# TASK NUMBER  0  DEST:  31 9
# TASK NUMBER  1  DEST:  37 1
# TASK NUMBER  0  DEST:  22 9
# TASK NUMBER  1  DEST:  40 5
# TASK NUMBER  0  DEST:  1 27
# TASK NUMBER  1  DEST:  8 32
# TASK NUMBER  0  DEST:  28 46
# TASK NUMBER  1  DEST:  10 31
# TASK NUMBER  0  DEST:  11 30
# TASK NUMBER  1  DEST:  12 4
# TASK NUMBER  0  DEST:  42 14
# TASK NUMBER  1  DEST:  3 4
# TASK NUMBER  0  DEST:  2 44
# TASK NUMBER  1  DEST:  31 5
# TASK NUMBER  0  DEST:  1 34
# TASK NUMBER  1  DEST:  11 40
# TASK NUMBER  0  DEST:  6 34
# TASK NUMBER  1  DEST:  33 11
# TASK NUMBER  0  DEST:  11 2
# TASK NUMBER  1  DEST:  40 16
# 10313.873791037715
# TASK NUMBER  0  DEST:  5 33
# TASK NUMBER  1  DEST:  33 14
# TASK NUMBER  0  DEST:  38 48
# TASK NUMBER  1  DEST:  23 42
# TASK NUMBER  0  DEST:  5 3
# TASK NUMBER  1  DEST:  26 22
# TASK NUMBER  0  DEST:  44 45
# TASK NUMBER  1  DEST:  19 14
# TASK NUMBER  0  DEST:  47 11
# TASK NUMBER  1  DEST:  17 34
# TASK NUMBER  0  DEST:  24 29
# TASK NUMBER  1  DEST:  16 15
# TASK NUMBER  0  DEST:  46 46
# TASK NUMBER  1  DEST:  27 1
# TASK NUMBER  0  DEST:  48 33
# TASK NUMBER  1  DEST:  40 28
# TASK NUMBER  0  DEST:  41 35
# TASK NUMBER  1  DEST:  38 46
# TASK NUMBER  0  DEST:  14 34
# TASK NUMBER  1  DEST:  7 22
# TASK NUMBER  0  DEST:  31 27
# TASK NUMBER  1  DEST:  41 8
# TASK NUMBER  0  DEST:  40 27
# TASK NUMBER  1  DEST:  7 47
# TASK NUMBER  0  DEST:  16 46
# TASK NUMBER  1  DEST:  19 30
# TASK NUMBER  0  DEST:  31 7
# TASK NUMBER  1  DEST:  35 39
# TASK NUMBER  0  DEST:  18 13
# TASK NUMBER  1  DEST:  44 23
# TASK NUMBER  0  DEST:  38 5
# TASK NUMBER  1  DEST:  36 49
# TASK NUMBER  0  DEST:  36 2
# TASK NUMBER  1  DEST:  24 9
# TASK NUMBER  0  DEST:  34 45
# TASK NUMBER  1  DEST:  7 1
# TASK NUMBER  0  DEST:  13 5
# TASK NUMBER  1  DEST:  36 16
# TASK NUMBER  0  DEST:  47 18
# TASK NUMBER  1  DEST:  37 14
# 8847.559167499363
# TASK NUMBER  0  DEST:  20 25
# TASK NUMBER  1  DEST:  39 32
# TASK NUMBER  0  DEST:  19 18
# TASK NUMBER  1  DEST:  8 7
# TASK NUMBER  0  DEST:  44 13
# TASK NUMBER  1  DEST:  32 7
# TASK NUMBER  0  DEST:  43 36
# TASK NUMBER  1  DEST:  13 45
# TASK NUMBER  0  DEST:  7 9
# TASK NUMBER  1  DEST:  37 36
# TASK NUMBER  0  DEST:  15 41
# TASK NUMBER  1  DEST:  21 42
# TASK NUMBER  0  DEST:  36 4
# TASK NUMBER  1  DEST:  48 41
# TASK NUMBER  0  DEST:  38 1
# TASK NUMBER  1  DEST:  40 28
# TASK NUMBER  0  DEST:  13 29
# TASK NUMBER  1  DEST:  36 19
# TASK NUMBER  0  DEST:  14 10
# TASK NUMBER  1  DEST:  1 11
# TASK NUMBER  0  DEST:  15 13
# TASK NUMBER  1  DEST:  5 16
# TASK NUMBER  0  DEST:  34 31
# TASK NUMBER  1  DEST:  9 36
# TASK NUMBER  0  DEST:  29 4
# TASK NUMBER  1  DEST:  20 49
# TASK NUMBER  0  DEST:  34 38
# TASK NUMBER  1  DEST:  45 5
# TASK NUMBER  0  DEST:  8 3
# TASK NUMBER  1  DEST:  29 34
# TASK NUMBER  0  DEST:  43 28
# TASK NUMBER  1  DEST:  48 22
# TASK NUMBER  0  DEST:  21 23
# TASK NUMBER  1  DEST:  36 35
# TASK NUMBER  0  DEST:  17 35
# TASK NUMBER  1  DEST:  26 14
# TASK NUMBER  0  DEST:  9 28
# TASK NUMBER  1  DEST:  43 46
# TASK NUMBER  0  DEST:  7 19
# TASK NUMBER  1  DEST:  26 13
# 10132.70453492492
# TASK NUMBER  0  DEST:  34 24
# TASK NUMBER  1  DEST:  36 9
# TASK NUMBER  0  DEST:  36 18
# TASK NUMBER  1  DEST:  31 47
# Task  0  completed at step  2173
# TASK NUMBER  0  DEST:  44 8
# TASK NUMBER  1  DEST:  21 4
# TASK NUMBER  0  DEST:  1 29
# TASK NUMBER  1  DEST:  37 36
# TASK NUMBER  0  DEST:  30 47
# TASK NUMBER  1  DEST:  12 6
# TASK NUMBER  0  DEST:  17 47
# TASK NUMBER  1  DEST:  9 48
# TASK NUMBER  0  DEST:  30 15
# TASK NUMBER  1  DEST:  43 13
# TASK NUMBER  0  DEST:  18 44
# TASK NUMBER  1  DEST:  31 8
# TASK NUMBER  0  DEST:  43 41
# TASK NUMBER  1  DEST:  27 33
# TASK NUMBER  0  DEST:  8 0
# TASK NUMBER  1  DEST:  4 49
# TASK NUMBER  0  DEST:  42 44
# TASK NUMBER  1  DEST:  8 11
# TASK NUMBER  0  DEST:  10 18
# TASK NUMBER  1  DEST:  23 12
# TASK NUMBER  0  DEST:  18 34
# TASK NUMBER  1  DEST:  45 7
# TASK NUMBER  0  DEST:  44 31
# TASK NUMBER  1  DEST:  43 27
# TASK NUMBER  0  DEST:  49 30
# TASK NUMBER  1  DEST:  3 38
# TASK NUMBER  0  DEST:  21 36
# TASK NUMBER  1  DEST:  32 25
# TASK NUMBER  0  DEST:  29 3
# TASK NUMBER  1  DEST:  45 13
# TASK NUMBER  0  DEST:  33 0
# TASK NUMBER  1  DEST:  45 23
# TASK NUMBER  0  DEST:  32 17
# TASK NUMBER  1  DEST:  26 23
# TASK NUMBER  0  DEST:  4 21
# TASK NUMBER  1  DEST:  47 43
# 10212.650643234641
# TASK NUMBER  0  DEST:  13 14
# TASK NUMBER  1  DEST:  32 10
# TASK NUMBER  0  DEST:  36 36
# TASK NUMBER  1  DEST:  41 7
# TASK NUMBER  0  DEST:  48 34
# TASK NUMBER  1  DEST:  23 25
# TASK NUMBER  0  DEST:  35 48
# TASK NUMBER  1  DEST:  25 33
# TASK NUMBER  0  DEST:  10 41
# TASK NUMBER  1  DEST:  26 22
# TASK NUMBER  0  DEST:  39 18
# TASK NUMBER  1  DEST:  41 36
# TASK NUMBER  0  DEST:  38 10
# TASK NUMBER  1  DEST:  33 44
# TASK NUMBER  0  DEST:  5 40
# TASK NUMBER  1  DEST:  1 11
# TASK NUMBER  0  DEST:  36 17
# TASK NUMBER  1  DEST:  17 35
# TASK NUMBER  0  DEST:  48 45
# TASK NUMBER  1  DEST:  19 37
# TASK NUMBER  0  DEST:  16 16
# TASK NUMBER  1  DEST:  4 17
# TASK NUMBER  0  DEST:  18 2
# TASK NUMBER  1  DEST:  19 38
# TASK NUMBER  0  DEST:  39 44
# TASK NUMBER  1  DEST:  32 6
# TASK NUMBER  0  DEST:  38 5
# TASK NUMBER  1  DEST:  27 33
# Task  1  completed at step  9
# TASK NUMBER  0  DEST:  26 32
# TASK NUMBER  1  DEST:  13 33
# TASK NUMBER  0  DEST:  33 47
# TASK NUMBER  1  DEST:  20 44
# TASK NUMBER  0  DEST:  20 30
# TASK NUMBER  1  DEST:  6 15
# TASK NUMBER  0  DEST:  39 22
# TASK NUMBER  1  DEST:  41 27
# TASK NUMBER  0  DEST:  32 20
# TASK NUMBER  1  DEST:  42 21
# TASK NUMBER  0  DEST:  40 27
# TASK NUMBER  1  DEST:  10 26
# 10972.310690259415
# TASK NUMBER  0  DEST:  10 48
# TASK NUMBER  1  DEST:  30 41
# TASK NUMBER  0  DEST:  39 19
# TASK NUMBER  1  DEST:  3 36
# TASK NUMBER  0  DEST:  24 41
# TASK NUMBER  1  DEST:  44 39
# TASK NUMBER  0  DEST:  12 33
# TASK NUMBER  1  DEST:  34 7
# TASK NUMBER  0  DEST:  47 42
# TASK NUMBER  1  DEST:  49 49
# TASK NUMBER  0  DEST:  29 47
# TASK NUMBER  1  DEST:  17 44
# TASK NUMBER  0  DEST:  26 16
# TASK NUMBER  1  DEST:  44 20
# TASK NUMBER  0  DEST:  0 42
# TASK NUMBER  1  DEST:  3 38
# TASK NUMBER  0  DEST:  10 0
# TASK NUMBER  1  DEST:  22 43
# TASK NUMBER  0  DEST:  21 45
# TASK NUMBER  1  DEST:  38 42
# TASK NUMBER  0  DEST:  20 12
# TASK NUMBER  1  DEST:  19 11
# TASK NUMBER  0  DEST:  3 42
# TASK NUMBER  1  DEST:  38 0
# TASK NUMBER  0  DEST:  15 38
# TASK NUMBER  1  DEST:  14 19
# TASK NUMBER  0  DEST:  32 48
# TASK NUMBER  1  DEST:  2 14
# TASK NUMBER  0  DEST:  19 0
# TASK NUMBER  1  DEST:  41 32
# TASK NUMBER  0  DEST:  46 4
# TASK NUMBER  1  DEST:  12 2
# TASK NUMBER  0  DEST:  6 41
# TASK NUMBER  1  DEST:  23 14
# TASK NUMBER  0  DEST:  3 25
# TASK NUMBER  1  DEST:  27 3
# TASK NUMBER  0  DEST:  40 36
# TASK NUMBER  1  DEST:  18 2
# TASK NUMBER  0  DEST:  10 32
# TASK NUMBER  1  DEST:  17 20
# 8577.462922487824
# TASK NUMBER  0  DEST:  26 27
# TASK NUMBER  1  DEST:  44 46
# Task  0  completed at step  462
# TASK NUMBER  0  DEST:  18 20
# TASK NUMBER  1  DEST:  36 38
# TASK NUMBER  0  DEST:  42 4
# TASK NUMBER  1  DEST:  32 26
# TASK NUMBER  0  DEST:  3 2
# TASK NUMBER  1  DEST:  42 3
# TASK NUMBER  0  DEST:  22 46
# TASK NUMBER  1  DEST:  10 24
# TASK NUMBER  0  DEST:  20 48
# TASK NUMBER  1  DEST:  28 24
# TASK NUMBER  0  DEST:  32 17
# TASK NUMBER  1  DEST:  23 30
# TASK NUMBER  0  DEST:  16 26
# TASK NUMBER  1  DEST:  25 7
# TASK NUMBER  0  DEST:  42 48
# TASK NUMBER  1  DEST:  12 49
# TASK NUMBER  0  DEST:  36 34
# TASK NUMBER  1  DEST:  43 22
# Task  1  completed at step  368
# TASK NUMBER  0  DEST:  15 9
# TASK NUMBER  1  DEST:  34 25
# TASK NUMBER  0  DEST:  9 32
# TASK NUMBER  1  DEST:  34 26
# TASK NUMBER  0  DEST:  41 28
# TASK NUMBER  1  DEST:  0 16
# TASK NUMBER  0  DEST:  32 12
# TASK NUMBER  1  DEST:  28 12
# TASK NUMBER  0  DEST:  22 29
# TASK NUMBER  1  DEST:  32 35
# Task  0  completed at step  136
# TASK NUMBER  0  DEST:  1 42
# TASK NUMBER  1  DEST:  27 5
# TASK NUMBER  0  DEST:  43 40
# TASK NUMBER  1  DEST:  38 36
# TASK NUMBER  0  DEST:  10 15
# TASK NUMBER  1  DEST:  9 14
# TASK NUMBER  0  DEST:  9 24
# TASK NUMBER  1  DEST:  41 20
# Task  1  completed at step  4525
# TASK NUMBER  0  DEST:  34 35
# TASK NUMBER  1  DEST:  9 20
# 13292.107919507473
# TASK NUMBER  0  DEST:  15 17
# TASK NUMBER  1  DEST:  46 11
# TASK NUMBER  0  DEST:  49 14
# TASK NUMBER  1  DEST:  5 19
# TASK NUMBER  0  DEST:  38 46
# TASK NUMBER  1  DEST:  39 41
# TASK NUMBER  0  DEST:  32 44
# TASK NUMBER  1  DEST:  18 39
# TASK NUMBER  0  DEST:  34 9
# TASK NUMBER  1  DEST:  14 0
# TASK NUMBER  0  DEST:  4 48
# TASK NUMBER  1  DEST:  28 44
# TASK NUMBER  0  DEST:  37 5
# TASK NUMBER  1  DEST:  31 0
# TASK NUMBER  0  DEST:  11 9
# TASK NUMBER  1  DEST:  4 26
# TASK NUMBER  0  DEST:  28 1
# TASK NUMBER  1  DEST:  24 11
# TASK NUMBER  0  DEST:  39 33
# TASK NUMBER  1  DEST:  30 33
# TASK NUMBER  0  DEST:  49 33
# TASK NUMBER  1  DEST:  31 43
# TASK NUMBER  0  DEST:  7 19
# TASK NUMBER  1  DEST:  12 35
# TASK NUMBER  0  DEST:  43 34
# TASK NUMBER  1  DEST:  27 28
# TASK NUMBER  0  DEST:  36 1
# TASK NUMBER  1  DEST:  5 8
# TASK NUMBER  0  DEST:  22 29
# TASK NUMBER  1  DEST:  49 10
# TASK NUMBER  0  DEST:  20 48
# TASK NUMBER  1  DEST:  9 9
# TASK NUMBER  0  DEST:  12 34
# TASK NUMBER  1  DEST:  1 4
# TASK NUMBER  0  DEST:  3 7
# TASK NUMBER  1  DEST:  48 49
# TASK NUMBER  0  DEST:  34 25
# TASK NUMBER  1  DEST:  47 39
# TASK NUMBER  0  DEST:  12 10
# TASK NUMBER  1  DEST:  21 3
# 8592.802326072906
# TASK NUMBER  0  DEST:  1 19
# TASK NUMBER  1  DEST:  4 44
# TASK NUMBER  0  DEST:  26 9
# TASK NUMBER  1  DEST:  16 21
# TASK NUMBER  0  DEST:  4 41
# TASK NUMBER  1  DEST:  39 31
# TASK NUMBER  0  DEST:  48 11
# TASK NUMBER  1  DEST:  23 25
# TASK NUMBER  0  DEST:  32 4
# TASK NUMBER  1  DEST:  30 15
# Task  1  completed at step  2530
# TASK NUMBER  0  DEST:  13 6
# TASK NUMBER  1  DEST:  29 30
# TASK NUMBER  0  DEST:  45 39
# TASK NUMBER  1  DEST:  9 38
# TASK NUMBER  0  DEST:  38 24
# TASK NUMBER  1  DEST:  37 14
# TASK NUMBER  0  DEST:  18 36
# TASK NUMBER  1  DEST:  37 41
# TASK NUMBER  0  DEST:  18 45
# TASK NUMBER  1  DEST:  5 49
# TASK NUMBER  0  DEST:  9 8
# TASK NUMBER  1  DEST:  24 5
# TASK NUMBER  0  DEST:  27 43
# TASK NUMBER  1  DEST:  47 30
# TASK NUMBER  0  DEST:  47 13
# TASK NUMBER  1  DEST:  48 38
# TASK NUMBER  0  DEST:  29 5
# TASK NUMBER  1  DEST:  23 32
# TASK NUMBER  0  DEST:  36 44
# TASK NUMBER  1  DEST:  17 35
# TASK NUMBER  0  DEST:  12 14
# TASK NUMBER  1  DEST:  11 15
# TASK NUMBER  0  DEST:  3 29
# TASK NUMBER  1  DEST:  21 12
# TASK NUMBER  0  DEST:  19 47
# TASK NUMBER  1  DEST:  38 46
# TASK NUMBER  0  DEST:  10 36
# TASK NUMBER  1  DEST:  25 28
# TASK NUMBER  0  DEST:  42 47
# TASK NUMBER  1  DEST:  40 35
# 10395.386667279581
# TASK NUMBER  0  DEST:  2 12
# TASK NUMBER  1  DEST:  45 7
# TASK NUMBER  0  DEST:  23 0
# TASK NUMBER  1  DEST:  23 35
# TASK NUMBER  0  DEST:  32 39
# TASK NUMBER  1  DEST:  37 11
# TASK NUMBER  0  DEST:  2 49
# TASK NUMBER  1  DEST:  45 15
# TASK NUMBER  0  DEST:  16 8
# TASK NUMBER  1  DEST:  23 44
# TASK NUMBER  0  DEST:  18 37
# TASK NUMBER  1  DEST:  47 36
# TASK NUMBER  0  DEST:  20 15
# TASK NUMBER  1  DEST:  21 41
# TASK NUMBER  0  DEST:  47 34
# TASK NUMBER  1  DEST:  21 12
# TASK NUMBER  0  DEST:  29 5
# TASK NUMBER  1  DEST:  12 29
# TASK NUMBER  0  DEST:  3 10
# TASK NUMBER  1  DEST:  28 34
# TASK NUMBER  0  DEST:  7 34
# TASK NUMBER  1  DEST:  21 12
# TASK NUMBER  0  DEST:  17 42
# TASK NUMBER  1  DEST:  29 8
# TASK NUMBER  0  DEST:  27 7
# TASK NUMBER  1  DEST:  5 26
# TASK NUMBER  0  DEST:  2 25
# TASK NUMBER  1  DEST:  14 16
# TASK NUMBER  0  DEST:  38 9
# TASK NUMBER  1  DEST:  0 22
# TASK NUMBER  0  DEST:  45 21
# TASK NUMBER  1  DEST:  40 27
# TASK NUMBER  0  DEST:  22 32
# TASK NUMBER  1  DEST:  37 4
# TASK NUMBER  0  DEST:  1 18
# TASK NUMBER  1  DEST:  1 15
# TASK NUMBER  0  DEST:  34 13
# TASK NUMBER  1  DEST:  8 27
# TASK NUMBER  0  DEST:  43 21
# TASK NUMBER  1  DEST:  47 20
# 10951.61400554442
# TASK NUMBER  0  DEST:  10 18
# TASK NUMBER  1  DEST:  30 33
# TASK NUMBER  0  DEST:  36 2
# TASK NUMBER  1  DEST:  18 36
# TASK NUMBER  0  DEST:  20 49
# TASK NUMBER  1  DEST:  22 7
# TASK NUMBER  0  DEST:  6 31
# TASK NUMBER  1  DEST:  27 4
# TASK NUMBER  0  DEST:  35 19
# TASK NUMBER  1  DEST:  28 47
# TASK NUMBER  0  DEST:  22 22
# TASK NUMBER  1  DEST:  38 32
# TASK NUMBER  0  DEST:  0 34
# TASK NUMBER  1  DEST:  28 8
# TASK NUMBER  0  DEST:  25 12
# TASK NUMBER  1  DEST:  9 32
# TASK NUMBER  0  DEST:  8 29
# TASK NUMBER  1  DEST:  34 45
# TASK NUMBER  0  DEST:  35 9
# TASK NUMBER  1  DEST:  12 5
# TASK NUMBER  0  DEST:  32 46
# TASK NUMBER  1  DEST:  28 7
# TASK NUMBER  0  DEST:  21 28
# TASK NUMBER  1  DEST:  24 18
# TASK NUMBER  0  DEST:  49 14
# TASK NUMBER  1  DEST:  47 24
# TASK NUMBER  0  DEST:  3 32
# TASK NUMBER  1  DEST:  44 43
# TASK NUMBER  0  DEST:  11 16
# TASK NUMBER  1  DEST:  39 0
# TASK NUMBER  0  DEST:  43 49
# TASK NUMBER  1  DEST:  3 25
# TASK NUMBER  0  DEST:  27 9
# TASK NUMBER  1  DEST:  18 30
# TASK NUMBER  0  DEST:  6 1
# TASK NUMBER  1  DEST:  38 16
# Task  1  completed at step  79
# TASK NUMBER  0  DEST:  8 42
# TASK NUMBER  1  DEST:  15 9
# TASK NUMBER  0  DEST:  43 15
# TASK NUMBER  1  DEST:  3 23
# 12945.509623187445
# TASK NUMBER  0  DEST:  13 0
# TASK NUMBER  1  DEST:  0 16
# TASK NUMBER  0  DEST:  33 45
# TASK NUMBER  1  DEST:  31 13
# TASK NUMBER  0  DEST:  5 20
# TASK NUMBER  1  DEST:  31 23
# TASK NUMBER  0  DEST:  6 42
# TASK NUMBER  1  DEST:  8 42
# TASK NUMBER  0  DEST:  17 40
# TASK NUMBER  1  DEST:  17 5
# TASK NUMBER  0  DEST:  4 34
# TASK NUMBER  1  DEST:  7 38
# TASK NUMBER  0  DEST:  44 6
# TASK NUMBER  1  DEST:  8 32
# TASK NUMBER  0  DEST:  11 11
# TASK NUMBER  1  DEST:  39 7
# TASK NUMBER  0  DEST:  3 7
# TASK NUMBER  1  DEST:  42 1
# TASK NUMBER  0  DEST:  17 44
# TASK NUMBER  1  DEST:  3 43
# TASK NUMBER  0  DEST:  10 1
# TASK NUMBER  1  DEST:  24 31
# TASK NUMBER  0  DEST:  32 5
# TASK NUMBER  1  DEST:  29 35
# TASK NUMBER  0  DEST:  37 38
# TASK NUMBER  1  DEST:  17 35
# TASK NUMBER  0  DEST:  7 29
# TASK NUMBER  1  DEST:  17 9
# TASK NUMBER  0  DEST:  30 27
# TASK NUMBER  1  DEST:  1 41
# TASK NUMBER  0  DEST:  42 4
# TASK NUMBER  1  DEST:  28 4
# TASK NUMBER  0  DEST:  28 23
# TASK NUMBER  1  DEST:  15 41
# TASK NUMBER  0  DEST:  12 40
# TASK NUMBER  1  DEST:  33 38
# TASK NUMBER  0  DEST:  49 5
# TASK NUMBER  1  DEST:  17 41
# TASK NUMBER  0  DEST:  29 6
# TASK NUMBER  1  DEST:  17 28
# 13413.99312285546
# TASK NUMBER  0  DEST:  2 9
# TASK NUMBER  1  DEST:  42 48
# TASK NUMBER  0  DEST:  36 36
# TASK NUMBER  1  DEST:  12 16
# TASK NUMBER  0  DEST:  11 27
# TASK NUMBER  1  DEST:  23 17
# TASK NUMBER  0  DEST:  47 45
# TASK NUMBER  1  DEST:  4 42
# TASK NUMBER  0  DEST:  31 36
# TASK NUMBER  1  DEST:  21 10
# TASK NUMBER  0  DEST:  39 14
# TASK NUMBER  1  DEST:  3 37
# TASK NUMBER  0  DEST:  36 28
# TASK NUMBER  1  DEST:  27 18
# TASK NUMBER  0  DEST:  30 20
# TASK NUMBER  1  DEST:  12 33
# Task  0  completed at step  424
# TASK NUMBER  0  DEST:  6 45
# TASK NUMBER  1  DEST:  20 0
# TASK NUMBER  0  DEST:  17 21
# TASK NUMBER  1  DEST:  19 36
# TASK NUMBER  0  DEST:  35 23
# TASK NUMBER  1  DEST:  20 24
# TASK NUMBER  0  DEST:  2 44
# TASK NUMBER  1  DEST:  22 5
# TASK NUMBER  0  DEST:  17 41
# TASK NUMBER  1  DEST:  36 12
# TASK NUMBER  0  DEST:  26 29
# TASK NUMBER  1  DEST:  7 6
# TASK NUMBER  0  DEST:  16 42
# TASK NUMBER  1  DEST:  48 30
# TASK NUMBER  0  DEST:  30 35
# TASK NUMBER  1  DEST:  21 42
# TASK NUMBER  0  DEST:  8 25
# TASK NUMBER  1  DEST:  19 45
# TASK NUMBER  0  DEST:  14 2
# TASK NUMBER  1  DEST:  34 35
# TASK NUMBER  0  DEST:  10 24
# TASK NUMBER  1  DEST:  9 8
# TASK NUMBER  0  DEST:  23 41
# TASK NUMBER  1  DEST:  49 2
# 12762.790605161386
# TASK NUMBER  0  DEST:  12 32
# TASK NUMBER  1  DEST:  18 44
# TASK NUMBER  0  DEST:  21 40
# TASK NUMBER  1  DEST:  2 31
# TASK NUMBER  0  DEST:  14 37
# TASK NUMBER  1  DEST:  46 13
# TASK NUMBER  0  DEST:  46 19
# TASK NUMBER  1  DEST:  2 2
# TASK NUMBER  0  DEST:  49 6
# TASK NUMBER  1  DEST:  12 29
# TASK NUMBER  0  DEST:  8 23
# TASK NUMBER  1  DEST:  16 18
# TASK NUMBER  0  DEST:  28 24
# TASK NUMBER  1  DEST:  48 3
# TASK NUMBER  0  DEST:  3 28
# TASK NUMBER  1  DEST:  9 2
# TASK NUMBER  0  DEST:  21 26
# TASK NUMBER  1  DEST:  28 7
# TASK NUMBER  0  DEST:  49 16
# TASK NUMBER  1  DEST:  10 32
# TASK NUMBER  0  DEST:  47 13
# TASK NUMBER  1  DEST:  49 34
# TASK NUMBER  0  DEST:  37 13
# TASK NUMBER  1  DEST:  13 43
# TASK NUMBER  0  DEST:  40 11
# TASK NUMBER  1  DEST:  31 39
# TASK NUMBER  0  DEST:  19 42
# TASK NUMBER  1  DEST:  37 41
# TASK NUMBER  0  DEST:  48 49
# TASK NUMBER  1  DEST:  14 40
# TASK NUMBER  0  DEST:  22 0
# TASK NUMBER  1  DEST:  30 30
# TASK NUMBER  0  DEST:  37 45
# TASK NUMBER  1  DEST:  17 41
# TASK NUMBER  0  DEST:  22 40
# TASK NUMBER  1  DEST:  16 22
# TASK NUMBER  0  DEST:  35 25
# TASK NUMBER  1  DEST:  39 4
# TASK NUMBER  0  DEST:  44 10
# TASK NUMBER  1  DEST:  34 28
# 10186.402778546833
# TASK NUMBER  0  DEST:  45 44
# TASK NUMBER  1  DEST:  14 43
# TASK NUMBER  0  DEST:  14 2
# TASK NUMBER  1  DEST:  48 33
# TASK NUMBER  0  DEST:  10 4
# TASK NUMBER  1  DEST:  11 48
# TASK NUMBER  0  DEST:  20 43
# TASK NUMBER  1  DEST:  33 5
# TASK NUMBER  0  DEST:  6 45
# TASK NUMBER  1  DEST:  9 18
# TASK NUMBER  0  DEST:  35 46
# TASK NUMBER  1  DEST:  31 49
# TASK NUMBER  0  DEST:  41 33
# TASK NUMBER  1  DEST:  6 32
# TASK NUMBER  0  DEST:  10 11
# TASK NUMBER  1  DEST:  15 23
# TASK NUMBER  0  DEST:  7 19
# TASK NUMBER  1  DEST:  15 40
# TASK NUMBER  0  DEST:  22 42
# TASK NUMBER  1  DEST:  17 22
# TASK NUMBER  0  DEST:  25 18
# TASK NUMBER  1  DEST:  14 12
# TASK NUMBER  0  DEST:  17 1
# TASK NUMBER  1  DEST:  25 23
# TASK NUMBER  0  DEST:  28 30
# TASK NUMBER  1  DEST:  34 39
# TASK NUMBER  0  DEST:  8 3
# TASK NUMBER  1  DEST:  30 26
# TASK NUMBER  0  DEST:  23 29
# TASK NUMBER  1  DEST:  33 8
# TASK NUMBER  0  DEST:  26 42
# TASK NUMBER  1  DEST:  35 42
# TASK NUMBER  0  DEST:  24 47
# TASK NUMBER  1  DEST:  44 24
# TASK NUMBER  0  DEST:  37 19
# TASK NUMBER  1  DEST:  27 5
# TASK NUMBER  0  DEST:  21 19
# TASK NUMBER  1  DEST:  24 28
# TASK NUMBER  0  DEST:  19 9
# TASK NUMBER  1  DEST:  25 13
# 10413.257138778943
# TASK NUMBER  0  DEST:  17 17
# TASK NUMBER  1  DEST:  4 11
# TASK NUMBER  0  DEST:  32 20
# TASK NUMBER  1  DEST:  42 39
# TASK NUMBER  0  DEST:  46 13
# TASK NUMBER  1  DEST:  34 4
# TASK NUMBER  0  DEST:  38 44
# TASK NUMBER  1  DEST:  41 18
# TASK NUMBER  0  DEST:  32 32
# TASK NUMBER  1  DEST:  45 45
# TASK NUMBER  0  DEST:  1 27
# TASK NUMBER  1  DEST:  17 35
# TASK NUMBER  0  DEST:  39 23
# TASK NUMBER  1  DEST:  18 46
# TASK NUMBER  0  DEST:  16 16
# TASK NUMBER  1  DEST:  0 42
# TASK NUMBER  0  DEST:  12 42
# TASK NUMBER  1  DEST:  47 1
# TASK NUMBER  0  DEST:  30 10
# TASK NUMBER  1  DEST:  29 27
# TASK NUMBER  0  DEST:  23 45
# TASK NUMBER  1  DEST:  19 6
# TASK NUMBER  0  DEST:  34 3
# TASK NUMBER  1  DEST:  4 47
# TASK NUMBER  0  DEST:  28 32
# TASK NUMBER  1  DEST:  46 44
# TASK NUMBER  0  DEST:  3 20
# TASK NUMBER  1  DEST:  30 33
# TASK NUMBER  0  DEST:  25 41
# TASK NUMBER  1  DEST:  6 41
# TASK NUMBER  0  DEST:  11 14
# TASK NUMBER  1  DEST:  1 7
# TASK NUMBER  0  DEST:  34 42
# TASK NUMBER  1  DEST:  42 13
# TASK NUMBER  0  DEST:  27 6
# TASK NUMBER  1  DEST:  29 16
# TASK NUMBER  0  DEST:  22 41
# TASK NUMBER  1  DEST:  11 25
# TASK NUMBER  0  DEST:  2 19
# TASK NUMBER  1  DEST:  37 44
# 14285.86562897781
# TASK NUMBER  0  DEST:  15 35
# TASK NUMBER  1  DEST:  49 0
# TASK NUMBER  0  DEST:  24 48
# TASK NUMBER  1  DEST:  17 30
# TASK NUMBER  0  DEST:  6 28
# TASK NUMBER  1  DEST:  40 31
# TASK NUMBER  0  DEST:  41 25
# TASK NUMBER  1  DEST:  49 49
# TASK NUMBER  0  DEST:  30 34
# TASK NUMBER  1  DEST:  11 14
# TASK NUMBER  0  DEST:  5 25
# TASK NUMBER  1  DEST:  49 17
# TASK NUMBER  0  DEST:  42 26
# TASK NUMBER  1  DEST:  34 1
# TASK NUMBER  0  DEST:  39 12
# TASK NUMBER  1  DEST:  12 31
# TASK NUMBER  0  DEST:  9 18
# TASK NUMBER  1  DEST:  36 42
# TASK NUMBER  0  DEST:  15 37
# TASK NUMBER  1  DEST:  30 19
# TASK NUMBER  0  DEST:  33 39
# TASK NUMBER  1  DEST:  25 29
# TASK NUMBER  0  DEST:  20 13
# TASK NUMBER  1  DEST:  30 14
# TASK NUMBER  0  DEST:  11 1
# TASK NUMBER  1  DEST:  45 46
# TASK NUMBER  0  DEST:  17 28
# TASK NUMBER  1  DEST:  37 46
# TASK NUMBER  0  DEST:  45 27
# TASK NUMBER  1  DEST:  31 12
# TASK NUMBER  0  DEST:  6 49
# TASK NUMBER  1  DEST:  1 45
# TASK NUMBER  0  DEST:  25 27
# TASK NUMBER  1  DEST:  43 46
# TASK NUMBER  0  DEST:  11 0
# TASK NUMBER  1  DEST:  11 2
# TASK NUMBER  0  DEST:  43 33
# TASK NUMBER  1  DEST:  15 24
# TASK NUMBER  0  DEST:  24 26
# TASK NUMBER  1  DEST:  6 42
# 9630.682089305292
# TASK NUMBER  0  DEST:  17 34
# TASK NUMBER  1  DEST:  40 12
# TASK NUMBER  0  DEST:  2 25
# TASK NUMBER  1  DEST:  49 24
# TASK NUMBER  0  DEST:  48 7
# TASK NUMBER  1  DEST:  45 30
# TASK NUMBER  0  DEST:  44 12
# TASK NUMBER  1  DEST:  35 28
# TASK NUMBER  0  DEST:  16 21
# TASK NUMBER  1  DEST:  9 47
# TASK NUMBER  0  DEST:  47 12
# TASK NUMBER  1  DEST:  47 29
# TASK NUMBER  0  DEST:  26 23
# TASK NUMBER  1  DEST:  22 11
# TASK NUMBER  0  DEST:  6 29
# TASK NUMBER  1  DEST:  45 40
# TASK NUMBER  0  DEST:  37 42
# TASK NUMBER  1  DEST:  26 6
# TASK NUMBER  0  DEST:  45 8
# TASK NUMBER  1  DEST:  42 0
# TASK NUMBER  0  DEST:  9 27
# TASK NUMBER  1  DEST:  20 26
# TASK NUMBER  0  DEST:  3 24
# TASK NUMBER  1  DEST:  49 37
# TASK NUMBER  0  DEST:  46 44
# TASK NUMBER  1  DEST:  4 46
# TASK NUMBER  0  DEST:  0 33
# TASK NUMBER  1  DEST:  30 11
# TASK NUMBER  0  DEST:  19 48
# TASK NUMBER  1  DEST:  19 11
# TASK NUMBER  0  DEST:  23 34
# TASK NUMBER  1  DEST:  19 42
# TASK NUMBER  0  DEST:  44 35
# TASK NUMBER  1  DEST:  19 13
# TASK NUMBER  0  DEST:  29 24
# TASK NUMBER  1  DEST:  38 1
# TASK NUMBER  0  DEST:  27 24
# TASK NUMBER  1  DEST:  21 15
# TASK NUMBER  0  DEST:  18 30
# TASK NUMBER  1  DEST:  22 36
# 11780.479928274352
# TASK NUMBER  0  DEST:  24 23
# TASK NUMBER  1  DEST:  26 0
# TASK NUMBER  0  DEST:  36 31
# TASK NUMBER  1  DEST:  33 7
# TASK NUMBER  0  DEST:  16 45
# TASK NUMBER  1  DEST:  23 5
# TASK NUMBER  0  DEST:  10 28
# TASK NUMBER  1  DEST:  36 30
# TASK NUMBER  0  DEST:  41 38
# TASK NUMBER  1  DEST:  0 32
# TASK NUMBER  0  DEST:  47 13
# TASK NUMBER  1  DEST:  19 24
# TASK NUMBER  0  DEST:  15 32
# TASK NUMBER  1  DEST:  30 49
# TASK NUMBER  0  DEST:  46 9
# TASK NUMBER  1  DEST:  44 30
# TASK NUMBER  0  DEST:  23 21
# TASK NUMBER  1  DEST:  17 15
# Task  1  completed at step  16
# TASK NUMBER  0  DEST:  24 20
# TASK NUMBER  1  DEST:  19 5
# TASK NUMBER  0  DEST:  47 38
# TASK NUMBER  1  DEST:  44 36
# TASK NUMBER  0  DEST:  22 49
# TASK NUMBER  1  DEST:  47 1
# TASK NUMBER  0  DEST:  27 37
# TASK NUMBER  1  DEST:  40 44
# TASK NUMBER  0  DEST:  21 34
# TASK NUMBER  1  DEST:  36 39
# TASK NUMBER  0  DEST:  17 33
# TASK NUMBER  1  DEST:  37 22
# TASK NUMBER  0  DEST:  20 45
# TASK NUMBER  1  DEST:  38 27
# TASK NUMBER  0  DEST:  6 14
# TASK NUMBER  1  DEST:  33 6
# TASK NUMBER  0  DEST:  14 37
# TASK NUMBER  1  DEST:  23 2
# TASK NUMBER  0  DEST:  45 14
# TASK NUMBER  1  DEST:  47 20
# TASK NUMBER  0  DEST:  12 41
# TASK NUMBER  1  DEST:  38 36
# 9197.698293666394
# TASK NUMBER  0  DEST:  6 31
# TASK NUMBER  1  DEST:  38 15
# TASK NUMBER  0  DEST:  13 31
# TASK NUMBER  1  DEST:  7 49
# TASK NUMBER  0  DEST:  21 9
# TASK NUMBER  1  DEST:  38 48
# TASK NUMBER  0  DEST:  38 41
# TASK NUMBER  1  DEST:  24 8
# TASK NUMBER  0  DEST:  24 41
# TASK NUMBER  1  DEST:  35 24
# TASK NUMBER  0  DEST:  36 48
# TASK NUMBER  1  DEST:  30 34
# TASK NUMBER  0  DEST:  7 40
# TASK NUMBER  1  DEST:  46 36
# TASK NUMBER  0  DEST:  22 10
# TASK NUMBER  1  DEST:  28 8
# TASK NUMBER  0  DEST:  25 5
# TASK NUMBER  1  DEST:  25 4
# TASK NUMBER  0  DEST:  10 3
# TASK NUMBER  1  DEST:  18 15
# TASK NUMBER  0  DEST:  14 4
# TASK NUMBER  1  DEST:  30 7
# TASK NUMBER  0  DEST:  14 49
# TASK NUMBER  1  DEST:  12 43
# TASK NUMBER  0  DEST:  0 32
# TASK NUMBER  1  DEST:  19 37
# TASK NUMBER  0  DEST:  8 20
# TASK NUMBER  1  DEST:  19 11
# TASK NUMBER  0  DEST:  34 29
# TASK NUMBER  1  DEST:  23 21
# TASK NUMBER  0  DEST:  3 32
# TASK NUMBER  1  DEST:  15 9
# TASK NUMBER  0  DEST:  22 22
# TASK NUMBER  1  DEST:  11 33
# TASK NUMBER  0  DEST:  7 21
# TASK NUMBER  1  DEST:  10 35
# TASK NUMBER  0  DEST:  12 7
# TASK NUMBER  1  DEST:  32 39
# TASK NUMBER  0  DEST:  17 23
# TASK NUMBER  1  DEST:  23 29
# 10441.018915953255
# TASK NUMBER  0  DEST:  48 23
# TASK NUMBER  1  DEST:  15 23
# TASK NUMBER  0  DEST:  32 12
# TASK NUMBER  1  DEST:  22 32
# TASK NUMBER  0  DEST:  24 49
# TASK NUMBER  1  DEST:  36 48
# TASK NUMBER  0  DEST:  7 28
# TASK NUMBER  1  DEST:  4 11
# TASK NUMBER  0  DEST:  18 34
# TASK NUMBER  1  DEST:  11 3
# TASK NUMBER  0  DEST:  6 26
# TASK NUMBER  1  DEST:  36 33
# TASK NUMBER  0  DEST:  24 22
# TASK NUMBER  1  DEST:  38 45
# TASK NUMBER  0  DEST:  17 6
# TASK NUMBER  1  DEST:  8 49
# TASK NUMBER  0  DEST:  3 45
# TASK NUMBER  1  DEST:  23 18
# TASK NUMBER  0  DEST:  18 24
# TASK NUMBER  1  DEST:  8 17
# TASK NUMBER  0  DEST:  10 36
# TASK NUMBER  1  DEST:  37 3
# TASK NUMBER  0  DEST:  43 39
# TASK NUMBER  1  DEST:  27 36
# TASK NUMBER  0  DEST:  42 47
# TASK NUMBER  1  DEST:  5 48
# TASK NUMBER  0  DEST:  37 23
# TASK NUMBER  1  DEST:  36 18
# TASK NUMBER  0  DEST:  10 32
# TASK NUMBER  1  DEST:  10 28
# TASK NUMBER  0  DEST:  10 26
# TASK NUMBER  1  DEST:  49 4
# TASK NUMBER  0  DEST:  35 37
# TASK NUMBER  1  DEST:  47 27
# TASK NUMBER  0  DEST:  19 37
# TASK NUMBER  1  DEST:  21 10
# TASK NUMBER  0  DEST:  33 40
# TASK NUMBER  1  DEST:  7 8
# TASK NUMBER  0  DEST:  14 19
# TASK NUMBER  1  DEST:  5 11
# 11410.741778146165
# TASK NUMBER  0  DEST:  35 9
# TASK NUMBER  1  DEST:  17 3
# TASK NUMBER  0  DEST:  37 1
# TASK NUMBER  1  DEST:  32 12
# TASK NUMBER  0  DEST:  28 41
# TASK NUMBER  1  DEST:  4 5
# TASK NUMBER  0  DEST:  23 33
# TASK NUMBER  1  DEST:  22 43
# TASK NUMBER  0  DEST:  28 34
# TASK NUMBER  1  DEST:  31 40
# TASK NUMBER  0  DEST:  35 28
# TASK NUMBER  1  DEST:  22 29
# TASK NUMBER  0  DEST:  24 39
# TASK NUMBER  1  DEST:  45 16
# TASK NUMBER  0  DEST:  8 3
# TASK NUMBER  1  DEST:  23 17
# TASK NUMBER  0  DEST:  30 32
# TASK NUMBER  1  DEST:  9 0
# TASK NUMBER  0  DEST:  37 25
# TASK NUMBER  1  DEST:  5 14
# TASK NUMBER  0  DEST:  5 15
# TASK NUMBER  1  DEST:  4 21
# TASK NUMBER  0  DEST:  12 16
# TASK NUMBER  1  DEST:  21 16
# TASK NUMBER  0  DEST:  9 14
# TASK NUMBER  1  DEST:  12 27
# TASK NUMBER  0  DEST:  13 35
# TASK NUMBER  1  DEST:  38 9
# TASK NUMBER  0  DEST:  10 2
# TASK NUMBER  1  DEST:  15 4
# TASK NUMBER  0  DEST:  1 1
# TASK NUMBER  1  DEST:  5 30
# TASK NUMBER  0  DEST:  32 41
# TASK NUMBER  1  DEST:  46 46
# TASK NUMBER  0  DEST:  8 10
# TASK NUMBER  1  DEST:  45 7
# TASK NUMBER  0  DEST:  45 21
# TASK NUMBER  1  DEST:  12 5
# TASK NUMBER  0  DEST:  45 3
# TASK NUMBER  1  DEST:  41 48
# 9149.594446791687
# TASK NUMBER  0  DEST:  38 19
# TASK NUMBER  1  DEST:  38 42
# TASK NUMBER  0  DEST:  49 5
# TASK NUMBER  1  DEST:  0 38
# TASK NUMBER  0  DEST:  44 10
# TASK NUMBER  1  DEST:  18 0
# TASK NUMBER  0  DEST:  2 31
# TASK NUMBER  1  DEST:  6 13
# Task  0  completed at step  589
# TASK NUMBER  0  DEST:  12 7
# TASK NUMBER  1  DEST:  41 34
# TASK NUMBER  0  DEST:  42 29
# TASK NUMBER  1  DEST:  25 49
# TASK NUMBER  0  DEST:  10 24
# TASK NUMBER  1  DEST:  5 46
# TASK NUMBER  0  DEST:  12 10
# TASK NUMBER  1  DEST:  18 10
# TASK NUMBER  0  DEST:  15 48
# TASK NUMBER  1  DEST:  30 34
# TASK NUMBER  0  DEST:  12 21
# TASK NUMBER  1  DEST:  3 41
# TASK NUMBER  0  DEST:  17 26
# TASK NUMBER  1  DEST:  38 37
# TASK NUMBER  0  DEST:  42 38
# TASK NUMBER  1  DEST:  25 9
# TASK NUMBER  0  DEST:  40 29
# TASK NUMBER  1  DEST:  19 46
# TASK NUMBER  0  DEST:  16 0
# TASK NUMBER  1  DEST:  7 19
# TASK NUMBER  0  DEST:  25 28
# TASK NUMBER  1  DEST:  7 4
# TASK NUMBER  0  DEST:  32 1
# TASK NUMBER  1  DEST:  36 9
# TASK NUMBER  0  DEST:  34 29
# TASK NUMBER  1  DEST:  48 13
# TASK NUMBER  0  DEST:  28 44
# TASK NUMBER  1  DEST:  36 42
# TASK NUMBER  0  DEST:  19 31
# TASK NUMBER  1  DEST:  39 5
# TASK NUMBER  0  DEST:  32 28
# TASK NUMBER  1  DEST:  26 22
# Task  1  completed at step  37
# 10404.627576054098
# TASK NUMBER  0  DEST:  34 13
# TASK NUMBER  1  DEST:  25 6
# TASK NUMBER  0  DEST:  35 7
# TASK NUMBER  1  DEST:  4 26
# TASK NUMBER  0  DEST:  47 16
# TASK NUMBER  1  DEST:  36 20
# TASK NUMBER  0  DEST:  38 39
# TASK NUMBER  1  DEST:  15 46
# TASK NUMBER  0  DEST:  9 38
# TASK NUMBER  1  DEST:  0 15
# TASK NUMBER  0  DEST:  20 39
# TASK NUMBER  1  DEST:  0 21
# TASK NUMBER  0  DEST:  11 22
# TASK NUMBER  1  DEST:  13 35
# TASK NUMBER  0  DEST:  42 30
# TASK NUMBER  1  DEST:  13 26
# TASK NUMBER  0  DEST:  22 7
# TASK NUMBER  1  DEST:  9 43
# TASK NUMBER  0  DEST:  43 26
# TASK NUMBER  1  DEST:  11 25
# Task  1  completed at step  27
# TASK NUMBER  0  DEST:  10 40
# TASK NUMBER  1  DEST:  48 27
# TASK NUMBER  0  DEST:  31 49
# TASK NUMBER  1  DEST:  36 45
# TASK NUMBER  0  DEST:  26 29
# TASK NUMBER  1  DEST:  6 1
# TASK NUMBER  0  DEST:  39 32
# TASK NUMBER  1  DEST:  12 31
# TASK NUMBER  0  DEST:  40 5
# TASK NUMBER  1  DEST:  37 27
# TASK NUMBER  0  DEST:  5 9
# TASK NUMBER  1  DEST:  40 49
# TASK NUMBER  0  DEST:  37 21
# TASK NUMBER  1  DEST:  46 24
# TASK NUMBER  0  DEST:  29 16
# TASK NUMBER  1  DEST:  45 10
# TASK NUMBER  0  DEST:  33 5
# TASK NUMBER  1  DEST:  6 39
# TASK NUMBER  0  DEST:  22 24
# TASK NUMBER  1  DEST:  22 27
# 13979.458918670676
# TASK NUMBER  0  DEST:  38 41
# TASK NUMBER  1  DEST:  24 18
# TASK NUMBER  0  DEST:  1 36
# TASK NUMBER  1  DEST:  13 3
# TASK NUMBER  0  DEST:  11 21
# TASK NUMBER  1  DEST:  3 1
# TASK NUMBER  0  DEST:  7 27
# TASK NUMBER  1  DEST:  19 1
# TASK NUMBER  0  DEST:  1 39
# TASK NUMBER  1  DEST:  24 25
# TASK NUMBER  0  DEST:  11 14
# TASK NUMBER  1  DEST:  9 33
# TASK NUMBER  0  DEST:  10 42
# TASK NUMBER  1  DEST:  9 13
# TASK NUMBER  0  DEST:  23 44
# TASK NUMBER  1  DEST:  0 40
# TASK NUMBER  0  DEST:  39 13
# TASK NUMBER  1  DEST:  17 22
# TASK NUMBER  0  DEST:  4 13
# TASK NUMBER  1  DEST:  30 12
# TASK NUMBER  0  DEST:  26 41
# TASK NUMBER  1  DEST:  40 3
# TASK NUMBER  0  DEST:  43 42
# TASK NUMBER  1  DEST:  36 16
# TASK NUMBER  0  DEST:  12 38
# TASK NUMBER  1  DEST:  30 5
# TASK NUMBER  0  DEST:  47 47
# TASK NUMBER  1  DEST:  49 1
# TASK NUMBER  0  DEST:  5 48
# TASK NUMBER  1  DEST:  46 0
# TASK NUMBER  0  DEST:  2 27
# TASK NUMBER  1  DEST:  36 20
# TASK NUMBER  0  DEST:  37 36
# TASK NUMBER  1  DEST:  45 26
# TASK NUMBER  0  DEST:  45 13
# TASK NUMBER  1  DEST:  32 39
# TASK NUMBER  0  DEST:  26 3
# TASK NUMBER  1  DEST:  24 23
# TASK NUMBER  0  DEST:  35 24
# TASK NUMBER  1  DEST:  28 24
# 11065.474951987979
# TASK NUMBER  0  DEST:  45 29
# TASK NUMBER  1  DEST:  6 28
# TASK NUMBER  0  DEST:  43 24
# TASK NUMBER  1  DEST:  26 9
# TASK NUMBER  0  DEST:  38 23
# TASK NUMBER  1  DEST:  13 48
# TASK NUMBER  0  DEST:  10 10
# TASK NUMBER  1  DEST:  35 10
# TASK NUMBER  0  DEST:  3 46
# TASK NUMBER  1  DEST:  13 37
# TASK NUMBER  0  DEST:  6 22
# TASK NUMBER  1  DEST:  3 19
# TASK NUMBER  0  DEST:  0 26
# TASK NUMBER  1  DEST:  47 48
# TASK NUMBER  0  DEST:  3 12
# TASK NUMBER  1  DEST:  17 31
# TASK NUMBER  0  DEST:  46 24
# TASK NUMBER  1  DEST:  5 4
# TASK NUMBER  0  DEST:  12 27
# TASK NUMBER  1  DEST:  37 11
# TASK NUMBER  0  DEST:  4 26
# TASK NUMBER  1  DEST:  15 39
# TASK NUMBER  0  DEST:  21 13
# TASK NUMBER  1  DEST:  20 30
# TASK NUMBER  0  DEST:  11 18
# TASK NUMBER  1  DEST:  21 29
# TASK NUMBER  0  DEST:  16 30
# TASK NUMBER  1  DEST:  16 18
# TASK NUMBER  0  DEST:  28 6
# TASK NUMBER  1  DEST:  40 30
# TASK NUMBER  0  DEST:  46 35
# TASK NUMBER  1  DEST:  3 22
# TASK NUMBER  0  DEST:  45 18
# TASK NUMBER  1  DEST:  49 19
# TASK NUMBER  0  DEST:  1 9
# TASK NUMBER  1  DEST:  23 42
# TASK NUMBER  0  DEST:  40 20
# TASK NUMBER  1  DEST:  22 20
# TASK NUMBER  0  DEST:  25 29
# TASK NUMBER  1  DEST:  38 1
# 15307.451852365517
# TASK NUMBER  0  DEST:  16 18
# TASK NUMBER  1  DEST:  35 46
# TASK NUMBER  0  DEST:  0 30
# TASK NUMBER  1  DEST:  16 27
# TASK NUMBER  0  DEST:  26 1
# TASK NUMBER  1  DEST:  12 34
# TASK NUMBER  0  DEST:  13 20
# TASK NUMBER  1  DEST:  5 38
# TASK NUMBER  0  DEST:  6 17
# TASK NUMBER  1  DEST:  29 48
# TASK NUMBER  0  DEST:  48 27
# TASK NUMBER  1  DEST:  18 26
# TASK NUMBER  0  DEST:  31 43
# TASK NUMBER  1  DEST:  31 44
# TASK NUMBER  0  DEST:  32 39
# TASK NUMBER  1  DEST:  27 42
# TASK NUMBER  0  DEST:  48 19
# TASK NUMBER  1  DEST:  22 49
# TASK NUMBER  0  DEST:  47 45
# TASK NUMBER  1  DEST:  13 41
# TASK NUMBER  0  DEST:  8 16
# TASK NUMBER  1  DEST:  42 26
# TASK NUMBER  0  DEST:  43 38
# TASK NUMBER  1  DEST:  35 13
# TASK NUMBER  0  DEST:  29 33
# TASK NUMBER  1  DEST:  5 22
# Task  0  completed at step  2423
# TASK NUMBER  0  DEST:  3 33
# TASK NUMBER  1  DEST:  27 25
# TASK NUMBER  0  DEST:  15 46
# TASK NUMBER  1  DEST:  30 36
# TASK NUMBER  0  DEST:  38 35
# TASK NUMBER  1  DEST:  23 38
# TASK NUMBER  0  DEST:  29 9
# TASK NUMBER  1  DEST:  29 46
# TASK NUMBER  0  DEST:  16 23
# TASK NUMBER  1  DEST:  12 30
# TASK NUMBER  0  DEST:  17 13
# TASK NUMBER  1  DEST:  35 43
# TASK NUMBER  0  DEST:  38 20
# TASK NUMBER  1  DEST:  15 29
# 12326.323189373565
# TASK NUMBER  0  DEST:  19 28
# TASK NUMBER  1  DEST:  26 35
# TASK NUMBER  0  DEST:  21 21
# TASK NUMBER  1  DEST:  4 48
# TASK NUMBER  0  DEST:  7 24
# TASK NUMBER  1  DEST:  13 46
# Task  0  completed at step  1718
# TASK NUMBER  0  DEST:  10 27
# TASK NUMBER  1  DEST:  22 0
# TASK NUMBER  0  DEST:  10 49
# TASK NUMBER  1  DEST:  42 38
# TASK NUMBER  0  DEST:  3 40
# TASK NUMBER  1  DEST:  19 8
# TASK NUMBER  0  DEST:  26 49
# TASK NUMBER  1  DEST:  42 45
# TASK NUMBER  0  DEST:  17 13
# TASK NUMBER  1  DEST:  48 45
# TASK NUMBER  0  DEST:  33 33
# TASK NUMBER  1  DEST:  42 39
# TASK NUMBER  0  DEST:  20 16
# TASK NUMBER  1  DEST:  16 15
# TASK NUMBER  0  DEST:  33 24
# TASK NUMBER  1  DEST:  2 46
# TASK NUMBER  0  DEST:  29 43
# TASK NUMBER  1  DEST:  16 3
# TASK NUMBER  0  DEST:  18 49
# TASK NUMBER  1  DEST:  21 21
# TASK NUMBER  0  DEST:  48 14
# TASK NUMBER  1  DEST:  6 17
# TASK NUMBER  0  DEST:  19 48
# TASK NUMBER  1  DEST:  31 9
# TASK NUMBER  0  DEST:  25 45
# TASK NUMBER  1  DEST:  37 21
# TASK NUMBER  0  DEST:  45 46
# TASK NUMBER  1  DEST:  28 26
# TASK NUMBER  0  DEST:  49 33
# TASK NUMBER  1  DEST:  41 13
# TASK NUMBER  0  DEST:  27 27
# TASK NUMBER  1  DEST:  29 12
# TASK NUMBER  0  DEST:  40 17
# TASK NUMBER  1  DEST:  16 15
# 12988.632238447432
# TASK NUMBER  0  DEST:  33 19
# TASK NUMBER  1  DEST:  26 23
# TASK NUMBER  0  DEST:  38 22
# TASK NUMBER  1  DEST:  13 41
# TASK NUMBER  0  DEST:  10 48
# TASK NUMBER  1  DEST:  39 28
# TASK NUMBER  0  DEST:  40 20
# TASK NUMBER  1  DEST:  0 49
# TASK NUMBER  0  DEST:  12 44
# TASK NUMBER  1  DEST:  33 48
# TASK NUMBER  0  DEST:  2 34
# TASK NUMBER  1  DEST:  41 4
# TASK NUMBER  0  DEST:  31 26
# TASK NUMBER  1  DEST:  1 10
# TASK NUMBER  0  DEST:  36 37
# TASK NUMBER  1  DEST:  42 32
# TASK NUMBER  0  DEST:  24 10
# TASK NUMBER  1  DEST:  24 8
# TASK NUMBER  0  DEST:  42 37
# TASK NUMBER  1  DEST:  24 19
# TASK NUMBER  0  DEST:  14 11
# TASK NUMBER  1  DEST:  30 24
# TASK NUMBER  0  DEST:  25 27
# TASK NUMBER  1  DEST:  17 22
# TASK NUMBER  0  DEST:  22 5
# TASK NUMBER  1  DEST:  13 41
# TASK NUMBER  0  DEST:  0 22
# TASK NUMBER  1  DEST:  7 22
# TASK NUMBER  0  DEST:  3 5
# TASK NUMBER  1  DEST:  5 26
# TASK NUMBER  0  DEST:  33 11
# TASK NUMBER  1  DEST:  4 16
# TASK NUMBER  0  DEST:  16 2
# TASK NUMBER  1  DEST:  47 4
# TASK NUMBER  0  DEST:  9 17
# TASK NUMBER  1  DEST:  28 21
# TASK NUMBER  0  DEST:  25 48
# TASK NUMBER  1  DEST:  32 16
# TASK NUMBER  0  DEST:  39 33
# TASK NUMBER  1  DEST:  34 30
# 14161.495350604735
# TASK NUMBER  0  DEST:  7 38
# TASK NUMBER  1  DEST:  9 3
# TASK NUMBER  0  DEST:  0 8
# TASK NUMBER  1  DEST:  32 36
# TASK NUMBER  0  DEST:  41 13
# TASK NUMBER  1  DEST:  37 13
# TASK NUMBER  0  DEST:  10 43
# TASK NUMBER  1  DEST:  34 24
# TASK NUMBER  0  DEST:  5 27
# TASK NUMBER  1  DEST:  10 4
# TASK NUMBER  0  DEST:  19 9
# TASK NUMBER  1  DEST:  9 12
# TASK NUMBER  0  DEST:  18 7
# TASK NUMBER  1  DEST:  12 10
# TASK NUMBER  0  DEST:  35 31
# TASK NUMBER  1  DEST:  35 47
# TASK NUMBER  0  DEST:  15 45
# TASK NUMBER  1  DEST:  49 49
# TASK NUMBER  0  DEST:  18 49
# TASK NUMBER  1  DEST:  7 30
# TASK NUMBER  0  DEST:  47 32
# TASK NUMBER  1  DEST:  46 47
# TASK NUMBER  0  DEST:  31 40
# TASK NUMBER  1  DEST:  24 14
# TASK NUMBER  0  DEST:  17 4
# TASK NUMBER  1  DEST:  32 32
# TASK NUMBER  0  DEST:  42 10
# TASK NUMBER  1  DEST:  45 20
# TASK NUMBER  0  DEST:  40 36
# TASK NUMBER  1  DEST:  25 37
# TASK NUMBER  0  DEST:  42 1
# TASK NUMBER  1  DEST:  13 5
# TASK NUMBER  0  DEST:  48 30
# TASK NUMBER  1  DEST:  11 22
# TASK NUMBER  0  DEST:  49 5
# TASK NUMBER  1  DEST:  42 36
# TASK NUMBER  0  DEST:  36 11
# TASK NUMBER  1  DEST:  17 36
# TASK NUMBER  0  DEST:  45 45
# TASK NUMBER  1  DEST:  37 25
# 10142.663567393496

# %% [markdown]
# https://github.com/jiechuanjiang/pytorch_DGN/blob/main/Surviving/DGN%2BATOC/main.py

# %%
env = GridWorldWithCare(NUM_TASKS)
observation_space = env.len_obs
n_actions = env.n_action
n_tasks = env.n_tasks

buff = ReplayBufferGCare(buffer_size,observation_space,n_actions,n_tasks)
model = MTRL_DGN(n_tasks,observation_space,hidden_dim,n_actions)
model_tar = MTRL_DGN(n_tasks,observation_space,hidden_dim,n_actions)
model = model.cuda()
model_tar = model_tar.cuda()
optimizer = optim.Adam(model.parameters(), lr = 0.001)
# att = MTRL_ATT(observation_space).cuda()
# att_tar = MTRL_ATT(observation_space).cuda()
# att_tar.load_state_dict(att.state_dict())
# optimizer_att = optim.Adam(att.parameters(), lr = 0.001)
criterion = nn.BCELoss()

M_Null = torch.Tensor(np.array([np.eye(n_tasks)]*batch_size)).cuda()
M_ZERO = torch.Tensor(np.zeros((batch_size,n_tasks,n_tasks))).cuda()
# threshold = float(sys.argv[1]) TODO: figure this out
# f = open(sys.argv[1]+'-'+sys.argv[2]+'.txt','w+')
f = open("TRIAL-9-SoftAttention-Concat.txt", "w+")
while i_episode<n_episode:
    if i_episode > 40:
        epsilon -= 0.001
        if epsilon < 0.01:
            epsilon = 0.01
    i_episode+=1
    steps = 0
    obs, adj = env.reset()
    obs = np.resize(obs, (n_tasks, observation_space))
    while steps < max_step:
        steps+=1 
#         cost_all += adj.sum()
#         v_a = np.array(att(torch.Tensor(np.array([obs])).cuda())[0].cpu().data)
#         for i in range(n_tasks):
#             if np.random.rand() < epsilon:
#                 adj[i] = adj[i]*0 if np.random.rand() < 0.5 else adj[i]*1
#             else:
#                 adj[i] = adj[i]*0 if v_a[i][0] < threshold else adj[i]*1
        # Note: above loop is epsilon greedy exploration to give less importance to observations that fall below a certain threshold
        # May not be needed if we use single encoder but could be useful in the case of mixture of encoders
        # Pruning "less imp" neighbours whose obs fall below a certain threshold
#         n_adj = adj*comm_flag
#         cost_comm += n_adj.sum()
#         n_adj = n_adj + np.eye(n_tasks)
#         q_dummy = model(torch.Tensor(np.array([obs])).cuda(), torch.Tensor(np.array([adj])).cuda())
#         print("model output shape", q_dummy.shape)
        q = model(torch.Tensor(np.array([obs])).cuda(), torch.Tensor(np.array([adj])).cuda())[0,0,:]
#         print("Shape of Q: ", q.shape)
        if np.random.rand() < epsilon:
#             print("HERE RANDOM")
            a = np.random.randint(n_actions)
        else:
#             print("HERE FROM MODEL")
            a = q.argmax().item()

        action = a
        
        next_obs, next_adj, reward, terminated = env.step(action)
#         print('action: {}, next_obs: {}\nnext_adj:\n{}'.format(
#             action, next_obs, next_adj
#         ))
        
        next_obs = np.resize(next_obs, (n_tasks, observation_space))
        
        buff.add(np.array(obs),action,reward,np.array(next_obs),adj,next_adj,terminated)
        
        obs = next_obs
        adj = next_adj
        score += reward

    if i_episode%20==0:
        print(score)
        #print(score/2000)
        f.write(str(score)+'\n')
        # Cost (neighbors in adj matrix)after pruning/ Cost before pruning
        f.flush()
        score = 0

#     if i_episode < 40:
#         continue

    for e in range(n_epoch):

        O,A,R,Next_O,Matrix,Next_Matrix,D = buff.getBatch(batch_size)
        O = torch.Tensor(O).cuda()
        Matrix = torch.Tensor(Matrix).cuda()
        Next_O = torch.Tensor(Next_O).cuda()
        Next_Matrix = torch.Tensor(Next_Matrix).cuda()

#         label = model(Next_O, Next_Matrix+M_Null).max(dim = 2)[0] - model(Next_O, M_Null).max(dim = 2)[0]
#         #print("Label", label.shape)
#         label = (label - label.mean())/(label.std()+0.000001) + 0.5
#         label = torch.clamp(label, 0, 1).unsqueeze(-1).detach()
#         #print("Label after clamping", label.shape)
#         #print("ATT output", label_dummy.shape)
#         loss = criterion(a(Next_O), label)
#         optimizer_att.zero_grad()
#         loss.backward()
#         optimizer_att.step()
        # Basically att is learning which obs from the maze help return the max q value

#         V_A_D = att_tar(Next_O).expand(-1,-1,n_ant)
#         Next_Matrix = torch.where(V_A_D > threshold, Next_Matrix, M_ZERO)
#         Next_Matrix = Next_Matrix*comm_flag + M_Null

        q_values = model(O, Matrix)
#         print("Q Vals Before slicing: ", q_values.shape)
        q_values = model(O, Matrix)[:,0, :]
#         print("Q Vals After slicing: ", q_values_final.shape)
        target_q_values = model_tar(Next_O, Next_Matrix).max(dim = 2)[0][:,0]
#         print("Target Q Vals: ", target_q_values.shape)
        target_q_values = np.array(target_q_values.cpu().data)
        expected_q = np.array(q_values.cpu().data)

        for j in range(batch_size):
#             for i in range(n_tasks):
            expected_q[j][A[j][0]] = R[j][0] + (1-D[j][0])*GAMMA*target_q_values[j]

        loss = (q_values - torch.Tensor(expected_q).cuda()).pow(2).mean()
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if e%10 == 0:
            with torch.no_grad():
                for p, p_targ in zip(model.parameters(), model_tar.parameters()):
                    p_targ.data.mul_(tau)
                    p_targ.data.add_((1 - tau) * p.data)
#                 for p, p_targ in zip(att.parameters(), att_tar.parameters()):
#                     p_targ.data.mul_(tau)
#                     p_targ.data.add_((1 - tau) * p.data)
# Out:
# TASK NUMBER  0  DEST:  27 20
# TASK NUMBER  1  DEST:  19 16
# TASK NUMBER  0  DEST:  26 3
# TASK NUMBER  1  DEST:  38 3
# TASK NUMBER  0  DEST:  8 25
# TASK NUMBER  1  DEST:  30 13
# TASK NUMBER  0  DEST:  14 31
# TASK NUMBER  1  DEST:  32 8
# TASK NUMBER  0  DEST:  2 31
# TASK NUMBER  1  DEST:  11 3
# TASK NUMBER  0  DEST:  39 35
# TASK NUMBER  1  DEST:  30 8
# TASK NUMBER  0  DEST:  32 1
# TASK NUMBER  1  DEST:  29 31
# TASK NUMBER  0  DEST:  21 0
# TASK NUMBER  1  DEST:  29 46
# TASK NUMBER  0  DEST:  21 37
# TASK NUMBER  1  DEST:  38 11
# TASK NUMBER  0  DEST:  33 35
# TASK NUMBER  1  DEST:  20 17
# TASK NUMBER  0  DEST:  34 35
# TASK NUMBER  1  DEST:  49 5
# TASK NUMBER  0  DEST:  28 5
# TASK NUMBER  1  DEST:  10 24
# TASK NUMBER  0  DEST:  42 27
# TASK NUMBER  1  DEST:  7 10
# TASK NUMBER  0  DEST:  6 17
# TASK NUMBER  1  DEST:  16 29
# Task  0  completed at step  148
# TASK NUMBER  0  DEST:  33 13
# TASK NUMBER  1  DEST:  23 46
# Task  1  completed at step  559
# TASK NUMBER  0  DEST:  35 44
# TASK NUMBER  1  DEST:  19 16
# TASK NUMBER  0  DEST:  24 1
# TASK NUMBER  1  DEST:  13 13
# TASK NUMBER  0  DEST:  15 46
# TASK NUMBER  1  DEST:  40 18
# 8230.462170060162
# TASK NUMBER  0  DEST:  26 36
# TASK NUMBER  1  DEST:  6 2
# TASK NUMBER  0  DEST:  46 15
# TASK NUMBER  1  DEST:  31 22
# TASK NUMBER  0  DEST:  25 18
# TASK NUMBER  1  DEST:  47 34
# TASK NUMBER  0  DEST:  37 21
# TASK NUMBER  1  DEST:  23 48
# TASK NUMBER  0  DEST:  33 17
# TASK NUMBER  1  DEST:  24 6
# TASK NUMBER  0  DEST:  39 11
# TASK NUMBER  1  DEST:  11 27
# TASK NUMBER  0  DEST:  10 16
# TASK NUMBER  1  DEST:  36 38
# TASK NUMBER  0  DEST:  44 10
# TASK NUMBER  1  DEST:  6 40
# TASK NUMBER  0  DEST:  48 5
# TASK NUMBER  1  DEST:  38 27
# Task  0  completed at step  4995
# TASK NUMBER  0  DEST:  0 22
# TASK NUMBER  1  DEST:  7 12
# TASK NUMBER  0  DEST:  4 16
# TASK NUMBER  1  DEST:  19 1
# Task  1  completed at step  561
# TASK NUMBER  0  DEST:  48 33
# TASK NUMBER  1  DEST:  31 35
# TASK NUMBER  0  DEST:  10 19
# TASK NUMBER  1  DEST:  31 28
# TASK NUMBER  0  DEST:  42 41
# TASK NUMBER  1  DEST:  23 38
# TASK NUMBER  0  DEST:  0 44
# TASK NUMBER  1  DEST:  38 43
# Task  0  completed at step  3532
# TASK NUMBER  0  DEST:  11 26
# TASK NUMBER  1  DEST:  24 36
# TASK NUMBER  0  DEST:  15 7
# TASK NUMBER  1  DEST:  29 21
# TASK NUMBER  0  DEST:  24 34
# TASK NUMBER  1  DEST:  36 23
# TASK NUMBER  0  DEST:  9 6
# TASK NUMBER  1  DEST:  18 3
# Task  1  completed at step  49
# TASK NUMBER  0  DEST:  20 9
# TASK NUMBER  1  DEST:  41 34
# 11695.582467680135
# TASK NUMBER  0  DEST:  29 14
# TASK NUMBER  1  DEST:  26 16
# Task  0  completed at step  2354
# TASK NUMBER  0  DEST:  48 48
# TASK NUMBER  1  DEST:  23 31
# TASK NUMBER  0  DEST:  31 37
# TASK NUMBER  1  DEST:  40 12
# TASK NUMBER  0  DEST:  36 34
# TASK NUMBER  1  DEST:  16 46
# TASK NUMBER  0  DEST:  19 42
# TASK NUMBER  1  DEST:  32 42
# TASK NUMBER  0  DEST:  21 21
# TASK NUMBER  1  DEST:  7 15
# Task  1  completed at step  215
# TASK NUMBER  0  DEST:  39 3
# TASK NUMBER  1  DEST:  1 44
# TASK NUMBER  0  DEST:  41 37
# TASK NUMBER  1  DEST:  6 19
# TASK NUMBER  0  DEST:  38 41
# TASK NUMBER  1  DEST:  40 18
# Task  1  completed at step  3892
# TASK NUMBER  0  DEST:  26 17
# TASK NUMBER  1  DEST:  4 7
# Task  1  completed at step  260
# TASK NUMBER  0  DEST:  11 41
# TASK NUMBER  1  DEST:  24 39
# TASK NUMBER  0  DEST:  19 31
# TASK NUMBER  1  DEST:  35 33
# TASK NUMBER  0  DEST:  22 15
# TASK NUMBER  1  DEST:  15 47
# TASK NUMBER  0  DEST:  24 15
# TASK NUMBER  1  DEST:  33 6
# TASK NUMBER  0  DEST:  48 35
# TASK NUMBER  1  DEST:  36 25
# Task  1  completed at step  365
# TASK NUMBER  0  DEST:  34 47
# TASK NUMBER  1  DEST:  7 25
# Task  1  completed at step  1529
# TASK NUMBER  0  DEST:  48 24
# TASK NUMBER  1  DEST:  32 10
# Task  1  completed at step  639
# TASK NUMBER  0  DEST:  21 19
# TASK NUMBER  1  DEST:  22 48
# TASK NUMBER  0  DEST:  46 33
# TASK NUMBER  1  DEST:  35 18
# Task  1  completed at step  519
# TASK NUMBER  0  DEST:  2 30
# TASK NUMBER  1  DEST:  25 33
# 19864.91632421636
# TASK NUMBER  0  DEST:  4 3
# TASK NUMBER  1  DEST:  6 31
# TASK NUMBER  0  DEST:  3 4
# TASK NUMBER  1  DEST:  44 48
# TASK NUMBER  0  DEST:  37 41
# TASK NUMBER  1  DEST:  16 13
# Task  1  completed at step  1198
# TASK NUMBER  0  DEST:  14 10
# TASK NUMBER  1  DEST:  21 48
# TASK NUMBER  0  DEST:  28 3
# TASK NUMBER  1  DEST:  34 43
# TASK NUMBER  0  DEST:  45 7
# TASK NUMBER  1  DEST:  15 30
# TASK NUMBER  0  DEST:  8 3
# TASK NUMBER  1  DEST:  27 9
# TASK NUMBER  0  DEST:  24 32
# TASK NUMBER  1  DEST:  44 1
# TASK NUMBER  0  DEST:  0 7
# TASK NUMBER  1  DEST:  39 1
# TASK NUMBER  0  DEST:  34 46
# TASK NUMBER  1  DEST:  18 40
# TASK NUMBER  0  DEST:  11 49
# TASK NUMBER  1  DEST:  24 20
# TASK NUMBER  0  DEST:  48 16
# TASK NUMBER  1  DEST:  40 19
# Task  0  completed at step  1533
# TASK NUMBER  0  DEST:  33 5
# TASK NUMBER  1  DEST:  37 47
# Task  1  completed at step  4469
# TASK NUMBER  0  DEST:  9 21
# TASK NUMBER  1  DEST:  48 20
# TASK NUMBER  0  DEST:  0 41
# TASK NUMBER  1  DEST:  20 6
# TASK NUMBER  0  DEST:  33 35
# TASK NUMBER  1  DEST:  0 14
# TASK NUMBER  0  DEST:  27 15
# TASK NUMBER  1  DEST:  20 33
# TASK NUMBER  0  DEST:  32 1
# TASK NUMBER  1  DEST:  41 33
# TASK NUMBER  0  DEST:  23 21
# TASK NUMBER  1  DEST:  49 27
# TASK NUMBER  0  DEST:  14 7
# TASK NUMBER  1  DEST:  40 21
# 15151.655015206592
# TASK NUMBER  0  DEST:  26 22
# TASK NUMBER  1  DEST:  4 24
# Task  1  completed at step  4654
# TASK NUMBER  0  DEST:  25 28
# TASK NUMBER  1  DEST:  38 16
# Task  1  completed at step  531
# TASK NUMBER  0  DEST:  11 16
# TASK NUMBER  1  DEST:  7 29
# TASK NUMBER  0  DEST:  46 21
# TASK NUMBER  1  DEST:  17 44
# TASK NUMBER  0  DEST:  21 33
# TASK NUMBER  1  DEST:  40 41
# Task  1  completed at step  39
# TASK NUMBER  0  DEST:  29 33
# TASK NUMBER  1  DEST:  5 44
# TASK NUMBER  0  DEST:  10 5
# TASK NUMBER  1  DEST:  6 19
# Task  1  completed at step  69
# TASK NUMBER  0  DEST:  2 33
# TASK NUMBER  1  DEST:  17 5
# TASK NUMBER  0  DEST:  40 1
# TASK NUMBER  1  DEST:  41 1
# TASK NUMBER  0  DEST:  11 35
# TASK NUMBER  1  DEST:  6 49
# Task  1  completed at step  794
# TASK NUMBER  0  DEST:  42 28
# TASK NUMBER  1  DEST:  48 14
# Task  1  completed at step  75
# TASK NUMBER  0  DEST:  40 25
# TASK NUMBER  1  DEST:  23 12
# Task  0  completed at step  20
# Task  1  completed at step  360
# TASK NUMBER  0  DEST:  8 11
# TASK NUMBER  1  DEST:  26 35
# TASK NUMBER  0  DEST:  44 24
# TASK NUMBER  1  DEST:  11 12
# TASK NUMBER  0  DEST:  26 47
# TASK NUMBER  1  DEST:  46 39
# TASK NUMBER  0  DEST:  7 0
# TASK NUMBER  1  DEST:  15 41
# TASK NUMBER  0  DEST:  3 47
# TASK NUMBER  1  DEST:  46 23
# TASK NUMBER  0  DEST:  4 11
# TASK NUMBER  1  DEST:  18 6
# Task  0  completed at step  77
# Task  1  completed at step  2002
# TASK NUMBER  0  DEST:  37 13
# TASK NUMBER  1  DEST:  49 47
# TASK NUMBER  0  DEST:  14 36
# TASK NUMBER  1  DEST:  37 30
# Task  1  completed at step  1437
# 24570.936535092835
# TASK NUMBER  0  DEST:  4 7
# TASK NUMBER  1  DEST:  47 49
# TASK NUMBER  0  DEST:  6 18
# TASK NUMBER  1  DEST:  23 7
# Task  1  completed at step  126
# TASK NUMBER  0  DEST:  21 43
# TASK NUMBER  1  DEST:  7 23
# TASK NUMBER  0  DEST:  11 33
# TASK NUMBER  1  DEST:  22 6
# TASK NUMBER  0  DEST:  27 45
# TASK NUMBER  1  DEST:  6 41
# TASK NUMBER  0  DEST:  49 28
# TASK NUMBER  1  DEST:  35 24
# TASK NUMBER  0  DEST:  19 14
# TASK NUMBER  1  DEST:  44 49
# TASK NUMBER  0  DEST:  46 12
# TASK NUMBER  1  DEST:  29 44
# TASK NUMBER  0  DEST:  49 2
# TASK NUMBER  1  DEST:  12 43
# TASK NUMBER  0  DEST:  13 1
# TASK NUMBER  1  DEST:  27 3
# Task  0  completed at step  12
# TASK NUMBER  0  DEST:  34 21
# TASK NUMBER  1  DEST:  0 45
# TASK NUMBER  0  DEST:  1 8
# TASK NUMBER  1  DEST:  5 49
# Task  1  completed at step  3890
# TASK NUMBER  0  DEST:  42 9
# TASK NUMBER  1  DEST:  15 46
# Task  1  completed at step  1207
# TASK NUMBER  0  DEST:  0 45
# TASK NUMBER  1  DEST:  34 27
# TASK NUMBER  0  DEST:  2 48
# TASK NUMBER  1  DEST:  9 40
# TASK NUMBER  0  DEST:  25 21
# TASK NUMBER  1  DEST:  19 23
# Task  1  completed at step  61
# TASK NUMBER  0  DEST:  9 36
# TASK NUMBER  1  DEST:  4 46
# TASK NUMBER  0  DEST:  16 23
# TASK NUMBER  1  DEST:  25 47
# Task  1  completed at step  3514
# TASK NUMBER  0  DEST:  38 9
# TASK NUMBER  1  DEST:  41 23
# Task  1  completed at step  617
# TASK NUMBER  0  DEST:  2 37
# TASK NUMBER  1  DEST:  32 47
# 20971.762072413138
# TASK NUMBER  0  DEST:  42 29
# TASK NUMBER  1  DEST:  3 18
# Task  1  completed at step  85
# TASK NUMBER  0  DEST:  25 45
# TASK NUMBER  1  DEST:  14 27
# TASK NUMBER  0  DEST:  8 15
# TASK NUMBER  1  DEST:  28 43
# TASK NUMBER  0  DEST:  22 13
# TASK NUMBER  1  DEST:  40 26
# Task  1  completed at step  1501
# TASK NUMBER  0  DEST:  32 29
# TASK NUMBER  1  DEST:  29 26
# Task  0  completed at step  1775
# Task  1  completed at step  1859
# TASK NUMBER  0  DEST:  49 42
# TASK NUMBER  1  DEST:  48 49
# TASK NUMBER  0  DEST:  20 46
# TASK NUMBER  1  DEST:  27 15
# TASK NUMBER  0  DEST:  31 30
# TASK NUMBER  1  DEST:  26 49
# TASK NUMBER  0  DEST:  30 11
# TASK NUMBER  1  DEST:  38 46
# Task  1  completed at step  108
# TASK NUMBER  0  DEST:  0 46
# TASK NUMBER  1  DEST:  38 23
# TASK NUMBER  0  DEST:  49 24
# TASK NUMBER  1  DEST:  25 16
# Task  1  completed at step  2980
# TASK NUMBER  0  DEST:  25 22
# TASK NUMBER  1  DEST:  6 47
# TASK NUMBER  0  DEST:  41 40
# TASK NUMBER  1  DEST:  36 33
# TASK NUMBER  0  DEST:  42 47
# TASK NUMBER  1  DEST:  21 21
# TASK NUMBER  0  DEST:  48 27
# TASK NUMBER  1  DEST:  5 10
# Task  0  completed at step  371
# TASK NUMBER  0  DEST:  17 43
# TASK NUMBER  1  DEST:  14 39
# TASK NUMBER  0  DEST:  11 28
# TASK NUMBER  1  DEST:  42 32
# TASK NUMBER  0  DEST:  1 12
# TASK NUMBER  1  DEST:  45 31
# Task  1  completed at step  2261
# TASK NUMBER  0  DEST:  23 22
# TASK NUMBER  1  DEST:  6 35
# Task  1  completed at step  26
# TASK NUMBER  0  DEST:  30 33
# TASK NUMBER  1  DEST:  28 0
# 20842.858327171056
# TASK NUMBER  0  DEST:  21 48
# TASK NUMBER  1  DEST:  22 4
# TASK NUMBER  0  DEST:  1 3
# TASK NUMBER  1  DEST:  3 29
# Task  1  completed at step  900
# TASK NUMBER  0  DEST:  33 48
# TASK NUMBER  1  DEST:  10 13
# TASK NUMBER  0  DEST:  29 12
# TASK NUMBER  1  DEST:  46 16
# TASK NUMBER  0  DEST:  15 43
# TASK NUMBER  1  DEST:  33 4
# Task  1  completed at step  1840
# TASK NUMBER  0  DEST:  19 22
# TASK NUMBER  1  DEST:  23 16
# Task  0  completed at step  752
# Task  1  completed at step  3698
# TASK NUMBER  0  DEST:  16 24
# TASK NUMBER  1  DEST:  40 3
# TASK NUMBER  0  DEST:  0 31
# TASK NUMBER  1  DEST:  41 31
# Task  1  completed at step  25
# TASK NUMBER  0  DEST:  49 35
# TASK NUMBER  1  DEST:  13 37
# TASK NUMBER  0  DEST:  38 32
# TASK NUMBER  1  DEST:  16 6
# TASK NUMBER  0  DEST:  1 24
# TASK NUMBER  1  DEST:  44 6
# TASK NUMBER  0  DEST:  26 38
# TASK NUMBER  1  DEST:  15 22
# TASK NUMBER  0  DEST:  19 30
# TASK NUMBER  1  DEST:  22 5
# TASK NUMBER  0  DEST:  11 48
# TASK NUMBER  1  DEST:  12 46
# TASK NUMBER  0  DEST:  5 45
# TASK NUMBER  1  DEST:  7 40
# Task  0  completed at step  3288
# TASK NUMBER  0  DEST:  8 46
# TASK NUMBER  1  DEST:  6 26
# Task  0  completed at step  567
# TASK NUMBER  0  DEST:  25 20
# TASK NUMBER  1  DEST:  27 46
# TASK NUMBER  0  DEST:  39 7
# TASK NUMBER  1  DEST:  6 48
# Task  1  completed at step  959
# TASK NUMBER  0  DEST:  22 44
# TASK NUMBER  1  DEST:  21 34
# TASK NUMBER  0  DEST:  47 27
# TASK NUMBER  1  DEST:  3 11
# 16445.36834305945
# TASK NUMBER  0  DEST:  28 25
# TASK NUMBER  1  DEST:  41 18
# TASK NUMBER  0  DEST:  41 46
# TASK NUMBER  1  DEST:  3 18
# TASK NUMBER  0  DEST:  31 42
# TASK NUMBER  1  DEST:  0 22
# TASK NUMBER  0  DEST:  16 0
# TASK NUMBER  1  DEST:  37 45
# Task  1  completed at step  458
# TASK NUMBER  0  DEST:  49 6
# TASK NUMBER  1  DEST:  1 35
# TASK NUMBER  0  DEST:  14 8
# TASK NUMBER  1  DEST:  12 30
# Task  1  completed at step  812
# TASK NUMBER  0  DEST:  0 6
# TASK NUMBER  1  DEST:  41 16
# Task  0  completed at step  1
# TASK NUMBER  0  DEST:  42 21
# TASK NUMBER  1  DEST:  1 36
# TASK NUMBER  0  DEST:  25 33
# TASK NUMBER  1  DEST:  18 0
# Task  1  completed at step  413
# TASK NUMBER  0  DEST:  23 43
# TASK NUMBER  1  DEST:  14 44
# TASK NUMBER  0  DEST:  8 44
# TASK NUMBER  1  DEST:  30 17
# TASK NUMBER  0  DEST:  9 34
# TASK NUMBER  1  DEST:  47 20
# TASK NUMBER  0  DEST:  33 8
# TASK NUMBER  1  DEST:  34 33
# Task  1  completed at step  780
# TASK NUMBER  0  DEST:  30 4
# TASK NUMBER  1  DEST:  0 22
# TASK NUMBER  0  DEST:  35 25
# TASK NUMBER  1  DEST:  4 6
# Task  0  completed at step  69
# TASK NUMBER  0  DEST:  4 13
# TASK NUMBER  1  DEST:  6 45
# TASK NUMBER  0  DEST:  8 33
# TASK NUMBER  1  DEST:  2 48
# Task  1  completed at step  132
# TASK NUMBER  0  DEST:  12 47
# TASK NUMBER  1  DEST:  30 12
# TASK NUMBER  0  DEST:  25 47
# TASK NUMBER  1  DEST:  8 35
# TASK NUMBER  0  DEST:  43 40
# TASK NUMBER  1  DEST:  9 14
# 20654.447649328406
# TASK NUMBER  0  DEST:  8 16
# TASK NUMBER  1  DEST:  41 8
# Task  1  completed at step  1179
# TASK NUMBER  0  DEST:  20 32
# TASK NUMBER  1  DEST:  21 32
# Task  1  completed at step  578
# Task  0  completed at step  3343
# TASK NUMBER  0  DEST:  43 12
# TASK NUMBER  1  DEST:  36 10
# TASK NUMBER  0  DEST:  32 42
# TASK NUMBER  1  DEST:  38 49
# Task  1  completed at step  164
# TASK NUMBER  0  DEST:  27 43
# TASK NUMBER  1  DEST:  34 47
# Task  0  completed at step  183
# TASK NUMBER  0  DEST:  33 9
# TASK NUMBER  1  DEST:  12 44
# Task  1  completed at step  57
# TASK NUMBER  0  DEST:  19 16
# TASK NUMBER  1  DEST:  18 40
# Task  1  completed at step  162
# TASK NUMBER  0  DEST:  34 15
# TASK NUMBER  1  DEST:  5 31
# Task  1  completed at step  543
# TASK NUMBER  0  DEST:  4 43
# TASK NUMBER  1  DEST:  38 13
# TASK NUMBER  0  DEST:  38 39
# TASK NUMBER  1  DEST:  42 31
# TASK NUMBER  0  DEST:  7 38
# TASK NUMBER  1  DEST:  23 9
# Task  1  completed at step  63
# TASK NUMBER  0  DEST:  15 14
# TASK NUMBER  1  DEST:  17 0
# TASK NUMBER  0  DEST:  19 33
# TASK NUMBER  1  DEST:  0 6
# TASK NUMBER  0  DEST:  10 41
# TASK NUMBER  1  DEST:  14 48
# Task  1  completed at step  450
# TASK NUMBER  0  DEST:  49 38
# TASK NUMBER  1  DEST:  26 23
# Task  1  completed at step  245
# TASK NUMBER  0  DEST:  12 33
# TASK NUMBER  1  DEST:  5 21
# Task  0  completed at step  179
# Task  1  completed at step  476
# TASK NUMBER  0  DEST:  4 33
# TASK NUMBER  1  DEST:  16 42
# Task  1  completed at step  149
# TASK NUMBER  0  DEST:  16 26
# TASK NUMBER  1  DEST:  21 24
# Task  1  completed at step  2066
# TASK NUMBER  0  DEST:  32 9
# TASK NUMBER  1  DEST:  36 27
# Task  1  completed at step  240
# TASK NUMBER  0  DEST:  9 48
# TASK NUMBER  1  DEST:  26 12
# Task  1  completed at step  1803
# 28693.87881575798
# TASK NUMBER  0  DEST:  13 14
# TASK NUMBER  1  DEST:  15 11
# Task  1  completed at step  576
# Task  0  completed at step  665
# TASK NUMBER  0  DEST:  22 18
# TASK NUMBER  1  DEST:  33 32
# Task  1  completed at step  178
# TASK NUMBER  0  DEST:  32 38
# TASK NUMBER  1  DEST:  45 27
# TASK NUMBER  0  DEST:  11 42
# TASK NUMBER  1  DEST:  2 9
# TASK NUMBER  0  DEST:  18 32
# TASK NUMBER  1  DEST:  1 13
# TASK NUMBER  0  DEST:  8 24
# TASK NUMBER  1  DEST:  49 22
# TASK NUMBER  0  DEST:  35 27
# TASK NUMBER  1  DEST:  42 0
# Task  1  completed at step  121
# TASK NUMBER  0  DEST:  14 49
# TASK NUMBER  1  DEST:  43 8
# Task  1  completed at step  625
# TASK NUMBER  0  DEST:  36 12
# TASK NUMBER  1  DEST:  6 9
# TASK NUMBER  0  DEST:  40 36
# TASK NUMBER  1  DEST:  3 20
# TASK NUMBER  0  DEST:  25 32
# TASK NUMBER  1  DEST:  29 15
# Task  1  completed at step  59
# TASK NUMBER  0  DEST:  2 20
# TASK NUMBER  1  DEST:  23 28
# Task  1  completed at step  62
# TASK NUMBER  0  DEST:  15 39
# TASK NUMBER  1  DEST:  30 9
# Task  1  completed at step  89
# TASK NUMBER  0  DEST:  48 49
# TASK NUMBER  1  DEST:  47 9
# Task  1  completed at step  294
# TASK NUMBER  0  DEST:  3 38
# TASK NUMBER  1  DEST:  46 30
# TASK NUMBER  0  DEST:  22 48
# TASK NUMBER  1  DEST:  24 47
# Task  1  completed at step  311
# TASK NUMBER  0  DEST:  19 9
# TASK NUMBER  1  DEST:  44 5
# Task  0  completed at step  119
# Task  1  completed at step  666
# TASK NUMBER  0  DEST:  29 17
# TASK NUMBER  1  DEST:  26 5
# Task  1  completed at step  490
# TASK NUMBER  0  DEST:  38 0
# TASK NUMBER  1  DEST:  3 15
# TASK NUMBER  0  DEST:  17 37
# TASK NUMBER  1  DEST:  31 48
# Task  1  completed at step  156
# 33399.15793839424
# TASK NUMBER  0  DEST:  45 0
# TASK NUMBER  1  DEST:  29 48
# Task  1  completed at step  135
# TASK NUMBER  0  DEST:  35 6
# TASK NUMBER  1  DEST:  43 37
# Task  1  completed at step  146
# TASK NUMBER  0  DEST:  36 1
# TASK NUMBER  1  DEST:  7 47
# Task  1  completed at step  4398
# TASK NUMBER  0  DEST:  44 17
# TASK NUMBER  1  DEST:  8 29
# Task  1  completed at step  118
# TASK NUMBER  0  DEST:  28 26
# TASK NUMBER  1  DEST:  36 13
# Task  1  completed at step  361
# TASK NUMBER  0  DEST:  5 8
# TASK NUMBER  1  DEST:  39 16
# Task  1  completed at step  59
# TASK NUMBER  0  DEST:  28 48
# TASK NUMBER  1  DEST:  14 17
# Task  1  completed at step  59
# TASK NUMBER  0  DEST:  47 45
# TASK NUMBER  1  DEST:  48 37
# Task  0  completed at step  370
# TASK NUMBER  0  DEST:  24 13
# TASK NUMBER  1  DEST:  6 49
# Task  1  completed at step  546
# TASK NUMBER  0  DEST:  41 46
# TASK NUMBER  1  DEST:  31 26
# Task  1  completed at step  83
# TASK NUMBER  0  DEST:  23 38
# TASK NUMBER  1  DEST:  24 46
# Task  1  completed at step  291
# TASK NUMBER  0  DEST:  35 0
# TASK NUMBER  1  DEST:  8 33
# Task  1  completed at step  692
# TASK NUMBER  0  DEST:  14 40
# TASK NUMBER  1  DEST:  30 32
# Task  1  completed at step  700
# TASK NUMBER  0  DEST:  29 5
# TASK NUMBER  1  DEST:  21 48
# Task  1  completed at step  201
# TASK NUMBER  0  DEST:  1 30
# TASK NUMBER  1  DEST:  0 0
# TASK NUMBER  0  DEST:  16 41
# TASK NUMBER  1  DEST:  14 13
# Task  1  completed at step  195
# TASK NUMBER  0  DEST:  23 3
# TASK NUMBER  1  DEST:  45 41
# Task  1  completed at step  139
# TASK NUMBER  0  DEST:  11 48
# TASK NUMBER  1  DEST:  28 1
# Task  1  completed at step  55
# TASK NUMBER  0  DEST:  14 47
# TASK NUMBER  1  DEST:  12 8
# Task  1  completed at step  96
# TASK NUMBER  0  DEST:  7 14
# TASK NUMBER  1  DEST:  39 24
# Task  1  completed at step  62
# 43745.12080061297
# TASK NUMBER  0  DEST:  46 28
# TASK NUMBER  1  DEST:  15 14
# TASK NUMBER  0  DEST:  43 35
# TASK NUMBER  1  DEST:  38 27
# Task  1  completed at step  1569
# TASK NUMBER  0  DEST:  17 28
# TASK NUMBER  1  DEST:  17 18
# Task  1  completed at step  14
# TASK NUMBER  0  DEST:  34 11
# TASK NUMBER  1  DEST:  30 48
# Task  1  completed at step  80
# TASK NUMBER  0  DEST:  26 3
# TASK NUMBER  1  DEST:  20 25
# Task  1  completed at step  8
# TASK NUMBER  0  DEST:  36 47
# TASK NUMBER  1  DEST:  48 28
# Task  1  completed at step  116
# TASK NUMBER  0  DEST:  45 3
# TASK NUMBER  1  DEST:  21 24
# Task  1  completed at step  56
# TASK NUMBER  0  DEST:  49 16
# TASK NUMBER  1  DEST:  39 2
# Task  1  completed at step  51
# TASK NUMBER  0  DEST:  21 47
# TASK NUMBER  1  DEST:  23 13
# Task  1  completed at step  60
# TASK NUMBER  0  DEST:  3 14
# TASK NUMBER  1  DEST:  21 47
# Task  1  completed at step  42
# TASK NUMBER  0  DEST:  9 38
# TASK NUMBER  1  DEST:  24 11
# Task  1  completed at step  52
# TASK NUMBER  0  DEST:  22 13
# TASK NUMBER  1  DEST:  36 46
# Task  1  completed at step  275
# TASK NUMBER  0  DEST:  26 42
# TASK NUMBER  1  DEST:  24 42
# Task  1  completed at step  195
# Task  0  completed at step  4835
# TASK NUMBER  0  DEST:  26 46
# TASK NUMBER  1  DEST:  29 43
# Task  1  completed at step  1213
# Task  0  completed at step  3463
# TASK NUMBER  0  DEST:  14 9
# TASK NUMBER  1  DEST:  35 13
# Task  1  completed at step  223
# TASK NUMBER  0  DEST:  10 42
# TASK NUMBER  1  DEST:  3 20
# TASK NUMBER  0  DEST:  3 8
# TASK NUMBER  1  DEST:  25 44
# Task  1  completed at step  99
# TASK NUMBER  0  DEST:  9 39
# TASK NUMBER  1  DEST:  20 18
# Task  0  completed at step  9
# Task  1  completed at step  129
# TASK NUMBER  0  DEST:  49 37
# TASK NUMBER  1  DEST:  26 27
# Task  1  completed at step  206
# TASK NUMBER  0  DEST:  7 43
# TASK NUMBER  1  DEST:  11 12
# Task  1  completed at step  37
# 45951.71931418193
# TASK NUMBER  0  DEST:  34 17
# TASK NUMBER  1  DEST:  36 49
# Task  1  completed at step  66
# TASK NUMBER  0  DEST:  37 40
# TASK NUMBER  1  DEST:  29 1
# TASK NUMBER  0  DEST:  6 17
# TASK NUMBER  1  DEST:  44 46
# Task  1  completed at step  75
# TASK NUMBER  0  DEST:  1 31
# TASK NUMBER  1  DEST:  14 1
# Task  1  completed at step  43
# TASK NUMBER  0  DEST:  15 30
# TASK NUMBER  1  DEST:  48 16
