# %% [markdown]
# https://github.com/jiechuanjiang/pytorch_DGN/blob/main/Surviving/DGN%2BATOC/config.py

# %%
import numpy as np
np.random.seed(14)
import math, random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd 
import torch.nn.functional as F
import copy
import os,sys
from torch.utils import tensorboard as tb

# %%
# hidden_dim = 64
# max_step = 5000 #originally 500
# GAMMA = 0.99
# n_episode = 1000 #originally 800
# i_episode = 0
# buffer_size = 65000 #change back to 65000
# batch_size = 64 #change back to 64
# n_epoch = 100 #orginally 25
# epsilon = 0.7 #originally 0.9
# score = 0
# tau = 0.98

GRID_DIM = 50 # TODO: Tune this
NUM_TASKS = 2 # TODO: Tune this
ADJ_THRESHOLD = GRID_DIM / 4 # TODO: Tune this
USE_CUDA = torch.cuda.is_available()
Variable = lambda *args, **kwargs: autograd.Variable(*args, **kwargs).cuda() if USE_CUDA else autograd.Variable(*args, **kwargs)

def is_legal(x,y):
    return (x>=0)&(x<GRID_DIM)&(y>=0)&(y<=GRID_DIM)

# %% [markdown]
# https://github.com/jiechuanjiang/pytorch_DGN/blob/main/Surviving/DGN%2BATOC/buffer.py

# %%
class ReplayBufferGCare(object):
    """
    Replay buffer for storing the agent's experiences
    """

    def __init__(self, buffer_size, obs_space, n_action, n_tasks):
        """
        Initialize the replay buffer
        
        Params:
        buffer_size:
        obs_space:
        n_action:
        n_tasks:
        """
        self.buffer_size = buffer_size
        self.n_tasks = n_tasks
        self.pointer = 0
        self.len = 0
        self.actions = np.zeros((self.buffer_size,1),dtype = np.int32)
        self.rewards = np.zeros((self.buffer_size, 1))
        self.dones = np.zeros((self.buffer_size,1))
        self.obs = np.zeros((self.buffer_size,n_tasks,obs_space))
        self.next_obs = np.zeros((self.buffer_size,n_tasks,obs_space))
        self.matrix = np.zeros((self.buffer_size,self.n_tasks,self.n_tasks))
        self.next_matrix = np.zeros((self.buffer_size,self.n_tasks,self.n_tasks))

    def getBatch(self, batch_size):
        """
        Sample a batch of random entries from the replay buffer
        
        Params:
        batch_size:
        
        Returns:
        obs:
        action:
        reward
        next_obs:
        matrix:
        next_matrix:
        done:
        """
        index = np.random.choice(self.len, batch_size, replace=False)
        return self.obs[index], self.actions[index], self.rewards[index], self.next_obs[index], self.matrix[index], self.next_matrix[index], self.dones[index]

    def add(self, obs, action, reward, next_obs, matrix, next_matrix, done):
        """
        Add to the replay buffer
        
        Params:
        obs:
        action:
        reward:
        next_obs:
        matrix:
        next_matrix:
        done:
        """
        self.obs[self.pointer] = obs
        self.actions[self.pointer] = action
        self.rewards[self.pointer] = reward
        self.next_obs[self.pointer] = next_obs
        self.matrix[self.pointer] = matrix
        self.next_matrix[self.pointer] = next_matrix
        self.dones[self.pointer] = done
        self.pointer = (self.pointer + 1)%self.buffer_size
        self.len = min(self.len + 1, self.buffer_size)

# %% [markdown]
# https://github.com/jiechuanjiang/pytorch_DGN/blob/main/Surviving/DGN%2BATOC/model.py

# %%
class MTRL_ATT(nn.Module):
    """
    """
    def __init__(self, din):
        super(MTRL_ATT, self).__init__()
        self.fc1 = nn.Linear(din, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, 1)

    def forward(self, x):
        y = F.relu(self.fc1(x))
        y = F.relu(self.fc2(y))
        y = F.sigmoid(self.fc3(y))
        return y

class MTRL_Encoder(nn.Module): # TODO: Need to make it a CNN for higher dim obs space like MetaWorld
    """
    """
    def __init__(self, din=32, hidden_dim=128):
        super(MTRL_Encoder, self).__init__()
        self.fc = nn.Linear(din, hidden_dim)


    def forward(self, x):
        embedding = F.tanh(self.fc(x))
        return embedding

class MTRL_AttModel(nn.Module):
    """
    """
    def __init__(self, n_node, din, hidden_dim, dout):
        super(MTRL_AttModel, self).__init__()
        self.fcv = nn.Linear(din, hidden_dim)
        self.fck = nn.Linear(din, hidden_dim)
        self.fcq = nn.Linear(din, hidden_dim)
        self.fcout = nn.Linear(hidden_dim, dout)

    def forward(self, x, mask):
        v = F.tanh(self.fcv(x))
        q = F.tanh(self.fcq(x))
        k = F.tanh(self.fck(x)).permute(0,2,1)
        att = F.softmax(torch.mul(torch.bmm(q,k), mask) - 9e15*(1 - mask),dim=2)
        # Note: Order of applying adj matrix is different than that in paper. Don't get confused!
        out = torch.bmm(att,v)
        return out

class MTRL_Q_Net(nn.Module):
    """
    """
    def __init__(self, hidden_dim, dout):
        super(MTRL_Q_Net, self).__init__()
        # NOTE: This is now modified to have both h vectors from both of the attention layers
        # concatenated - originally it was only getting the h vector of the last layer
        # so the input dim of the linear layer was hidden_dim
        self.fc = nn.Linear(hidden_dim*2, dout)

    def forward(self, x):
        q = F.relu(self.fc(x))
        return q

    
class MTRL_DGN(nn.Module):
    """
    """
    def __init__(self,n_tasks,num_inputs,hidden_dim,num_actions):
        super(MTRL_DGN, self).__init__()

        self.encoder = MTRL_Encoder(num_inputs,hidden_dim)
        # TODO: Try both single encoder and mix of encoder settings
        # Will remain same for MTRL
        self.att_1 = MTRL_AttModel(n_tasks,hidden_dim,hidden_dim,hidden_dim)
        self.att_2 = MTRL_AttModel(n_tasks,hidden_dim,hidden_dim,hidden_dim)
        self.q_net = MTRL_Q_Net(hidden_dim,num_actions)
        # Q Net remains same for MTRL

    def forward(self, x, mask):
        h1 = self.encoder(x)
        h2 = self.att_1(h1, mask)
        h3 = self.att_2(h2, mask) 
        # TODO: try concatentation for MTRL
        
        h4 = torch.cat((h2,h3),dim=2)
        q = self.q_net(h4)
        # Note: No concatenation done. Output of last attention head used directly
        # Note: 2 attention heads used
        return q

# %% [markdown]
# https://github.com/jiechuanjiang/pytorch_DGN/blob/main/Surviving/DGN%2BATOC/surviving.py

# %%
class GridWorldWithCare(object):
    
    def __init__(self, n_tasks):
        """
        Initialize the gridworld
        
        Params:
        n_tasks:
        """
        super(GridWorldWithCare, self).__init__()
        self.n_action = 4
        self.n_tasks = n_tasks
        # TODO: maybe include food as part of task, reach dest with > 0 food or something
        self.tasks = [0]*self.n_tasks
        self.agent = [-1, -1]
        self.build_env()

        self.dones = np.zeros(self.n_tasks) # Array to indicate whether each task is done or not -- used to calculate rewards
        self.steps = 0
        self.len_obs = (self.n_tasks+1)*2

    def reset(self):
        """
        Reset the gridworld
        
        Returns:
        obs:
        adj:
        """

        self.build_env()
        self.dones = np.zeros(self.n_tasks)
        self.steps = 0
        return self.get_obs(), self.get_adj()

    def build_env(self):
        """
        Build the gridworld
        """
        for i in range(self.n_tasks):
            x = np.random.randint(0, GRID_DIM)
            y = np.random.randint(0, GRID_DIM)
            self.tasks[i] = [x, y]
            print("TASK NUMBER ", i, " DEST: ", x, y)
        self.agent[0] = np.random.randint(0, GRID_DIM)
        self.agent[1] = np.random.randint(0, GRID_DIM)

    def get_obs(self):
        """
        Get observations
        
        Returns:
        obs:
        """
        # TODO: change this for MTRL 
        obs = []
        
        x_agent = self.agent[0]
        y_agent = self.agent[1]

        obs.append(x_agent/GRID_DIM)
        obs.append(y_agent/GRID_DIM)

        # 		for i in range(-1,2):
        # 			for j in range(-1,2):
        # 				obs.append(self.maze[x_agent+i][y_agent+j])

        for i in range(self.n_tasks):
            obs.append((self.tasks[i][0]-x_agent)/GRID_DIM)
            obs.append((self.tasks[i][1]-y_agent)/GRID_DIM)

        # TODO: 1. if we include maze state or not, and if we do, we would need to figure out
        # how to effectively send that along with task destinations
        
        #Idea: use distance between agent and task as obs
        
        return obs

    def get_adj(self): # TODO: Change this to use task description encoding. 
        # In this case task description is the location of the destination.
        """
        Get adjacency matrix
        
        Returns:
        adj:
        """
        adj = np.zeros((self.n_tasks, self.n_tasks))

        # Calculate adjacency regarding to the distances of the tasks respect to the agent
        x_agent, y_agent = self.agent[0], self.agent[1]

        # HARD ATTENTION
        # Traverse through the tasks and calculate the Euclidean distance between them and the agent
#         for i in range(self.n_tasks):
#             x_task_i, y_task_i = self.tasks[i][0] - x_agent, self.tasks[i][1] - y_agent
#             for j in range(self.n_tasks):
#                 x_task_j, y_task_j = self.tasks[j][0] - x_agent, self.tasks[j][1] - y_agent
#                 task_dist = math.sqrt((x_task_j - x_task_i)**2 + (y_task_i - y_task_j)**2)
#                 if task_dist <= ADJ_THRESHOLD:
#                     adj[i,j] = 1
#                     adj[j,i] = 1
                    
        # SOFT ATTENTION
#         adj = np.ones((self.n_tasks, self.n_tasks)) # NOTE: 
        for i in range(self.n_tasks):
            x_task_i, y_task_i = self.tasks[i][0]-x_agent, self.tasks[i][1]-y_agent
            for j in range(self.n_tasks):
                x_task_j, y_task_j = self.tasks[j][0]-x_agent, self.tasks[j][1]-y_agent
                # Instead of having 1 or 0s, have their vectoral positions according to each other
                task_dist = math.sqrt((x_task_j - x_task_i)**2 + (y_task_j - y_task_i)**2)
                
#                 print('x_task_i: {}, y_task_i: {}, x_task_j: {}, y_task_j: {}, task_dist: {}'.format(
#                         x_task_i, y_task_i, x_task_j, y_task_j, task_dist
#                 ))
                
                # Set this distance / GRID_DIM
                adj[i,j] = 1 - float(task_dist)/GRID_DIM # Extract from 1 bc the closer the better
                adj[j,i] = 1 - float(task_dist)/GRID_DIM
                
        
                
#         print("ADJACENCY: {}".format(adj))

#         print('x_agent: {}, y_agent: {}'.format(x_agent, y_agent))

        return adj



    def step(self, action):
        """
        Take one step in the gridworld according to the given actions
        
        Params:
        action:
        
        Returns:
        obs:
        adj:
        reward:
        all_tasks_done:
        """

        # There are 4 different actions for the agent
        # If there is any place to go in the maze then the agent will go 
        # 0: Move up, 1: Move down, 2: Move left, 3: Move right

        self.steps += 1
        x_agent, y_agent = self.agent[0], self.agent[1]
#         print("AGENT LOCATION: ", agent_x, agent_y)
#         print("ACTION: ", action)
        if action == 0: # Move up (decrease x by one)
            if is_legal(x_agent-1, y_agent):
                # Change the agent and the maze
                self.agent[0] -= 1

        elif action == 1: # Move down (increase x by one)
            if is_legal(x_agent+1, y_agent):
                # Change the agent and the maze
                self.agent[0] += 1

        elif action == 2: # Move left (decrease y by one)
            if is_legal(x_agent, y_agent-1):
                # Change the agent and the maze
                self.agent[1] -= 1

        elif action == 3: # Move right (increase y by one)
            if is_legal(x_agent, y_agent+1):
                # Change the agent and the maze
                self.agent[1] += 1
                
        # Calculate the rewards for each task
        rewards = [0] * self.n_tasks
        total_reward = 0

        # Check if you reached to any destinations here
        new_agent_x, new_agent_y = self.agent[0], self.agent[1]
        for i in range(self.n_tasks):
            if self.tasks[i][0] == new_agent_x and self.tasks[i][1] == new_agent_y:
                if self.dones[i] == 0:
                    self.dones[i] = 1
                    rewards[i] = 1
                    total_reward += 1
                    print("Task ", i, " completed at step ", self.steps)
            else:
                total_reward += 1.0/float((math.sqrt((self.tasks[i][0]-new_agent_x)**2 + (self.tasks[i][1]-new_agent_y)**2)))
                

        # Only if all the tasks are done, then the episode is done
        all_tasks_done = not (0 in self.dones)



        return self.get_obs(), self.get_adj(), total_reward, all_tasks_done

# %%
# Class for making the training with different set of hyper parameters
class Training:
    """
    This class trains the model and holds the highest scores and the hyper parameter combination that gave us that
    highest score. 
    Prints tryout_index -> highest_score_in_that_tryout for each tryout to the file
    
    params:
    test_results_file: name of the file to hold the results
    vizier: boolean to indicate whether to do hyper parameter search
    """
    def __init__(self, file_name, vizier=False): # vizier indicates whether to do hyper param research
        self.file_name = file_name
        self.file = open(file_name, "w+")
        self.vizier = vizier # if vizier is true then the class makes 

        if self.vizier:

            # Dictionary to give us all options for hyper parameters
            self.hyper_params = {
                'hidden_dim': [64, 128], # 2
                'max_step': [10000], # 1
                'gamma': [0.99], # 1
                'n_episode': [1000], # 1
                'buffer_size': [65000, 100000, 10000000], # 3
                'batch_size': [128], # 1
                'n_epoch': [75, 150] # 2
                'epsilon': [0.5, 0.7, 0.9], # 3
                'tau': [0.75, 0.95], # 2
                'learning_rate': [0.0005, 0.001, 0.005] # 3
            }

            self.tryouts = []
            for key, value in self.hyper_params.items():
                tryouts_len = len(self.tryouts)
                if tryouts_len == 0:
                    for param in value:
                        self.tryouts.append({key : param})

                else:
                    params_len = len(value)
                    for i in range(params_len-1):
                        for j in range(tryouts_len):
                            self.tryouts.append(copy.deepcopy(self.tryouts[j]))

                    for j in range(params_len):
                        for i in range(tryouts_len):
                            self.tryouts[j*tryouts_len+i][key] = value[j]

            print('len(tryouts): {}'.format(len(self.tryouts)))
            self.num_tryout = len(self.tryouts)
            self.highest_scores = [0] * self.num_tryout # This will hold the highest score in each try out
            
        else: 
            
            self.hidden_dim = 64
            self.max_step = 5000 #originally 500
            self.gamma = 0.99
            self.n_episode = 1000 #originally 800
            self.buffer_size = 65000 #change back to 65000
            self.batch_size = 64 #change back to 64
            self.n_epoch = 100 #orginally 25
            self.epsilon = 0.7 #originally 0.9
            self.tau = 0.98
            self.learning_rate = 0.001
            
            self.num_tryout = 1
        
            
    def train(self):
        env = GridWorldWithCare(NUM_TASKS)
        observation_space = env.len_obs
        n_actions = env.n_action
        n_tasks = env.n_tasks
        
        # Set the hyper parameters 
        for tryout_index in range(self.num_tryout):
            if self.vizier:
                self.hidden_dim = self.tryouts[tryout_index]['hidden_dim']
                self.max_step = self.tryouts[tryout_index]['max_step']
                self.gamma = self.tryouts[tryout_index]['gamma']
                self.n_episode = self.tryouts[tryout_index]['n_episode']
                self.buffer_size = self.tryouts[tryout_index]['buffer_size']
                self.batch_size = self.tryouts[tryout_index]['batch_size']
                self.n_epoch = self.tryouts[tryout_index]['n_epoch']
                self.epsilon = self.tryouts[tryout_index]['epsilon']
                self.tau = self.tryouts[tryout_index]['tau']
                self.learning_rate = self.tryouts[tryout_index]['learning_rate']
                
            print('-------\nTRYOUT[{}]: (hidden_dim={}, max_step={}, gamma={}, n_episode={}, buffer_size={}, batch_size={}, n_epoch={}, epsilon={}, tau={}, learning_rate={})'.format(
                tryout_index, self.hidden_dim, self.max_step, self.gamma, self.n_episode, self.buffer_size, self.batch_size, self.n_epoch, self.epsilon, self.tau, self.learning_rate
            ))
                
                
            buff = ReplayBufferGCare(self.buffer_size, observation_space, n_actions, n_tasks)
            model = MTRL_DGN(n_tasks, observation_space, self.hidden_dim, n_actions).cuda()
            model_tar = MTRL_DGN(n_tasks, observation_space, self.hidden_dim, n_actions).cuda()
            optimizer = optim.Adam(model.parameters(), lr = self.learning_rate)
            criterion = nn.BCELoss()
            
            M_Null = torch.Tensor(np.array([np.eye(n_tasks)] * self.batch_size)).cuda()
            M_ZERO = torch.Tensor(np.zeros((self.batch_size, n_tasks, n_tasks))).cuda()
        
            i_episode = 0
            score = 0
            
            while i_episode < self.n_episode:
                if i_episode > 40:
                    self.epsilon -= 0.001
                    if self.epsilon < 0.01:
                        self.epsilon = 0.01
                i_episode+=1
                steps = 0
                obs, adj = env.reset()
                obs = np.resize(obs, (n_tasks, observation_space))
                
                if not self.vizier:
                    log_file_name = self.file_name+str(i)+"Episode
                    episode_summary_writer = tb.SummaryWriter(log_dir='./TB-Logs/'+log_file_name)
                    episode_epoch_count = 0
                
                while steps < self.max_step:
                    steps+=1 
                    # Get the action with forward prop and add the obs, adjs to replay buffer
                    q = model(torch.Tensor(np.array([obs])).cuda(), torch.Tensor(np.array([adj])).cuda())[0,0,:]
                    if np.random.rand() < self.epsilon:
                        action = np.random.randint(n_actions)
                    else:
                        action = q.argmax().item()
                    next_obs, next_adj, reward, terminated = env.step(action)
                    next_obs = np.resize(next_obs, (n_tasks, observation_space))
                    buff.add(np.array(obs),action,reward,np.array(next_obs),adj,next_adj,terminated)

                    obs = next_obs
                    adj = next_adj
                    score += reward

                if i_episode%20==0:
                    print(score)
                    episode_summary_writer.add_scalar("Score/Episode", score, i_episode)
                    if score > self.highest_scores[tryout_index]:
                        self.highest_scores[tryout_index] = score
                    score = 0
                
                # Train the model
                for e in range(self.n_epoch):
                    O,A,R,Next_O,Matrix,Next_Matrix,D = buff.getBatch(self.batch_size)
                    O = torch.Tensor(O).cuda()
                    Matrix = torch.Tensor(Matrix).cuda()
                    Next_O = torch.Tensor(Next_O).cuda()
                    Next_Matrix = torch.Tensor(Next_Matrix).cuda()

                    q_values = model(O, Matrix)
                    q_values = model(O, Matrix)[:,0, :]
                    target_q_values = model_tar(Next_O, Next_Matrix).max(dim = 2)[0][:,0]
                    target_q_values = np.array(target_q_values.cpu().data)
                    expected_q = np.array(q_values.cpu().data)

                    for j in range(self.batch_size):
                        expected_q[j][A[j][0]] = R[j][0] + (1-D[j][0])*self.gamma*target_q_values[j]

                    loss = (q_values - torch.Tensor(expected_q).cuda()).pow(2).mean()
                    episode_summary_writer.add_scalar('Loss', loss, episode_epoch_count)
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                    if e%10 == 0:
                        with torch.no_grad():
                            for p, p_targ in zip(model.parameters(), model_tar.parameters()):
                                p_targ.data.mul_(self.tau)
                                p_targ.data.add_((1 - self.tau) * p.data)
    
            # Print the highest score to the file
            self.file.write('Tryout[{}]: (hidden_dim={}, max_step={}, gamma={}, n_episode={}, buffer_size={}, batch_size={}, n_epoch={}, epsilon={}, tau={}, learning_rate={}): \t ---> \t Highest Score: {}\n'.format(
                tryout_index, self.hidden_dim, self.max_step, self.gamma, self.n_episode, self.buffer_size, self.batch_size, self.n_epoch, self.epsilon, self.tau, self.learning_rate, self.highest_scores[tryout_index]
            ))
            
            self.file.flush()

# %%
training = Training('VIZIER_OUTPUT.txt', True)
training.train()
# Out:
# len(tryouts): 104976
# TASK NUMBER  0  DEST:  36 24
# TASK NUMBER  1  DEST:  27 4
# -------
# TRYOUT[0]: (hidden_dim=32, max_step=500, gamma=0.99, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  5 26
# TASK NUMBER  1  DEST:  28 12
# 10.798059814414934
# TASK NUMBER  0  DEST:  33 48
# TASK NUMBER  1  DEST:  41 24
# 7.736252950302205
# TASK NUMBER  0  DEST:  16 48
# TASK NUMBER  1  DEST:  5 4
# 18.924235715113483
# TASK NUMBER  0  DEST:  31 33
# TASK NUMBER  1  DEST:  30 18
# 9.222761257257707
# TASK NUMBER  0  DEST:  22 39
# TASK NUMBER  1  DEST:  6 30
# 13.937725752974556
# TASK NUMBER  0  DEST:  19 7
# TASK NUMBER  1  DEST:  36 6
# 14.771769176326092
# TASK NUMBER  0  DEST:  30 15
# TASK NUMBER  1  DEST:  1 44
# 7.430241715576467
# TASK NUMBER  0  DEST:  29 39
# TASK NUMBER  1  DEST:  7 28
# 7.693890422074836
# TASK NUMBER  0  DEST:  47 36
# TASK NUMBER  1  DEST:  22 49
# 19.410906983987868
# TASK NUMBER  0  DEST:  12 29
# TASK NUMBER  1  DEST:  31 41
# 26.538937668662115
# -------
# TRYOUT[1]: (hidden_dim=64, max_step=500, gamma=0.99, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  37 40
# TASK NUMBER  1  DEST:  32 18
# 8.427239570257463
# TASK NUMBER  0  DEST:  1 22
# TASK NUMBER  1  DEST:  36 43
# 12.820347832059937
# TASK NUMBER  0  DEST:  24 49
# TASK NUMBER  1  DEST:  22 42
# 9.224105549337104
# TASK NUMBER  0  DEST:  39 34
# TASK NUMBER  1  DEST:  0 8
# 9.818383604428096
# TASK NUMBER  0  DEST:  0 3
# TASK NUMBER  1  DEST:  29 45
# 10.691760577628667
# TASK NUMBER  0  DEST:  45 23
# TASK NUMBER  1  DEST:  30 48
# 23.93368551693356
# TASK NUMBER  0  DEST:  13 42
# TASK NUMBER  1  DEST:  29 6
# 12.688290180821804
# TASK NUMBER  0  DEST:  18 43
# TASK NUMBER  1  DEST:  12 45
# 35.88143478794751
# TASK NUMBER  0  DEST:  17 38
# TASK NUMBER  1  DEST:  1 0
# 7.284341477210201
# TASK NUMBER  0  DEST:  23 24
# TASK NUMBER  1  DEST:  47 33
# 8.164785057723313
# -------
# TRYOUT[2]: (hidden_dim=128, max_step=500, gamma=0.99, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  31 41
# TASK NUMBER  1  DEST:  28 49
# 6.63340446955345
# TASK NUMBER  0  DEST:  20 30
# TASK NUMBER  1  DEST:  2 28
# 6.857257272688222
# TASK NUMBER  0  DEST:  40 14
# TASK NUMBER  1  DEST:  28 1
# Task  0  completed at step  14
# 28.181203396539836
# TASK NUMBER  0  DEST:  39 34
# TASK NUMBER  1  DEST:  47 5
# Task  1  completed at step  63
# 52.415903137771856
# TASK NUMBER  0  DEST:  46 6
# TASK NUMBER  1  DEST:  40 32
# 33.01008972710844
# TASK NUMBER  0  DEST:  34 23
# TASK NUMBER  1  DEST:  15 40
# 7.929610158155095
# TASK NUMBER  0  DEST:  49 10
# TASK NUMBER  1  DEST:  17 45
# 10.01181155745225
# TASK NUMBER  0  DEST:  40 36
# TASK NUMBER  1  DEST:  31 15
# 14.134058997900647
# TASK NUMBER  0  DEST:  47 25
# TASK NUMBER  1  DEST:  31 6
# 22.67193027245601
# TASK NUMBER  0  DEST:  45 23
# TASK NUMBER  1  DEST:  32 10
# 5.502675938353687
# -------
# TRYOUT[3]: (hidden_dim=32, max_step=1000, gamma=0.99, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  17 5
# TASK NUMBER  1  DEST:  9 12
# 7.264991632223761
# TASK NUMBER  0  DEST:  13 11
# TASK NUMBER  1  DEST:  17 44
# 13.028508584220377
# TASK NUMBER  0  DEST:  11 18
# TASK NUMBER  1  DEST:  39 18
# Task  0  completed at step  11
# 26.051690226274307
# TASK NUMBER  0  DEST:  25 25
# TASK NUMBER  1  DEST:  14 6
# 12.524338088312925
# TASK NUMBER  0  DEST:  45 15
# TASK NUMBER  1  DEST:  18 26
# 7.443763749336228
# TASK NUMBER  0  DEST:  48 12
# TASK NUMBER  1  DEST:  14 45
# 6.931530149049226
# TASK NUMBER  0  DEST:  8 41
# TASK NUMBER  1  DEST:  3 35
# 32.216356533176864
# TASK NUMBER  0  DEST:  19 23
# TASK NUMBER  1  DEST:  24 1
# 15.080047730859736
# TASK NUMBER  0  DEST:  23 30
# TASK NUMBER  1  DEST:  0 47
# 6.793063937475232
# TASK NUMBER  0  DEST:  14 11
# TASK NUMBER  1  DEST:  8 7
# 11.132437426692302
# -------
# TRYOUT[4]: (hidden_dim=64, max_step=1000, gamma=0.99, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  5 2
# TASK NUMBER  1  DEST:  41 39
# 8.5766363255674
# TASK NUMBER  0  DEST:  20 36
# TASK NUMBER  1  DEST:  29 12
# 10.876432998552755
# TASK NUMBER  0  DEST:  30 44
# TASK NUMBER  1  DEST:  37 39
# 19.54172987915027
# TASK NUMBER  0  DEST:  20 40
# TASK NUMBER  1  DEST:  26 0
# 9.383986631628657
# TASK NUMBER  0  DEST:  26 41
# TASK NUMBER  1  DEST:  3 40
# 6.695995549308991
# TASK NUMBER  0  DEST:  22 36
# TASK NUMBER  1  DEST:  39 38
# 20.910787728331563
# TASK NUMBER  0  DEST:  6 30
# TASK NUMBER  1  DEST:  32 10
# 10.734273617610734
# TASK NUMBER  0  DEST:  23 38
# TASK NUMBER  1  DEST:  12 33
# 14.61958800731852
# TASK NUMBER  0  DEST:  24 17
# TASK NUMBER  1  DEST:  35 38
# Task  0  completed at step  20
# 25.45180464928113
# TASK NUMBER  0  DEST:  34 31
# TASK NUMBER  1  DEST:  10 34
# 9.966820537868335
# -------
# TRYOUT[5]: (hidden_dim=128, max_step=1000, gamma=0.99, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  17 23
# TASK NUMBER  1  DEST:  29 22
# 8.11838355206734
# TASK NUMBER  0  DEST:  47 25
# TASK NUMBER  1  DEST:  33 22
# 8.78196032971475
# TASK NUMBER  0  DEST:  20 5
# TASK NUMBER  1  DEST:  11 20
# 13.160518994251728
# TASK NUMBER  0  DEST:  37 15
# TASK NUMBER  1  DEST:  39 10
# 5.8358557398816515
# TASK NUMBER  0  DEST:  30 17
# TASK NUMBER  1  DEST:  27 23
# 12.434693816001634
# TASK NUMBER  0  DEST:  22 41
# TASK NUMBER  1  DEST:  20 26
# 14.45987755612634
# TASK NUMBER  0  DEST:  35 41
# TASK NUMBER  1  DEST:  19 36
# 16.631106987676986
# TASK NUMBER  0  DEST:  29 47
# TASK NUMBER  1  DEST:  21 25
# 6.85565871541434
# TASK NUMBER  0  DEST:  10 7
# TASK NUMBER  1  DEST:  18 26
# 12.417564851763217
# TASK NUMBER  0  DEST:  35 22
# TASK NUMBER  1  DEST:  23 39
# 9.438104837310247
# -------
# TRYOUT[6]: (hidden_dim=32, max_step=5000, gamma=0.99, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  24 5
# TASK NUMBER  1  DEST:  3 12
# 6.0011722294558565
# TASK NUMBER  0  DEST:  49 1
# TASK NUMBER  1  DEST:  0 32
# 12.168464538946383
# TASK NUMBER  0  DEST:  11 45
# TASK NUMBER  1  DEST:  27 43
# 5.910731980119603
# TASK NUMBER  0  DEST:  14 29
# TASK NUMBER  1  DEST:  28 26
# 26.346323092252604
# TASK NUMBER  0  DEST:  4 12
# TASK NUMBER  1  DEST:  30 36
# 10.012244397473406
# TASK NUMBER  0  DEST:  36 21
# TASK NUMBER  1  DEST:  42 43
# 13.22899399755181
# TASK NUMBER  0  DEST:  41 10
# TASK NUMBER  1  DEST:  6 39
# 12.819081115595337
# TASK NUMBER  0  DEST:  23 24
# TASK NUMBER  1  DEST:  37 0
# 9.877699944093996
# TASK NUMBER  0  DEST:  19 47
# TASK NUMBER  1  DEST:  4 18
# 19.709786804672195
# TASK NUMBER  0  DEST:  48 29
# TASK NUMBER  1  DEST:  26 39
# 17.788774888936835
# -------
# TRYOUT[7]: (hidden_dim=64, max_step=5000, gamma=0.99, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  11 26
# TASK NUMBER  1  DEST:  3 11
# 5.736274453225928
# TASK NUMBER  0  DEST:  19 30
# TASK NUMBER  1  DEST:  15 41
# 7.670097244778549
# TASK NUMBER  0  DEST:  29 8
# TASK NUMBER  1  DEST:  47 32
# 17.35047253660381
# TASK NUMBER  0  DEST:  48 35
# TASK NUMBER  1  DEST:  35 49
# 11.097370703984193
# TASK NUMBER  0  DEST:  12 34
# TASK NUMBER  1  DEST:  6 29
# 13.928212335735997
# TASK NUMBER  0  DEST:  0 13
# TASK NUMBER  1  DEST:  1 17
# 7.810565919223378
# TASK NUMBER  0  DEST:  38 21
# TASK NUMBER  1  DEST:  44 31
# 23.937165589740037
# TASK NUMBER  0  DEST:  48 38
# TASK NUMBER  1  DEST:  12 23
# 15.061157158250483
# TASK NUMBER  0  DEST:  49 1
# TASK NUMBER  1  DEST:  27 1
# 6.183476256922501
# TASK NUMBER  0  DEST:  27 25
# TASK NUMBER  1  DEST:  2 38
# Task  0  completed at step  15
# 28.03511418682824
# -------
# TRYOUT[8]: (hidden_dim=128, max_step=5000, gamma=0.99, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  35 12
# TASK NUMBER  1  DEST:  17 21
# 11.92164172114011
# TASK NUMBER  0  DEST:  22 24
# TASK NUMBER  1  DEST:  27 46
# 15.10440137253635
# TASK NUMBER  0  DEST:  42 6
# TASK NUMBER  1  DEST:  37 8
# 7.416260614394216
# TASK NUMBER  0  DEST:  41 41
# TASK NUMBER  1  DEST:  6 13
# 7.819485124607167
# TASK NUMBER  0  DEST:  22 25
# TASK NUMBER  1  DEST:  20 34
# Task  0  completed at step  57
# 28.40214784503535
# TASK NUMBER  0  DEST:  3 15
# TASK NUMBER  1  DEST:  49 19
# 17.782958504894243
# TASK NUMBER  0  DEST:  38 11
# TASK NUMBER  1  DEST:  37 35
# 14.120024327235349
# TASK NUMBER  0  DEST:  9 12
# TASK NUMBER  1  DEST:  39 21
# 28.08103104665062
# TASK NUMBER  0  DEST:  23 12
# TASK NUMBER  1  DEST:  5 10
# 11.072118042642707
# TASK NUMBER  0  DEST:  0 32
# TASK NUMBER  1  DEST:  5 11
# 7.400956404482855
# -------
# TRYOUT[9]: (hidden_dim=32, max_step=10000, gamma=0.99, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  17 36
# TASK NUMBER  1  DEST:  27 21
# 7.937045840450337
# TASK NUMBER  0  DEST:  12 2
# TASK NUMBER  1  DEST:  34 22
# 8.807365145655956
# TASK NUMBER  0  DEST:  24 1
# TASK NUMBER  1  DEST:  10 47
# 8.68409066157631
# TASK NUMBER  0  DEST:  18 33
# TASK NUMBER  1  DEST:  29 37
# 32.73556375749102
# TASK NUMBER  0  DEST:  5 32
# TASK NUMBER  1  DEST:  36 25
# 15.093109716863092
# TASK NUMBER  0  DEST:  2 10
# TASK NUMBER  1  DEST:  49 10
# 12.513019612736606
# TASK NUMBER  0  DEST:  15 37
# TASK NUMBER  1  DEST:  19 35
# 7.580993699257421
# TASK NUMBER  0  DEST:  26 26
# TASK NUMBER  1  DEST:  30 48
# 11.69750399760186
# TASK NUMBER  0  DEST:  39 14
# TASK NUMBER  1  DEST:  45 38
# 25.138035081479114
# TASK NUMBER  0  DEST:  42 42
# TASK NUMBER  1  DEST:  28 39
# 13.074559569858874
# -------
# TRYOUT[10]: (hidden_dim=64, max_step=10000, gamma=0.99, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  13 18
# TASK NUMBER  1  DEST:  35 4
# 18.632212329395653
# TASK NUMBER  0  DEST:  45 40
# TASK NUMBER  1  DEST:  22 38
# 6.131196039261547
# TASK NUMBER  0  DEST:  38 5
# TASK NUMBER  1  DEST:  21 12
# 21.385959179393257
# TASK NUMBER  0  DEST:  28 27
# TASK NUMBER  1  DEST:  49 3
# 14.30678564308187
# TASK NUMBER  0  DEST:  22 27
# TASK NUMBER  1  DEST:  13 33
# 8.465461993675177
# TASK NUMBER  0  DEST:  10 42
# TASK NUMBER  1  DEST:  4 12
# 11.943803356026313
# TASK NUMBER  0  DEST:  27 33
# TASK NUMBER  1  DEST:  17 43
# 8.102179275574205
# TASK NUMBER  0  DEST:  29 10
# TASK NUMBER  1  DEST:  47 8
# Task  1  completed at step  65
# 27.962792929406483
# TASK NUMBER  0  DEST:  21 41
# TASK NUMBER  1  DEST:  26 6
# 22.974560138789542
# TASK NUMBER  0  DEST:  39 33
# TASK NUMBER  1  DEST:  22 49
# 6.121582282297731
# -------
# TRYOUT[11]: (hidden_dim=128, max_step=10000, gamma=0.99, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  15 25
# TASK NUMBER  1  DEST:  26 18
# 28.75539725043693
# TASK NUMBER  0  DEST:  8 26
# TASK NUMBER  1  DEST:  26 18
# 9.361306178546975
# TASK NUMBER  0  DEST:  48 35
# TASK NUMBER  1  DEST:  15 10
# 7.304616600392929
# TASK NUMBER  0  DEST:  27 35
# TASK NUMBER  1  DEST:  38 16
# 20.214003559532834
# TASK NUMBER  0  DEST:  41 9
# TASK NUMBER  1  DEST:  43 27
# 6.894721829122738
# TASK NUMBER  0  DEST:  20 42
# TASK NUMBER  1  DEST:  6 21
# 6.131131311705157
# TASK NUMBER  0  DEST:  34 3
# TASK NUMBER  1  DEST:  20 28
# 9.074524152439961
# TASK NUMBER  0  DEST:  16 45
# TASK NUMBER  1  DEST:  26 19
# 7.365547524120179
# TASK NUMBER  0  DEST:  46 10
# TASK NUMBER  1  DEST:  46 32
# 11.849290478257231
# TASK NUMBER  0  DEST:  36 4
# TASK NUMBER  1  DEST:  30 17
# 7.977574678157524
# -------
# TRYOUT[12]: (hidden_dim=32, max_step=500, gamma=0.999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  4 33
# TASK NUMBER  1  DEST:  35 39
# 13.104886680532791
# TASK NUMBER  0  DEST:  29 9
# TASK NUMBER  1  DEST:  23 45
# 13.60552788052561
# TASK NUMBER  0  DEST:  34 39
# TASK NUMBER  1  DEST:  28 23
# 8.230314895372315
# TASK NUMBER  0  DEST:  26 36
# TASK NUMBER  1  DEST:  3 36
# 5.748368316103918
# TASK NUMBER  0  DEST:  37 16
# TASK NUMBER  1  DEST:  14 45
# 12.188410608216232
# TASK NUMBER  0  DEST:  35 19
# TASK NUMBER  1  DEST:  7 23
# 15.314424479280811
# TASK NUMBER  0  DEST:  6 9
# TASK NUMBER  1  DEST:  42 33
# 9.373714335981132
# TASK NUMBER  0  DEST:  20 20
# TASK NUMBER  1  DEST:  21 22
# 12.317979735796623
# TASK NUMBER  0  DEST:  0 35
# TASK NUMBER  1  DEST:  25 21
# 12.462813877422672
# TASK NUMBER  0  DEST:  21 23
# TASK NUMBER  1  DEST:  12 47
# 10.860157571765367
# -------
# TRYOUT[13]: (hidden_dim=64, max_step=500, gamma=0.999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  3 30
# TASK NUMBER  1  DEST:  1 21
# 11.241451550878178
# TASK NUMBER  0  DEST:  42 29
# TASK NUMBER  1  DEST:  45 34
# 17.45250258631383
# TASK NUMBER  0  DEST:  33 37
# TASK NUMBER  1  DEST:  46 7
# 18.195350116452055
# TASK NUMBER  0  DEST:  31 34
# TASK NUMBER  1  DEST:  8 41
# 26.659284502459325
# TASK NUMBER  0  DEST:  42 17
# TASK NUMBER  1  DEST:  0 22
# 12.711190320411593
# TASK NUMBER  0  DEST:  36 7
# TASK NUMBER  1  DEST:  3 39
# 9.972109294496272
# TASK NUMBER  0  DEST:  24 12
# TASK NUMBER  1  DEST:  7 18
# 10.022993032307665
# TASK NUMBER  0  DEST:  43 42
# TASK NUMBER  1  DEST:  35 37
# 6.6909336940999005
# TASK NUMBER  0  DEST:  9 41
# TASK NUMBER  1  DEST:  41 15
# 16.237054441601714
# TASK NUMBER  0  DEST:  10 39
# TASK NUMBER  1  DEST:  33 8
# 11.51080777626357
# -------
# TRYOUT[14]: (hidden_dim=128, max_step=500, gamma=0.999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  3 2
# TASK NUMBER  1  DEST:  42 49
# 9.125024651229188
# TASK NUMBER  0  DEST:  45 33
# TASK NUMBER  1  DEST:  48 8
# 5.513551012567837
# TASK NUMBER  0  DEST:  46 34
# TASK NUMBER  1  DEST:  22 19
# 7.584683632955288
# TASK NUMBER  0  DEST:  24 23
# TASK NUMBER  1  DEST:  32 38
# 12.386854896496356
# TASK NUMBER  0  DEST:  36 36
# TASK NUMBER  1  DEST:  47 38
# Task  0  completed at step  1
# 22.112114369414186
# TASK NUMBER  0  DEST:  32 26
# TASK NUMBER  1  DEST:  16 37
# 7.55947893442844
# TASK NUMBER  0  DEST:  5 20
# TASK NUMBER  1  DEST:  47 3
# 16.80296227549919
# TASK NUMBER  0  DEST:  15 30
# TASK NUMBER  1  DEST:  17 36
# 14.796754238019814
# TASK NUMBER  0  DEST:  31 7
# TASK NUMBER  1  DEST:  36 11
# 7.169547067253913
# TASK NUMBER  0  DEST:  48 48
# TASK NUMBER  1  DEST:  28 36
# 13.835669075684152
# -------
# TRYOUT[15]: (hidden_dim=32, max_step=1000, gamma=0.999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  40 3
# TASK NUMBER  1  DEST:  22 43
# 19.13943256902757
# TASK NUMBER  0  DEST:  16 47
# TASK NUMBER  1  DEST:  15 23
# 14.512346999707962
# TASK NUMBER  0  DEST:  9 43
# TASK NUMBER  1  DEST:  32 27
# 12.724558001112726
# TASK NUMBER  0  DEST:  32 2
# TASK NUMBER  1  DEST:  32 2
# 7.481519992651377
# TASK NUMBER  0  DEST:  11 15
# TASK NUMBER  1  DEST:  29 32
# 8.298631545433974
# TASK NUMBER  0  DEST:  10 31
# TASK NUMBER  1  DEST:  37 3
# 33.3194448648317
# TASK NUMBER  0  DEST:  26 37
# TASK NUMBER  1  DEST:  45 48
# 10.068042915696939
# TASK NUMBER  0  DEST:  49 13
# TASK NUMBER  1  DEST:  12 6
# 6.746305592932547
# TASK NUMBER  0  DEST:  11 6
# TASK NUMBER  1  DEST:  43 11
# 6.696591047020692
# TASK NUMBER  0  DEST:  29 40
# TASK NUMBER  1  DEST:  34 30
# 8.886927522378745
# -------
# TRYOUT[16]: (hidden_dim=64, max_step=1000, gamma=0.999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  9 11
# TASK NUMBER  1  DEST:  21 43
# 6.287997933385401
# TASK NUMBER  0  DEST:  48 26
# TASK NUMBER  1  DEST:  40 31
# 21.94374654194548
# TASK NUMBER  0  DEST:  42 42
# TASK NUMBER  1  DEST:  49 1
# 11.762917712236124
# TASK NUMBER  0  DEST:  8 30
# TASK NUMBER  1  DEST:  16 35
# 7.140498959418222
# TASK NUMBER  0  DEST:  44 10
# TASK NUMBER  1  DEST:  25 8
# 7.709487996100729
# TASK NUMBER  0  DEST:  6 13
# TASK NUMBER  1  DEST:  49 38
# Task  1  completed at step  43
# 49.86410971130468
# TASK NUMBER  0  DEST:  18 7
# TASK NUMBER  1  DEST:  14 5
# 5.638082887270985
# TASK NUMBER  0  DEST:  31 25
# TASK NUMBER  1  DEST:  11 12
# 15.835444561107222
# TASK NUMBER  0  DEST:  29 45
# TASK NUMBER  1  DEST:  24 30
# 14.863528349420045
# TASK NUMBER  0  DEST:  10 5
# TASK NUMBER  1  DEST:  35 14
# Task  1  completed at step  32
# 23.219351818539305
# -------
# TRYOUT[17]: (hidden_dim=128, max_step=1000, gamma=0.999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  33 48
# TASK NUMBER  1  DEST:  25 48
# 9.327097301192097
# TASK NUMBER  0  DEST:  15 22
# TASK NUMBER  1  DEST:  34 35
# 9.44911272225081
# TASK NUMBER  0  DEST:  40 13
# TASK NUMBER  1  DEST:  21 41
# 8.645335769173053
# TASK NUMBER  0  DEST:  31 21
# TASK NUMBER  1  DEST:  21 36
# 26.391422231603865
# TASK NUMBER  0  DEST:  5 17
# TASK NUMBER  1  DEST:  12 17
# 13.269305045744474
# TASK NUMBER  0  DEST:  6 28
# TASK NUMBER  1  DEST:  33 11
# 14.08874388101183
# TASK NUMBER  0  DEST:  21 10
# TASK NUMBER  1  DEST:  43 40
# 9.78764337181089
# TASK NUMBER  0  DEST:  31 27
# TASK NUMBER  1  DEST:  44 29
# 11.608514963860191
# TASK NUMBER  0  DEST:  42 21
# TASK NUMBER  1  DEST:  12 35
# 22.38514700943878
# TASK NUMBER  0  DEST:  1 30
# TASK NUMBER  1  DEST:  13 36
# 17.803500167817337
# -------
# TRYOUT[18]: (hidden_dim=32, max_step=5000, gamma=0.999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  24 5
# TASK NUMBER  1  DEST:  38 14
# 5.6511815705460595
# TASK NUMBER  0  DEST:  25 19
# TASK NUMBER  1  DEST:  17 48
# 9.974069033206813
# TASK NUMBER  0  DEST:  15 18
# TASK NUMBER  1  DEST:  12 28
# 19.411358717302637
# TASK NUMBER  0  DEST:  44 47
# TASK NUMBER  1  DEST:  20 2
# 10.972955818123117
# TASK NUMBER  0  DEST:  12 12
# TASK NUMBER  1  DEST:  16 11
# 10.783609381033942
# TASK NUMBER  0  DEST:  32 36
# TASK NUMBER  1  DEST:  45 26
# 7.702567306840328
# TASK NUMBER  0  DEST:  26 25
# TASK NUMBER  1  DEST:  24 26
# 9.430066310390185
# TASK NUMBER  0  DEST:  9 45
# TASK NUMBER  1  DEST:  1 40
# 17.512959106570296
# TASK NUMBER  0  DEST:  12 27
# TASK NUMBER  1  DEST:  38 27
# 18.66312909993089
# TASK NUMBER  0  DEST:  8 39
# TASK NUMBER  1  DEST:  38 10
# 7.2455102149117945
# -------
# TRYOUT[19]: (hidden_dim=64, max_step=5000, gamma=0.999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  47 30
# TASK NUMBER  1  DEST:  22 2
# 11.72628631339262
# TASK NUMBER  0  DEST:  43 25
# TASK NUMBER  1  DEST:  24 38
# 10.094405775756782
# TASK NUMBER  0  DEST:  21 12
# TASK NUMBER  1  DEST:  43 11
# 19.879677733411686
# TASK NUMBER  0  DEST:  18 16
# TASK NUMBER  1  DEST:  6 25
# 7.221920168686415
# TASK NUMBER  0  DEST:  37 39
# TASK NUMBER  1  DEST:  35 1
# 12.877922775349402
# TASK NUMBER  0  DEST:  45 18
# TASK NUMBER  1  DEST:  46 44
# 8.2319734199859
# TASK NUMBER  0  DEST:  15 47
# TASK NUMBER  1  DEST:  37 38
# 27.66907315324461
# TASK NUMBER  0  DEST:  5 1
# TASK NUMBER  1  DEST:  38 46
# 10.325661859799277
# TASK NUMBER  0  DEST:  6 21
# TASK NUMBER  1  DEST:  49 17
# 11.70184825164035
# TASK NUMBER  0  DEST:  36 44
# TASK NUMBER  1  DEST:  49 17
# 11.286216737262654
# -------
# TRYOUT[20]: (hidden_dim=128, max_step=5000, gamma=0.999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  37 30
# TASK NUMBER  1  DEST:  19 3
# 10.356697083002816
# TASK NUMBER  0  DEST:  49 44
# TASK NUMBER  1  DEST:  7 31
# 15.020835519293364
# TASK NUMBER  0  DEST:  31 46
# TASK NUMBER  1  DEST:  47 37
# 5.085371506986684
# TASK NUMBER  0  DEST:  31 47
# TASK NUMBER  1  DEST:  23 24
# 21.307647105106938
# TASK NUMBER  0  DEST:  38 47
# TASK NUMBER  1  DEST:  9 33
# 6.242230935364409
# TASK NUMBER  0  DEST:  35 3
# TASK NUMBER  1  DEST:  31 31
# 13.26983931396524
# TASK NUMBER  0  DEST:  38 0
# TASK NUMBER  1  DEST:  19 15
# 7.360590519170498
# TASK NUMBER  0  DEST:  49 40
# TASK NUMBER  1  DEST:  34 12
# 14.747173516093659
# TASK NUMBER  0  DEST:  12 16
# TASK NUMBER  1  DEST:  38 9
# 12.13381226461974
# TASK NUMBER  0  DEST:  22 38
# TASK NUMBER  1  DEST:  22 4
# 9.417634510842962
# -------
# TRYOUT[21]: (hidden_dim=32, max_step=10000, gamma=0.999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  13 23
# TASK NUMBER  1  DEST:  21 5
# 11.854927439640388
# TASK NUMBER  0  DEST:  3 47
# TASK NUMBER  1  DEST:  44 6
# 8.629159986963604
# TASK NUMBER  0  DEST:  8 15
# TASK NUMBER  1  DEST:  2 45
# 27.66324539026781
# TASK NUMBER  0  DEST:  28 24
# TASK NUMBER  1  DEST:  38 46
# 26.43596434951482
# TASK NUMBER  0  DEST:  1 20
# TASK NUMBER  1  DEST:  47 2
# 9.503837461221256
# TASK NUMBER  0  DEST:  34 39
# TASK NUMBER  1  DEST:  36 27
# 31.00432824615131
# TASK NUMBER  0  DEST:  4 39
# TASK NUMBER  1  DEST:  7 49
# 34.8790780276059
# TASK NUMBER  0  DEST:  8 26
# TASK NUMBER  1  DEST:  27 3
# 7.084406877395514
# TASK NUMBER  0  DEST:  20 49
# TASK NUMBER  1  DEST:  0 24
# 16.00616262013388
# TASK NUMBER  0  DEST:  33 7
# TASK NUMBER  1  DEST:  5 5
# 7.492110538178012
# -------
# TRYOUT[22]: (hidden_dim=64, max_step=10000, gamma=0.999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  6 37
# TASK NUMBER  1  DEST:  6 27
# 6.35628844887829
# TASK NUMBER  0  DEST:  40 16
# TASK NUMBER  1  DEST:  1 48
# 8.080376759684105
# TASK NUMBER  0  DEST:  27 48
# TASK NUMBER  1  DEST:  23 15
# 9.320999424320991
# TASK NUMBER  0  DEST:  33 36
# TASK NUMBER  1  DEST:  37 45
# 11.104510677251797
# TASK NUMBER  0  DEST:  1 48
# TASK NUMBER  1  DEST:  9 6
# 5.220374477117726
# TASK NUMBER  0  DEST:  12 21
# TASK NUMBER  1  DEST:  12 49
# 16.76142502834108
# TASK NUMBER  0  DEST:  0 12
# TASK NUMBER  1  DEST:  20 15
# 11.330085163153306
# TASK NUMBER  0  DEST:  18 47
# TASK NUMBER  1  DEST:  27 28
# 17.53087387663301
# TASK NUMBER  0  DEST:  40 46
# TASK NUMBER  1  DEST:  31 30
# 17.665796582684404
# TASK NUMBER  0  DEST:  49 24
# TASK NUMBER  1  DEST:  48 46
# 15.262788941356549
# -------
# TRYOUT[23]: (hidden_dim=128, max_step=10000, gamma=0.999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  16 4
# TASK NUMBER  1  DEST:  37 8
# 15.732628884191572
# TASK NUMBER  0  DEST:  48 6
# TASK NUMBER  1  DEST:  43 39
# 15.127959863997264
# TASK NUMBER  0  DEST:  10 44
# TASK NUMBER  1  DEST:  30 39
# 19.00083455231757
# TASK NUMBER  0  DEST:  32 1
# TASK NUMBER  1  DEST:  3 29
# 5.661009204095012
# TASK NUMBER  0  DEST:  13 31
# TASK NUMBER  1  DEST:  48 12
# 21.34226316075993
# TASK NUMBER  0  DEST:  31 29
# TASK NUMBER  1  DEST:  43 33
# 29.13193383323235
# TASK NUMBER  0  DEST:  49 33
# TASK NUMBER  1  DEST:  15 34
# 25.610579093322325
# TASK NUMBER  0  DEST:  22 38
# TASK NUMBER  1  DEST:  37 16
# 16.078635596320204
# TASK NUMBER  0  DEST:  23 8
# TASK NUMBER  1  DEST:  42 25
# 9.936872362228174
# TASK NUMBER  0  DEST:  17 11
# TASK NUMBER  1  DEST:  2 45
# 5.560305788033738
# -------
# TRYOUT[24]: (hidden_dim=32, max_step=500, gamma=0.9999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  29 2
# TASK NUMBER  1  DEST:  8 30
# 10.95167550475607
# TASK NUMBER  0  DEST:  5 15
# TASK NUMBER  1  DEST:  11 23
# 26.885113183627116
# TASK NUMBER  0  DEST:  1 25
# TASK NUMBER  1  DEST:  9 33
# 15.344940911203093
# TASK NUMBER  0  DEST:  18 4
# TASK NUMBER  1  DEST:  45 13
# 15.604883003147446
# TASK NUMBER  0  DEST:  36 39
# TASK NUMBER  1  DEST:  33 13
# Task  1  completed at step  22
# 23.23342403619394
# TASK NUMBER  0  DEST:  30 19
# TASK NUMBER  1  DEST:  29 18
# 17.913883416102696
# TASK NUMBER  0  DEST:  5 43
# TASK NUMBER  1  DEST:  39 40
# 15.89637407105068
# TASK NUMBER  0  DEST:  37 34
# TASK NUMBER  1  DEST:  16 11
# 10.703988209762763
# TASK NUMBER  0  DEST:  43 19
# TASK NUMBER  1  DEST:  0 48
# 9.734118913752903
# TASK NUMBER  0  DEST:  48 23
# TASK NUMBER  1  DEST:  39 36
# 15.105322955702896
# -------
# TRYOUT[25]: (hidden_dim=64, max_step=500, gamma=0.9999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  43 45
# TASK NUMBER  1  DEST:  9 14
# 11.348570555189912
# TASK NUMBER  0  DEST:  45 49
# TASK NUMBER  1  DEST:  49 44
# 7.149002987501919
# TASK NUMBER  0  DEST:  36 9
# TASK NUMBER  1  DEST:  34 6
# 9.534483568099624
# TASK NUMBER  0  DEST:  15 18
# TASK NUMBER  1  DEST:  49 5
# 5.8831512833088375
# TASK NUMBER  0  DEST:  41 18
# TASK NUMBER  1  DEST:  37 46
# 16.810073793110178
# TASK NUMBER  0  DEST:  10 21
# TASK NUMBER  1  DEST:  47 30
# 11.296127432608268
# TASK NUMBER  0  DEST:  5 19
# TASK NUMBER  1  DEST:  43 26
# 20.873532048567636
# TASK NUMBER  0  DEST:  34 29
# TASK NUMBER  1  DEST:  45 44
# 5.256884056907872
# TASK NUMBER  0  DEST:  49 31
# TASK NUMBER  1  DEST:  40 13
# 7.956932751715296
# TASK NUMBER  0  DEST:  41 35
# TASK NUMBER  1  DEST:  19 21
# 16.92838643895032
# -------
# TRYOUT[26]: (hidden_dim=128, max_step=500, gamma=0.9999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  3 5
# TASK NUMBER  1  DEST:  4 7
# 5.537702999200272
# TASK NUMBER  0  DEST:  21 31
# TASK NUMBER  1  DEST:  11 13
# 20.245787328990193
# TASK NUMBER  0  DEST:  21 40
# TASK NUMBER  1  DEST:  41 36
# 16.515698083158988
# TASK NUMBER  0  DEST:  42 18
# TASK NUMBER  1  DEST:  17 33
# 9.821570742187063
# TASK NUMBER  0  DEST:  25 42
# TASK NUMBER  1  DEST:  2 22
# 12.425951682380472
# TASK NUMBER  0  DEST:  38 23
# TASK NUMBER  1  DEST:  18 28
# 11.173763662027964
# TASK NUMBER  0  DEST:  6 6
# TASK NUMBER  1  DEST:  30 40
# 8.986805701915987
# TASK NUMBER  0  DEST:  7 11
# TASK NUMBER  1  DEST:  6 7
# 10.541921680371145
# TASK NUMBER  0  DEST:  18 48
# TASK NUMBER  1  DEST:  16 25
# 5.487949368487205
# TASK NUMBER  0  DEST:  19 21
# TASK NUMBER  1  DEST:  26 6
# 6.532282785160202
# -------
# TRYOUT[27]: (hidden_dim=32, max_step=1000, gamma=0.9999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  43 12
# TASK NUMBER  1  DEST:  17 20
# 9.001482260504728
# TASK NUMBER  0  DEST:  43 33
# TASK NUMBER  1  DEST:  28 41
# 15.147115831949224
# TASK NUMBER  0  DEST:  5 9
# TASK NUMBER  1  DEST:  7 26
# 8.666565367134945
# TASK NUMBER  0  DEST:  16 24
# TASK NUMBER  1  DEST:  21 46
# 10.356454579128298
# TASK NUMBER  0  DEST:  13 17
# TASK NUMBER  1  DEST:  23 28
# 22.508293270312457
# TASK NUMBER  0  DEST:  27 28
# TASK NUMBER  1  DEST:  7 23
# 10.413351134365746
# TASK NUMBER  0  DEST:  36 34
# TASK NUMBER  1  DEST:  44 23
# 12.316382467993915
# TASK NUMBER  0  DEST:  11 3
# TASK NUMBER  1  DEST:  34 30
# 14.901158434519957
# TASK NUMBER  0  DEST:  26 11
# TASK NUMBER  1  DEST:  10 41
# 13.493982560264168
# TASK NUMBER  0  DEST:  35 48
# TASK NUMBER  1  DEST:  28 42
# 5.656959747986365
# -------
# TRYOUT[28]: (hidden_dim=64, max_step=1000, gamma=0.9999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  31 36
# TASK NUMBER  1  DEST:  41 1
# 7.704136019179855
# TASK NUMBER  0  DEST:  3 29
# TASK NUMBER  1  DEST:  43 39
# 32.815430600702264
# TASK NUMBER  0  DEST:  14 35
# TASK NUMBER  1  DEST:  45 9
# 12.3103528494849
# TASK NUMBER  0  DEST:  7 12
# TASK NUMBER  1  DEST:  13 17
# 13.255206913324464
# TASK NUMBER  0  DEST:  36 1
# TASK NUMBER  1  DEST:  11 46
# 10.959095652842912
# TASK NUMBER  0  DEST:  25 13
# TASK NUMBER  1  DEST:  33 20
# 12.572909288259366
# TASK NUMBER  0  DEST:  0 8
# TASK NUMBER  1  DEST:  9 11
# 7.49087173113082
# TASK NUMBER  0  DEST:  7 10
# TASK NUMBER  1  DEST:  25 34
# 12.032782704196
# TASK NUMBER  0  DEST:  32 19
# TASK NUMBER  1  DEST:  6 4
# 8.577312386026565
# TASK NUMBER  0  DEST:  40 49
# TASK NUMBER  1  DEST:  5 10
# 6.747138929771212
# -------
# TRYOUT[29]: (hidden_dim=128, max_step=1000, gamma=0.9999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  1 24
# TASK NUMBER  1  DEST:  20 44
# 13.33844036699311
# TASK NUMBER  0  DEST:  41 20
# TASK NUMBER  1  DEST:  46 30
# 11.22560144482545
# TASK NUMBER  0  DEST:  32 16
# TASK NUMBER  1  DEST:  20 4
# 7.5560579973278905
# TASK NUMBER  0  DEST:  46 44
# TASK NUMBER  1  DEST:  40 35
# 6.5969706593119986
# TASK NUMBER  0  DEST:  4 5
# TASK NUMBER  1  DEST:  20 45
# 13.980219842481594
# TASK NUMBER  0  DEST:  19 20
# TASK NUMBER  1  DEST:  8 48
# 15.449476981100132
# TASK NUMBER  0  DEST:  10 28
# TASK NUMBER  1  DEST:  29 13
# 9.894567949808609
# TASK NUMBER  0  DEST:  22 11
# TASK NUMBER  1  DEST:  12 30
# 18.26020577512069
# TASK NUMBER  0  DEST:  2 32
# TASK NUMBER  1  DEST:  17 20
# 10.990794746208186
# TASK NUMBER  0  DEST:  48 18
# TASK NUMBER  1  DEST:  14 45
# 5.705374454153545
# -------
# TRYOUT[30]: (hidden_dim=32, max_step=5000, gamma=0.9999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  0 40
# TASK NUMBER  1  DEST:  4 43
# Task  0  completed at step  116
# 51.03666451711083
# TASK NUMBER  0  DEST:  20 9
# TASK NUMBER  1  DEST:  33 7
# 9.071118264527195
# TASK NUMBER  0  DEST:  3 17
# TASK NUMBER  1  DEST:  39 37
# 12.844534237262671
# TASK NUMBER  0  DEST:  28 18
# TASK NUMBER  1  DEST:  1 47
# 7.945297750676569
# TASK NUMBER  0  DEST:  14 41
# TASK NUMBER  1  DEST:  8 35
# 11.006348999284244
# TASK NUMBER  0  DEST:  40 4
# TASK NUMBER  1  DEST:  20 28
# 9.267014418696053
# TASK NUMBER  0  DEST:  45 29
# TASK NUMBER  1  DEST:  9 23
# 15.883206528138583
# TASK NUMBER  0  DEST:  32 30
# TASK NUMBER  1  DEST:  4 17
# 8.171348266947149
# TASK NUMBER  0  DEST:  38 7
# TASK NUMBER  1  DEST:  42 23
# 18.104464506809954
# TASK NUMBER  0  DEST:  23 45
# TASK NUMBER  1  DEST:  0 47
# Task  1  completed at step  109
# 37.863271185447395
# -------
# TRYOUT[31]: (hidden_dim=64, max_step=5000, gamma=0.9999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  12 36
# TASK NUMBER  1  DEST:  28 42
# 16.088961290667147
# TASK NUMBER  0  DEST:  48 23
# TASK NUMBER  1  DEST:  1 38
# 23.24163789453047
# TASK NUMBER  0  DEST:  35 43
# TASK NUMBER  1  DEST:  20 38
# 7.764527477264027
# TASK NUMBER  0  DEST:  40 33
# TASK NUMBER  1  DEST:  12 17
# 12.197055056917181
# TASK NUMBER  0  DEST:  39 30
# TASK NUMBER  1  DEST:  31 41
# 8.895104607048191
# TASK NUMBER  0  DEST:  0 49
# TASK NUMBER  1  DEST:  47 22
# 12.908668142004338
# TASK NUMBER  0  DEST:  29 42
# TASK NUMBER  1  DEST:  1 37
# 7.602106604961299
# TASK NUMBER  0  DEST:  29 31
# TASK NUMBER  1  DEST:  4 11
# 19.28809137923336
# TASK NUMBER  0  DEST:  26 41
# TASK NUMBER  1  DEST:  4 48
# 33.8143215245803
# TASK NUMBER  0  DEST:  46 40
# TASK NUMBER  1  DEST:  16 20
# 10.477646675392549
# -------
# TRYOUT[32]: (hidden_dim=128, max_step=5000, gamma=0.9999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  49 39
# TASK NUMBER  1  DEST:  23 14
# 9.508317582281279
# TASK NUMBER  0  DEST:  44 28
# TASK NUMBER  1  DEST:  25 7
# 9.150402243660599
# TASK NUMBER  0  DEST:  8 16
# TASK NUMBER  1  DEST:  30 7
# 12.035983960301172
# TASK NUMBER  0  DEST:  6 23
# TASK NUMBER  1  DEST:  5 13
# 6.101484068257372
# TASK NUMBER  0  DEST:  8 2
# TASK NUMBER  1  DEST:  7 4
# 5.600960004618064
# TASK NUMBER  0  DEST:  9 20
# TASK NUMBER  1  DEST:  6 17
# 8.224795830224084
# TASK NUMBER  0  DEST:  16 6
# TASK NUMBER  1  DEST:  33 19
# 8.122125636532596
# TASK NUMBER  0  DEST:  11 8
# TASK NUMBER  1  DEST:  32 29
# 7.889234136228472
# TASK NUMBER  0  DEST:  36 36
# TASK NUMBER  1  DEST:  34 35
# 12.111821769304493
# TASK NUMBER  0  DEST:  4 40
# TASK NUMBER  1  DEST:  42 23
# 11.325625913547764
# -------
# TRYOUT[33]: (hidden_dim=32, max_step=10000, gamma=0.9999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  5 24
# TASK NUMBER  1  DEST:  43 16
# 26.970317191476177
# TASK NUMBER  0  DEST:  36 25
# TASK NUMBER  1  DEST:  28 48
# 8.572484690205075
# TASK NUMBER  0  DEST:  23 49
# TASK NUMBER  1  DEST:  33 43
# 12.057130649920227
# TASK NUMBER  0  DEST:  33 47
# TASK NUMBER  1  DEST:  37 20
# 13.52914566202346
# TASK NUMBER  0  DEST:  44 42
# TASK NUMBER  1  DEST:  43 21
# 5.7062862666705625
# TASK NUMBER  0  DEST:  42 29
# TASK NUMBER  1  DEST:  2 17
# 9.71453030083294
# TASK NUMBER  0  DEST:  23 34
# TASK NUMBER  1  DEST:  18 17
# 7.341056080314535
# TASK NUMBER  0  DEST:  24 16
# TASK NUMBER  1  DEST:  46 13
# 7.247816585547586
# TASK NUMBER  0  DEST:  7 34
# TASK NUMBER  1  DEST:  15 12
# 16.030866002771475
# TASK NUMBER  0  DEST:  23 36
# TASK NUMBER  1  DEST:  49 41
# 6.583974408721641
# -------
# TRYOUT[34]: (hidden_dim=64, max_step=10000, gamma=0.9999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  4 49
# TASK NUMBER  1  DEST:  29 22
# 13.769401126255284
# TASK NUMBER  0  DEST:  5 44
# TASK NUMBER  1  DEST:  9 27
# 9.020895419757855
# TASK NUMBER  0  DEST:  42 46
# TASK NUMBER  1  DEST:  3 15
# 9.746844621170451
# TASK NUMBER  0  DEST:  8 43
# TASK NUMBER  1  DEST:  38 21
# Task  0  completed at step  22
# 26.22751382910841
# TASK NUMBER  0  DEST:  15 34
# TASK NUMBER  1  DEST:  27 45
# Task  1  completed at step  3
# 28.958193424467325
# TASK NUMBER  0  DEST:  11 25
# TASK NUMBER  1  DEST:  30 6
# 8.496289342008488
# TASK NUMBER  0  DEST:  15 14
# TASK NUMBER  1  DEST:  7 35
# 8.689800551852315
# TASK NUMBER  0  DEST:  32 7
# TASK NUMBER  1  DEST:  41 25
# 10.62240048581298
# TASK NUMBER  0  DEST:  22 5
# TASK NUMBER  1  DEST:  49 26
# Task  1  completed at step  72
# 65.52954315250727
# TASK NUMBER  0  DEST:  47 7
# TASK NUMBER  1  DEST:  38 49
# 6.49358445919016
# -------
# TRYOUT[35]: (hidden_dim=128, max_step=10000, gamma=0.9999, n_episode=1000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  23 14
# TASK NUMBER  1  DEST:  16 21
# 8.019814468643709
# TASK NUMBER  0  DEST:  28 11
# TASK NUMBER  1  DEST:  39 22
# 9.1750569018488
# TASK NUMBER  0  DEST:  11 25
# TASK NUMBER  1  DEST:  3 22
# 8.100542746920567
# TASK NUMBER  0  DEST:  46 33
# TASK NUMBER  1  DEST:  48 22
# 45.24256234094425
# TASK NUMBER  0  DEST:  29 32
# TASK NUMBER  1  DEST:  48 38
# 8.320554296565929
# TASK NUMBER  0  DEST:  23 43
# TASK NUMBER  1  DEST:  34 6
# 11.606130943434312
# TASK NUMBER  0  DEST:  29 21
# TASK NUMBER  1  DEST:  34 40
# 16.592347782063335
# TASK NUMBER  0  DEST:  38 2
# TASK NUMBER  1  DEST:  6 12
# 6.250610908827896
# TASK NUMBER  0  DEST:  24 5
# TASK NUMBER  1  DEST:  8 5
# 22.98554627094043
# TASK NUMBER  0  DEST:  0 38
# TASK NUMBER  1  DEST:  32 26
# 10.789530224736177
# -------
# TRYOUT[36]: (hidden_dim=32, max_step=500, gamma=0.99, n_episode=2000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  6 18
# TASK NUMBER  1  DEST:  47 46
# 8.589906778874038
# TASK NUMBER  0  DEST:  5 38
# TASK NUMBER  1  DEST:  37 17
# 10.924948108429215
# TASK NUMBER  0  DEST:  31 7
# TASK NUMBER  1  DEST:  20 48
# 7.269832778080028
# TASK NUMBER  0  DEST:  13 45
# TASK NUMBER  1  DEST:  24 41
# 29.700915756978386
# TASK NUMBER  0  DEST:  16 48
# TASK NUMBER  1  DEST:  22 3
# 42.36188102458646
# TASK NUMBER  0  DEST:  26 16
# TASK NUMBER  1  DEST:  11 26
# 8.149638396519743
# TASK NUMBER  0  DEST:  4 28
# TASK NUMBER  1  DEST:  11 10
# 11.282221588449856
# TASK NUMBER  0  DEST:  18 16
# TASK NUMBER  1  DEST:  3 37
# 16.485416654344643
# TASK NUMBER  0  DEST:  45 40
# TASK NUMBER  1  DEST:  48 39
# 34.518101025647276
# TASK NUMBER  0  DEST:  32 5
# TASK NUMBER  1  DEST:  34 4
# 5.915140816551711
# -------
# TRYOUT[37]: (hidden_dim=64, max_step=500, gamma=0.99, n_episode=2000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  49 30
# TASK NUMBER  1  DEST:  12 32
# 20.714475847135606
# TASK NUMBER  0  DEST:  30 16
# TASK NUMBER  1  DEST:  42 9
# 13.514139532402112
# TASK NUMBER  0  DEST:  22 31
# TASK NUMBER  1  DEST:  38 43
# 14.530991037263558
# TASK NUMBER  0  DEST:  17 47
# TASK NUMBER  1  DEST:  14 44
# 32.455567738545206
# TASK NUMBER  0  DEST:  43 34
# TASK NUMBER  1  DEST:  25 3
# 19.70571181605503
# TASK NUMBER  0  DEST:  43 40
# TASK NUMBER  1  DEST:  49 30
# 5.076388512557988
# TASK NUMBER  0  DEST:  22 23
# TASK NUMBER  1  DEST:  22 19
# 11.648689080476498
# TASK NUMBER  0  DEST:  36 2
# TASK NUMBER  1  DEST:  35 7
# 6.5891335059336855
# TASK NUMBER  0  DEST:  42 21
# TASK NUMBER  1  DEST:  24 37
# 10.127708410639798
# TASK NUMBER  0  DEST:  15 47
# TASK NUMBER  1  DEST:  15 2
# 18.571223583893378
# -------
# TRYOUT[38]: (hidden_dim=128, max_step=500, gamma=0.99, n_episode=2000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  16 34
# TASK NUMBER  1  DEST:  18 46
# 7.328002159568926
# TASK NUMBER  0  DEST:  13 45
# TASK NUMBER  1  DEST:  21 34
# 8.807824936409427
# TASK NUMBER  0  DEST:  15 31
# TASK NUMBER  1  DEST:  0 41
# 5.563417652539485
# TASK NUMBER  0  DEST:  40 7
# TASK NUMBER  1  DEST:  27 38
# 9.523977404909742
# TASK NUMBER  0  DEST:  32 2
# TASK NUMBER  1  DEST:  32 2
# 11.906599066971719
# TASK NUMBER  0  DEST:  46 45
# TASK NUMBER  1  DEST:  39 48
# Task  1  completed at step  4
# 27.19372606806273
# TASK NUMBER  0  DEST:  37 42
# TASK NUMBER  1  DEST:  49 39
# 6.340424202896817
# TASK NUMBER  0  DEST:  18 46
# TASK NUMBER  1  DEST:  27 10
# 14.670166388077401
# TASK NUMBER  0  DEST:  0 0
# TASK NUMBER  1  DEST:  33 16
# 5.8203340401754655
# TASK NUMBER  0  DEST:  19 29
# TASK NUMBER  1  DEST:  23 27
# 18.67309889141995
# -------
# TRYOUT[39]: (hidden_dim=32, max_step=1000, gamma=0.99, n_episode=2000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  40 7
# TASK NUMBER  1  DEST:  0 36
# 20.325313848229513
# TASK NUMBER  0  DEST:  14 28
# TASK NUMBER  1  DEST:  5 46
# 22.518425721341103
# TASK NUMBER  0  DEST:  14 31
# TASK NUMBER  1  DEST:  20 24
# 7.089709700457508
# TASK NUMBER  0  DEST:  7 9
# TASK NUMBER  1  DEST:  25 15
# 15.061709161995854
# TASK NUMBER  0  DEST:  37 19
# TASK NUMBER  1  DEST:  40 20
# 6.269932460761062
# TASK NUMBER  0  DEST:  7 48
# TASK NUMBER  1  DEST:  36 35
# Task  0  completed at step  19
# 46.427867505777066
# TASK NUMBER  0  DEST:  1 46
# TASK NUMBER  1  DEST:  28 31
# 13.523597596534216
# TASK NUMBER  0  DEST:  39 11
# TASK NUMBER  1  DEST:  17 42
# 10.654374446145319
# TASK NUMBER  0  DEST:  39 1
# TASK NUMBER  1  DEST:  28 32
# 13.672526390936794
# TASK NUMBER  0  DEST:  45 12
# TASK NUMBER  1  DEST:  36 48
# 7.539505439215052
# -------
# TRYOUT[40]: (hidden_dim=64, max_step=1000, gamma=0.99, n_episode=2000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  41 18
# TASK NUMBER  1  DEST:  9 25
# 10.109283904156117
# TASK NUMBER  0  DEST:  38 30
# TASK NUMBER  1  DEST:  31 5
# 9.269319208383447
# TASK NUMBER  0  DEST:  47 5
# TASK NUMBER  1  DEST:  34 7
# 25.398899253456225
# TASK NUMBER  0  DEST:  21 21
# TASK NUMBER  1  DEST:  34 7
# 17.46773962525527
# TASK NUMBER  0  DEST:  10 17
# TASK NUMBER  1  DEST:  1 44
# 13.866120665993904
# TASK NUMBER  0  DEST:  8 14
# TASK NUMBER  1  DEST:  40 13
# 12.101591236936878
# TASK NUMBER  0  DEST:  11 14
# TASK NUMBER  1  DEST:  12 40
# 17.197364345920693
# TASK NUMBER  0  DEST:  33 49
# TASK NUMBER  1  DEST:  48 33
# 7.940755488093722
# TASK NUMBER  0  DEST:  39 34
# TASK NUMBER  1  DEST:  2 11
# 17.81735280815321
# TASK NUMBER  0  DEST:  41 36
# TASK NUMBER  1  DEST:  47 31
# 9.954309522035752
# -------
# TRYOUT[41]: (hidden_dim=128, max_step=1000, gamma=0.99, n_episode=2000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  25 45
# TASK NUMBER  1  DEST:  16 30
# Task  1  completed at step  18
# 28.22337506357375
# TASK NUMBER  0  DEST:  29 3
# TASK NUMBER  1  DEST:  6 49
# 8.724394066924935
# TASK NUMBER  0  DEST:  32 6
# TASK NUMBER  1  DEST:  40 46
# 9.437850366695683
# TASK NUMBER  0  DEST:  29 34
# TASK NUMBER  1  DEST:  5 0
# 6.702935083613937
# TASK NUMBER  0  DEST:  48 34
# TASK NUMBER  1  DEST:  42 45
# 32.72996933135569
# TASK NUMBER  0  DEST:  48 6
# TASK NUMBER  1  DEST:  20 1
# 15.040835621767878
# TASK NUMBER  0  DEST:  41 36
# TASK NUMBER  1  DEST:  26 25
# 18.369099426375797
# TASK NUMBER  0  DEST:  20 14
# TASK NUMBER  1  DEST:  43 9
# 18.34806902089034
# TASK NUMBER  0  DEST:  4 31
# TASK NUMBER  1  DEST:  1 14
# 6.879527553566256
# TASK NUMBER  0  DEST:  46 44
# TASK NUMBER  1  DEST:  15 25
# 9.50087572426962
# -------
# TRYOUT[42]: (hidden_dim=32, max_step=5000, gamma=0.99, n_episode=2000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  17 5
# TASK NUMBER  1  DEST:  12 9
# 8.979060435926069
# TASK NUMBER  0  DEST:  19 32
# TASK NUMBER  1  DEST:  20 47
# 5.622711866801917
# TASK NUMBER  0  DEST:  7 43
# TASK NUMBER  1  DEST:  16 16
# 7.405588025361995
# TASK NUMBER  0  DEST:  43 49
# TASK NUMBER  1  DEST:  26 22
# 9.573128205119048
# TASK NUMBER  0  DEST:  49 23
# TASK NUMBER  1  DEST:  44 8
# 9.25358333004293
# TASK NUMBER  0  DEST:  42 30
# TASK NUMBER  1  DEST:  0 47
# 6.407820602635948
# TASK NUMBER  0  DEST:  44 37
# TASK NUMBER  1  DEST:  19 34
# 5.896311384508641
# TASK NUMBER  0  DEST:  36 35
# TASK NUMBER  1  DEST:  47 1
# 5.948091293971634
# TASK NUMBER  0  DEST:  10 21
# TASK NUMBER  1  DEST:  16 5
# 16.395873366184276
# TASK NUMBER  0  DEST:  17 47
# TASK NUMBER  1  DEST:  40 12
# 7.830719191978362
# -------
# TRYOUT[43]: (hidden_dim=64, max_step=5000, gamma=0.99, n_episode=2000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  43 43
# TASK NUMBER  1  DEST:  31 3
# 6.2832135748009765
# TASK NUMBER  0  DEST:  11 29
# TASK NUMBER  1  DEST:  47 36
# 14.173614150558777
# TASK NUMBER  0  DEST:  39 21
# TASK NUMBER  1  DEST:  4 31
# 8.89929619822449
# TASK NUMBER  0  DEST:  28 31
# TASK NUMBER  1  DEST:  45 48
# 7.7172248005621675
# TASK NUMBER  0  DEST:  1 30
# TASK NUMBER  1  DEST:  17 23
# 24.06541358017386
# TASK NUMBER  0  DEST:  33 39
# TASK NUMBER  1  DEST:  43 14
# 7.378098471197606
# TASK NUMBER  0  DEST:  38 14
# TASK NUMBER  1  DEST:  6 37
# 15.846115072713449
# TASK NUMBER  0  DEST:  5 45
# TASK NUMBER  1  DEST:  9 20
# 8.302628056076655
# TASK NUMBER  0  DEST:  31 48
# TASK NUMBER  1  DEST:  3 6
# 6.863129205696584
# TASK NUMBER  0  DEST:  39 32
# TASK NUMBER  1  DEST:  4 10
# 12.95101299527751
# -------
# TRYOUT[44]: (hidden_dim=128, max_step=5000, gamma=0.99, n_episode=2000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  20 24
# TASK NUMBER  1  DEST:  31 0
# 23.66595441387116
# TASK NUMBER  0  DEST:  13 22
# TASK NUMBER  1  DEST:  32 18
# 11.682919849853786
# TASK NUMBER  0  DEST:  34 30
# TASK NUMBER  1  DEST:  24 4
# 6.686493226689904
# TASK NUMBER  0  DEST:  32 36
# TASK NUMBER  1  DEST:  12 32
# 16.875570544513565
# TASK NUMBER  0  DEST:  30 38
# TASK NUMBER  1  DEST:  28 48
# 7.2730867347052195
# TASK NUMBER  0  DEST:  9 44
# TASK NUMBER  1  DEST:  43 13
# 14.52236115564451
# TASK NUMBER  0  DEST:  33 41
# TASK NUMBER  1  DEST:  20 40
# 12.327799316551669
# TASK NUMBER  0  DEST:  28 11
# TASK NUMBER  1  DEST:  20 4
# 19.980812184419335
# TASK NUMBER  0  DEST:  12 1
# TASK NUMBER  1  DEST:  25 42
# 9.132345731533327
# TASK NUMBER  0  DEST:  29 7
# TASK NUMBER  1  DEST:  22 37
# 14.229324868694649
# -------
# TRYOUT[45]: (hidden_dim=32, max_step=10000, gamma=0.99, n_episode=2000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  40 47
# TASK NUMBER  1  DEST:  16 39
# 8.110057190668787
# TASK NUMBER  0  DEST:  22 3
# TASK NUMBER  1  DEST:  10 16
# 23.71702803702373
# TASK NUMBER  0  DEST:  35 9
# TASK NUMBER  1  DEST:  7 0
# 19.86816349469271
# TASK NUMBER  0  DEST:  35 18
# TASK NUMBER  1  DEST:  8 21
# 17.73530065838035
# TASK NUMBER  0  DEST:  30 1
# TASK NUMBER  1  DEST:  17 0
# 18.29371776287192
# TASK NUMBER  0  DEST:  20 2
# TASK NUMBER  1  DEST:  39 33
# 7.199711574708284
# TASK NUMBER  0  DEST:  24 47
# TASK NUMBER  1  DEST:  29 9
# 8.434947083911435
# TASK NUMBER  0  DEST:  30 30
# TASK NUMBER  1  DEST:  36 44
# 21.796058442036458
# TASK NUMBER  0  DEST:  15 7
# TASK NUMBER  1  DEST:  30 43
# 9.833243508001233
# TASK NUMBER  0  DEST:  21 48
# TASK NUMBER  1  DEST:  38 36
# 13.399799000947908
# -------
# TRYOUT[46]: (hidden_dim=64, max_step=10000, gamma=0.99, n_episode=2000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  13 5
# TASK NUMBER  1  DEST:  8 24
# 24.755963381640854
# TASK NUMBER  0  DEST:  1 38
# TASK NUMBER  1  DEST:  6 43
# 7.424199098341438
# TASK NUMBER  0  DEST:  10 15
# TASK NUMBER  1  DEST:  34 24
# 9.476172409244588
# TASK NUMBER  0  DEST:  12 4
# TASK NUMBER  1  DEST:  40 48
# Task  0  completed at step  95
# 23.6299580824216
# TASK NUMBER  0  DEST:  30 41
# TASK NUMBER  1  DEST:  7 2
# 28.88254477824342
# TASK NUMBER  0  DEST:  1 47
# TASK NUMBER  1  DEST:  17 34
# 5.0786289062906596
# TASK NUMBER  0  DEST:  35 46
# TASK NUMBER  1  DEST:  43 11
# 9.388104389695654
# TASK NUMBER  0  DEST:  37 24
# TASK NUMBER  1  DEST:  30 30
# 16.782189669693633
# TASK NUMBER  0  DEST:  1 7
# TASK NUMBER  1  DEST:  5 16
# 17.07202899862065
# TASK NUMBER  0  DEST:  14 19
# TASK NUMBER  1  DEST:  29 39
# 9.670694476684123
# -------
# TRYOUT[47]: (hidden_dim=128, max_step=10000, gamma=0.99, n_episode=2000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  49 32
# TASK NUMBER  1  DEST:  9 43
# Task  1  completed at step  93
# 42.582073286799776
# TASK NUMBER  0  DEST:  41 43
# TASK NUMBER  1  DEST:  19 1
# 9.182863848506592
# TASK NUMBER  0  DEST:  24 11
# TASK NUMBER  1  DEST:  8 16
# 7.232280432615764
# TASK NUMBER  0  DEST:  11 35
# TASK NUMBER  1  DEST:  24 35
# Task  1  completed at step  42
# 27.062792011365058
# TASK NUMBER  0  DEST:  25 44
# TASK NUMBER  1  DEST:  13 2
# 10.941851322859844
# TASK NUMBER  0  DEST:  19 49
# TASK NUMBER  1  DEST:  14 40
# 14.171231219299514
# TASK NUMBER  0  DEST:  35 31
# TASK NUMBER  1  DEST:  5 4
# 12.268899787930415
# TASK NUMBER  0  DEST:  25 20
# TASK NUMBER  1  DEST:  26 40
# 12.919090524001588
# TASK NUMBER  0  DEST:  26 3
# TASK NUMBER  1  DEST:  20 37
# 8.892241175024695
# TASK NUMBER  0  DEST:  38 21
# TASK NUMBER  1  DEST:  1 12
# 16.881148599516788
# -------
# TRYOUT[48]: (hidden_dim=32, max_step=500, gamma=0.999, n_episode=2000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  2 40
# TASK NUMBER  1  DEST:  3 30
# 7.966470600924039
# TASK NUMBER  0  DEST:  39 0
# TASK NUMBER  1  DEST:  14 44
# 19.82905618475517
# TASK NUMBER  0  DEST:  47 24
# TASK NUMBER  1  DEST:  35 2
# 29.490548350774784
# TASK NUMBER  0  DEST:  38 8
# TASK NUMBER  1  DEST:  9 32
# 24.10796935545104
# TASK NUMBER  0  DEST:  2 16
# TASK NUMBER  1  DEST:  0 20
# 7.076142950113493
# TASK NUMBER  0  DEST:  15 34
# TASK NUMBER  1  DEST:  48 36
# 8.129813377703387
# TASK NUMBER  0  DEST:  0 21
# TASK NUMBER  1  DEST:  47 28
# 13.332040140165793
# TASK NUMBER  0  DEST:  37 35
# TASK NUMBER  1  DEST:  40 3
# 11.702414421454671
# TASK NUMBER  0  DEST:  3 26
# TASK NUMBER  1  DEST:  3 25
# 22.571694083283123
# TASK NUMBER  0  DEST:  23 43
# TASK NUMBER  1  DEST:  21 31
# 7.061285470528063
# -------
# TRYOUT[49]: (hidden_dim=64, max_step=500, gamma=0.999, n_episode=2000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  17 46
# TASK NUMBER  1  DEST:  43 45
# 8.329378784332498
# TASK NUMBER  0  DEST:  1 32
# TASK NUMBER  1  DEST:  28 19
# 9.374596301495265
# TASK NUMBER  0  DEST:  34 22
# TASK NUMBER  1  DEST:  3 33
# 8.683777960091101
# TASK NUMBER  0  DEST:  11 27
# TASK NUMBER  1  DEST:  41 8
# 9.412716206245568
# TASK NUMBER  0  DEST:  33 20
# TASK NUMBER  1  DEST:  31 0
# 10.72760687370528
# TASK NUMBER  0  DEST:  19 34
# TASK NUMBER  1  DEST:  29 0
# 8.375332410244207
# TASK NUMBER  0  DEST:  10 11
# TASK NUMBER  1  DEST:  14 14
# 7.301769317888142
# TASK NUMBER  0  DEST:  8 17
# TASK NUMBER  1  DEST:  15 1
# 23.15805193219811
# TASK NUMBER  0  DEST:  35 9
# TASK NUMBER  1  DEST:  13 25
# 9.888094106805315
# TASK NUMBER  0  DEST:  32 41
# TASK NUMBER  1  DEST:  2 25
# 15.808746961366158
# -------
# TRYOUT[50]: (hidden_dim=128, max_step=500, gamma=0.999, n_episode=2000, buffer_size=65000, batch_size=32, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  5 3
# TASK NUMBER  1  DEST:  42 17
# 6.097909614160455
# TASK NUMBER  0  DEST:  0 27
# TASK NUMBER  1  DEST:  21 48
# 22.719228935196316
# TASK NUMBER  0  DEST:  4 31
# TASK NUMBER  1  DEST:  27 21
# 10.723796120044028
# TASK NUMBER  0  DEST:  5 48
# TASK NUMBER  1  DEST:  40 28
# 18.716886937693708
# TASK NUMBER  0  DEST:  15 10
# TASK NUMBER  1  DEST:  16 32
# 8.422777448472708
# TASK NUMBER  0  DEST:  47 25
# TASK NUMBER  1  DEST:  32 26
# 10.485911863447166
# TASK NUMBER  0  DEST:  15 0
# TASK NUMBER  1  DEST:  12 20
# 6.008121085885004
# TASK NUMBER  0  DEST:  2 10
# TASK NUMBER  1  DEST:  11 30
# 11.487877773639683
# TASK NUMBER  0  DEST:  45 22
# TASK NUMBER  1  DEST:  49 22
# 20.485185708204735
# TASK NUMBER  0  DEST:  42 13
# TASK NUMBER  1  DEST:  31 31
# 21.799977479214277
# -------
# ...
# TASK NUMBER  0  DEST:  43 13
# TASK NUMBER  1  DEST:  49 22
# 12.312063992804752
# TASK NUMBER  0  DEST:  38 6
# TASK NUMBER  1  DEST:  27 49
# 11.556858807563714
# TASK NUMBER  0  DEST:  18 6
# TASK NUMBER  1  DEST:  24 16
# 24.597309801296838
# TASK NUMBER  0  DEST:  26 31
# TASK NUMBER  1  DEST:  9 7
# 7.160710538129987
# TASK NUMBER  0  DEST:  49 14
# TASK NUMBER  1  DEST:  18 18
# 11.847883272957377
# TASK NUMBER  0  DEST:  46 49
# TASK NUMBER  1  DEST:  33 44
# 5.458470757721463
# TASK NUMBER  0  DEST:  8 23
# TASK NUMBER  1  DEST:  11 23
# 7.546266818138501
# TASK NUMBER  0  DEST:  13 6
# TASK NUMBER  1  DEST:  46 4
# 15.020214825995748
# TASK NUMBER  0  DEST:  13 5
# TASK NUMBER  1  DEST:  10 48
# 9.353372495099277
# TASK NUMBER  0  DEST:  1 37
# TASK NUMBER  1  DEST:  28 41
# 6.652422040492111
# -------
# TRYOUT[558]: (hidden_dim=32, max_step=5000, gamma=0.999, n_episode=1000, buffer_size=10000000, batch_size=64, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  10 15
# TASK NUMBER  1  DEST:  33 20
# 26.59950408704993
# TASK NUMBER  0  DEST:  32 36
# TASK NUMBER  1  DEST:  39 7
# 7.7238182424289
# TASK NUMBER  0  DEST:  19 37
# TASK NUMBER  1  DEST:  1 24
# 14.78897159337072
# TASK NUMBER  0  DEST:  43 30
# TASK NUMBER  1  DEST:  35 36
# 5.6512650812007905
# TASK NUMBER  0  DEST:  49 4
# TASK NUMBER  1  DEST:  23 27
# 13.788697116748226
# TASK NUMBER  0  DEST:  27 7
# TASK NUMBER  1  DEST:  18 47
# 11.888065376676673
# TASK NUMBER  0  DEST:  20 16
# TASK NUMBER  1  DEST:  11 44
# 11.256757267774063
# TASK NUMBER  0  DEST:  7 28
# TASK NUMBER  1  DEST:  45 14
# 9.192693654016225
# TASK NUMBER  0  DEST:  9 30
# TASK NUMBER  1  DEST:  12 49
# 9.71650325227014
# TASK NUMBER  0  DEST:  0 12
# TASK NUMBER  1  DEST:  31 1
# 24.50871745641013
# -------
# TRYOUT[559]: (hidden_dim=64, max_step=5000, gamma=0.999, n_episode=1000, buffer_size=10000000, batch_size=64, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  45 41
# TASK NUMBER  1  DEST:  22 44
# 7.135948940242081
# TASK NUMBER  0  DEST:  37 6
# TASK NUMBER  1  DEST:  43 32
# 5.848255763966206
# TASK NUMBER  0  DEST:  7 31
# TASK NUMBER  1  DEST:  3 21
# 33.23608184317297
# TASK NUMBER  0  DEST:  0 14
# TASK NUMBER  1  DEST:  23 22
# 14.614010249123087
# TASK NUMBER  0  DEST:  47 22
# TASK NUMBER  1  DEST:  20 13
# 7.201628132435819
# TASK NUMBER  0  DEST:  23 1
# TASK NUMBER  1  DEST:  27 13
# 8.872218365051001
# TASK NUMBER  0  DEST:  36 36
# TASK NUMBER  1  DEST:  13 8
# 9.811154696546595
# TASK NUMBER  0  DEST:  30 42
# TASK NUMBER  1  DEST:  12 13
# 11.29836461747141
# TASK NUMBER  0  DEST:  34 32
# TASK NUMBER  1  DEST:  2 9
# 10.062714334126241
# TASK NUMBER  0  DEST:  31 49
# TASK NUMBER  1  DEST:  46 39
# 6.281709930230752
# -------
# TRYOUT[560]: (hidden_dim=128, max_step=5000, gamma=0.999, n_episode=1000, buffer_size=10000000, batch_size=64, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  30 5
# TASK NUMBER  1  DEST:  43 38
# 6.64588664913481
# TASK NUMBER  0  DEST:  20 34
# TASK NUMBER  1  DEST:  23 6
# 10.578220095196023
# TASK NUMBER  0  DEST:  45 7
# TASK NUMBER  1  DEST:  6 44
# 18.598140581818903
# TASK NUMBER  0  DEST:  3 46
# TASK NUMBER  1  DEST:  6 48
# 5.589317317905601
# TASK NUMBER  0  DEST:  29 1
# TASK NUMBER  1  DEST:  30 7
# 18.09352738303962
# TASK NUMBER  0  DEST:  18 24
# TASK NUMBER  1  DEST:  37 4
# 10.231532369036216
# TASK NUMBER  0  DEST:  38 0
# TASK NUMBER  1  DEST:  0 1
# 12.292201585539319
# TASK NUMBER  0  DEST:  37 24
# TASK NUMBER  1  DEST:  21 45
# 8.742702101098974
# TASK NUMBER  0  DEST:  16 14
# TASK NUMBER  1  DEST:  47 9
# 15.84331876280664
# TASK NUMBER  0  DEST:  32 21
# TASK NUMBER  1  DEST:  49 33
# 11.445814830569507
# -------
# TRYOUT[561]: (hidden_dim=32, max_step=10000, gamma=0.999, n_episode=1000, buffer_size=10000000, batch_size=64, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  20 0
# TASK NUMBER  1  DEST:  41 16
# 6.475083095995641
# TASK NUMBER  0  DEST:  14 24
# TASK NUMBER  1  DEST:  42 17
# Task  1  completed at step  81
# 27.068986508725047
# TASK NUMBER  0  DEST:  7 31
# TASK NUMBER  1  DEST:  30 29
# 25.4221127504646
# TASK NUMBER  0  DEST:  41 0
# TASK NUMBER  1  DEST:  29 17
# 15.72713649300129
# TASK NUMBER  0  DEST:  1 33
# TASK NUMBER  1  DEST:  36 47
# 5.80999272157272
# TASK NUMBER  0  DEST:  19 26
# TASK NUMBER  1  DEST:  12 27
# 7.7165444949804325
# TASK NUMBER  0  DEST:  34 46
# TASK NUMBER  1  DEST:  49 16
# 13.307337245038303
# TASK NUMBER  0  DEST:  4 14
# TASK NUMBER  1  DEST:  25 37
# 14.346950792957278
# TASK NUMBER  0  DEST:  3 19
# TASK NUMBER  1  DEST:  25 46
# 9.808733910936986
# TASK NUMBER  0  DEST:  41 3
# TASK NUMBER  1  DEST:  27 22
# 13.495322735453618
# -------
# TRYOUT[562]: (hidden_dim=64, max_step=10000, gamma=0.999, n_episode=1000, buffer_size=10000000, batch_size=64, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  6 28
# TASK NUMBER  1  DEST:  11 32
# 8.11505488990855
# TASK NUMBER  0  DEST:  23 19
# TASK NUMBER  1  DEST:  11 26
# 7.950984056621362
# TASK NUMBER  0  DEST:  42 32
# TASK NUMBER  1  DEST:  18 15
# 24.167447493117805
# TASK NUMBER  0  DEST:  35 17
# TASK NUMBER  1  DEST:  26 8
# 10.623960613119253
# TASK NUMBER  0  DEST:  40 33
# TASK NUMBER  1  DEST:  20 19
# 18.306417117943433
# TASK NUMBER  0  DEST:  1 12
# TASK NUMBER  1  DEST:  40 16
# Task  1  completed at step  28
# 23.42139123028399
# TASK NUMBER  0  DEST:  42 18
# TASK NUMBER  1  DEST:  22 40
# 17.747928990479043
# TASK NUMBER  0  DEST:  40 20
# TASK NUMBER  1  DEST:  24 21
# 11.741676984258364
# TASK NUMBER  0  DEST:  3 11
# TASK NUMBER  1  DEST:  25 9
# 13.849835291865547
# TASK NUMBER  0  DEST:  13 4
# TASK NUMBER  1  DEST:  47 6
# 17.532836319883884
# -------
# TRYOUT[563]: (hidden_dim=128, max_step=10000, gamma=0.999, n_episode=1000, buffer_size=10000000, batch_size=64, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  39 22
# TASK NUMBER  1  DEST:  45 18
# 16.541155485626778
# TASK NUMBER  0  DEST:  1 45
# TASK NUMBER  1  DEST:  39 0
# 6.804187016650659
# TASK NUMBER  0  DEST:  25 6
# TASK NUMBER  1  DEST:  24 25
# 10.098332355821125
# TASK NUMBER  0  DEST:  0 5
# TASK NUMBER  1  DEST:  46 48
# Task  1  completed at step  102
# 35.631167563923455
# TASK NUMBER  0  DEST:  16 36
# TASK NUMBER  1  DEST:  6 9
# 9.160988378105126
# TASK NUMBER  0  DEST:  41 45
# TASK NUMBER  1  DEST:  33 37
# 25.16592389017187
# TASK NUMBER  0  DEST:  25 43
# TASK NUMBER  1  DEST:  0 24
# 11.512218566804318
# TASK NUMBER  0  DEST:  45 38
# TASK NUMBER  1  DEST:  12 17
# 11.549969120611442
# TASK NUMBER  0  DEST:  29 25
# TASK NUMBER  1  DEST:  1 4
# 11.513519307188727
# TASK NUMBER  0  DEST:  39 12
# TASK NUMBER  1  DEST:  28 12
# 7.5618284929217285
# -------
# TRYOUT[564]: (hidden_dim=32, max_step=500, gamma=0.9999, n_episode=1000, buffer_size=10000000, batch_size=64, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  42 4
# TASK NUMBER  1  DEST:  26 13
# 8.83378784860645
# TASK NUMBER  0  DEST:  2 12
# TASK NUMBER  1  DEST:  0 37
# 6.918518874721576
# TASK NUMBER  0  DEST:  1 30
# TASK NUMBER  1  DEST:  33 40
# 8.905496434984304
# TASK NUMBER  0  DEST:  20 44
# TASK NUMBER  1  DEST:  18 45
# 6.91144410906122
# TASK NUMBER  0  DEST:  2 29
# TASK NUMBER  1  DEST:  32 32
# 15.740903453630642
# TASK NUMBER  0  DEST:  34 10
# TASK NUMBER  1  DEST:  42 24
# 23.191110549499147
# TASK NUMBER  0  DEST:  15 20
# TASK NUMBER  1  DEST:  14 18
# 19.19930514944345
# TASK NUMBER  0  DEST:  9 35
# TASK NUMBER  1  DEST:  34 46
# 16.509633462586006
# TASK NUMBER  0  DEST:  16 46
# TASK NUMBER  1  DEST:  10 33
# 13.11435536808026
# TASK NUMBER  0  DEST:  27 28
# TASK NUMBER  1  DEST:  32 4
# 8.138116857268262
# -------
# TRYOUT[565]: (hidden_dim=64, max_step=500, gamma=0.9999, n_episode=1000, buffer_size=10000000, batch_size=64, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  14 30
# TASK NUMBER  1  DEST:  16 37
# 10.143609356729046
# TASK NUMBER  0  DEST:  20 44
# TASK NUMBER  1  DEST:  10 14
# 12.548382947057904
# TASK NUMBER  0  DEST:  44 0
# TASK NUMBER  1  DEST:  19 1
# 7.32086057720565
# TASK NUMBER  0  DEST:  42 25
# TASK NUMBER  1  DEST:  24 17
# 16.319377284444144
# TASK NUMBER  0  DEST:  13 5
# TASK NUMBER  1  DEST:  38 33
# 8.514365514699696
# TASK NUMBER  0  DEST:  41 21
# TASK NUMBER  1  DEST:  42 14
# 8.47191851422863
# TASK NUMBER  0  DEST:  37 36
# TASK NUMBER  1  DEST:  9 34
# 12.149639449806035
# TASK NUMBER  0  DEST:  22 25
# TASK NUMBER  1  DEST:  38 14
# 17.002449310580683
# TASK NUMBER  0  DEST:  38 5
# TASK NUMBER  1  DEST:  16 21
# 15.396776246639194
# TASK NUMBER  0  DEST:  21 34
# TASK NUMBER  1  DEST:  9 36
# 9.106699606206929
# -------
# TRYOUT[566]: (hidden_dim=128, max_step=500, gamma=0.9999, n_episode=1000, buffer_size=10000000, batch_size=64, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  30 14
# TASK NUMBER  1  DEST:  42 20
# 6.1364348836805584
# TASK NUMBER  0  DEST:  41 17
# TASK NUMBER  1  DEST:  35 44
# 14.734567063475993
# TASK NUMBER  0  DEST:  35 7
# TASK NUMBER  1  DEST:  8 36
# 22.72226013525523
# TASK NUMBER  0  DEST:  27 1
# TASK NUMBER  1  DEST:  36 31
# 12.855460960744958
# TASK NUMBER  0  DEST:  39 40
# TASK NUMBER  1  DEST:  29 7
# 8.552546002912653
# TASK NUMBER  0  DEST:  0 32
# TASK NUMBER  1  DEST:  15 46
# 5.437117691873856
# TASK NUMBER  0  DEST:  25 34
# TASK NUMBER  1  DEST:  23 5
# 10.693242870205204
# TASK NUMBER  0  DEST:  48 5
# TASK NUMBER  1  DEST:  13 29
# 9.082785730542573
# TASK NUMBER  0  DEST:  11 44
# TASK NUMBER  1  DEST:  10 23
# 11.159348767646401
# TASK NUMBER  0  DEST:  8 28
# TASK NUMBER  1  DEST:  17 23
# 7.398010876910147
# -------
# TRYOUT[567]: (hidden_dim=32, max_step=1000, gamma=0.9999, n_episode=1000, buffer_size=10000000, batch_size=64, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  31 47
# TASK NUMBER  1  DEST:  19 23
# 10.957960686338073
# TASK NUMBER  0  DEST:  25 26
# TASK NUMBER  1  DEST:  19 7
# 11.169419247558467
# TASK NUMBER  0  DEST:  22 13
# TASK NUMBER  1  DEST:  26 24
# 10.444171199325972
# TASK NUMBER  0  DEST:  35 39
# TASK NUMBER  1  DEST:  1 7
# 21.23342809445838
# TASK NUMBER  0  DEST:  47 11
# TASK NUMBER  1  DEST:  24 8
# 7.090300622386235
# TASK NUMBER  0  DEST:  38 13
# TASK NUMBER  1  DEST:  40 20
# 12.11321467282997
# TASK NUMBER  0  DEST:  38 45
# TASK NUMBER  1  DEST:  11 14
# 9.175592969466216
# TASK NUMBER  0  DEST:  16 8
# TASK NUMBER  1  DEST:  46 29
# 7.832817135892321
# TASK NUMBER  0  DEST:  48 3
# TASK NUMBER  1  DEST:  4 30
# 9.704629866965119
# TASK NUMBER  0  DEST:  30 31
# TASK NUMBER  1  DEST:  18 48
# 19.230245548671277
# -------
# TRYOUT[568]: (hidden_dim=64, max_step=1000, gamma=0.9999, n_episode=1000, buffer_size=10000000, batch_size=64, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  28 46
# TASK NUMBER  1  DEST:  26 19
# 24.18460817945049
# TASK NUMBER  0  DEST:  42 44
# TASK NUMBER  1  DEST:  24 16
# 11.064665159716045
# TASK NUMBER  0  DEST:  1 12
# TASK NUMBER  1  DEST:  32 43
# 7.594529459001176
# TASK NUMBER  0  DEST:  19 11
# TASK NUMBER  1  DEST:  22 43
# 15.40973566140887
# TASK NUMBER  0  DEST:  1 32
# TASK NUMBER  1  DEST:  27 24
# 10.21546741757591
# TASK NUMBER  0  DEST:  48 13
# TASK NUMBER  1  DEST:  16 28
# 13.738568735539149
# TASK NUMBER  0  DEST:  12 1
# TASK NUMBER  1  DEST:  16 18
# 9.587811416773908
# TASK NUMBER  0  DEST:  22 35
# TASK NUMBER  1  DEST:  17 44
# 9.74769417089723
# TASK NUMBER  0  DEST:  35 30
# TASK NUMBER  1  DEST:  47 46
# 8.34845029286377
# TASK NUMBER  0  DEST:  3 44
# TASK NUMBER  1  DEST:  34 3
# 8.850626674488192
# -------
# TRYOUT[569]: (hidden_dim=128, max_step=1000, gamma=0.9999, n_episode=1000, buffer_size=10000000, batch_size=64, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  2 28
# TASK NUMBER  1  DEST:  46 18
# 7.561160772994859
# TASK NUMBER  0  DEST:  44 5
# TASK NUMBER  1  DEST:  11 45
# 10.098823440109447
# TASK NUMBER  0  DEST:  42 7
# TASK NUMBER  1  DEST:  24 10
# 12.979136105050287
# TASK NUMBER  0  DEST:  26 20
# TASK NUMBER  1  DEST:  37 33
# 11.820554543477945
# TASK NUMBER  0  DEST:  2 23
# TASK NUMBER  1  DEST:  28 39
# 11.857715683232733
# TASK NUMBER  0  DEST:  32 32
# TASK NUMBER  1  DEST:  41 32
# 14.452433273796183
# TASK NUMBER  0  DEST:  28 26
# TASK NUMBER  1  DEST:  36 6
# 7.37714956048587
# TASK NUMBER  0  DEST:  37 0
# TASK NUMBER  1  DEST:  41 38
# 6.567487099957626
# TASK NUMBER  0  DEST:  31 40
# TASK NUMBER  1  DEST:  40 0
# 10.985481285526456
# TASK NUMBER  0  DEST:  29 14
# TASK NUMBER  1  DEST:  3 38
# 20.848966193035153
# -------
# TRYOUT[570]: (hidden_dim=32, max_step=5000, gamma=0.9999, n_episode=1000, buffer_size=10000000, batch_size=64, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  22 34
# TASK NUMBER  1  DEST:  40 48
# 9.802157390847208
# TASK NUMBER  0  DEST:  43 20
# TASK NUMBER  1  DEST:  9 25
# 19.107538565627138
# TASK NUMBER  0  DEST:  35 27
# TASK NUMBER  1  DEST:  16 34
# 11.491240239418522
# TASK NUMBER  0  DEST:  25 4
# TASK NUMBER  1  DEST:  24 10
# 12.091014302744673
# TASK NUMBER  0  DEST:  18 28
# TASK NUMBER  1  DEST:  29 1
# 8.0541089545755
# TASK NUMBER  0  DEST:  8 4
# TASK NUMBER  1  DEST:  9 16
# 21.17548017681801
# TASK NUMBER  0  DEST:  32 32
# TASK NUMBER  1  DEST:  9 27
# 33.23416217998395
# TASK NUMBER  0  DEST:  9 40
# TASK NUMBER  1  DEST:  27 27
# 12.069152741816616
# TASK NUMBER  0  DEST:  24 21
# TASK NUMBER  1  DEST:  15 41
# 26.912499973818683
# TASK NUMBER  0  DEST:  29 20
# TASK NUMBER  1  DEST:  38 8
# Task  0  completed at step  50
# 27.11342653589691
# -------
# TRYOUT[571]: (hidden_dim=64, max_step=5000, gamma=0.9999, n_episode=1000, buffer_size=10000000, batch_size=64, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  15 25
# TASK NUMBER  1  DEST:  19 26
# 12.58868342833885
# TASK NUMBER  0  DEST:  28 46
# TASK NUMBER  1  DEST:  41 7
# 21.65733481786556
# TASK NUMBER  0  DEST:  41 18
# TASK NUMBER  1  DEST:  20 4
# 25.405133583030654
# TASK NUMBER  0  DEST:  2 43
# TASK NUMBER  1  DEST:  6 20
# 7.226749499713773
# TASK NUMBER  0  DEST:  8 8
# TASK NUMBER  1  DEST:  16 25
# 11.33130916106868
# TASK NUMBER  0  DEST:  45 44
# TASK NUMBER  1  DEST:  12 16
# 8.109715782579164
# TASK NUMBER  0  DEST:  44 33
# TASK NUMBER  1  DEST:  40 44
# 8.475833705397694
# TASK NUMBER  0  DEST:  25 8
# TASK NUMBER  1  DEST:  32 43
# 15.826423544462031
# TASK NUMBER  0  DEST:  35 47
# TASK NUMBER  1  DEST:  0 26
# 13.54789242746598
# TASK NUMBER  0  DEST:  24 12
# TASK NUMBER  1  DEST:  43 48
# 11.858175073659911
# -------
# TRYOUT[572]: (hidden_dim=128, max_step=5000, gamma=0.9999, n_episode=1000, buffer_size=10000000, batch_size=64, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  37 4
# TASK NUMBER  1  DEST:  41 34
# 17.08624256693827
# TASK NUMBER  0  DEST:  24 44
# TASK NUMBER  1  DEST:  31 8
# 8.78816669913119
# TASK NUMBER  0  DEST:  23 7
# TASK NUMBER  1  DEST:  39 21
# 7.900518591455518
# TASK NUMBER  0  DEST:  37 43
# TASK NUMBER  1  DEST:  12 1
# 13.16017596798706
# TASK NUMBER  0  DEST:  41 28
# TASK NUMBER  1  DEST:  22 17
# 9.811703621805435
# TASK NUMBER  0  DEST:  29 16
# TASK NUMBER  1  DEST:  42 48
# 6.889064497616781
# TASK NUMBER  0  DEST:  36 43
# TASK NUMBER  1  DEST:  41 49
# 43.14396597098595
# TASK NUMBER  0  DEST:  17 35
# TASK NUMBER  1  DEST:  31 36
# 20.264070434897988
# TASK NUMBER  0  DEST:  44 22
# TASK NUMBER  1  DEST:  16 30
# 9.159020397421871
# TASK NUMBER  0  DEST:  44 17
# TASK NUMBER  1  DEST:  35 23
# 13.32466280810005
# -------
# TRYOUT[573]: (hidden_dim=32, max_step=10000, gamma=0.9999, n_episode=1000, buffer_size=10000000, batch_size=64, n_epoch=25, epsilon=0.5, tau=0.5, learning_rate=0.0005)
# TASK NUMBER  0  DEST:  23 6
# TASK NUMBER  1  DEST:  43 47
# 8.408649483161106
# TASK NUMBER  0  DEST:  25 45
# TASK NUMBER  1  DEST:  32 12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-041357441f02> in <module>
#       1 training = Training('VIZIER_OUTPUT.txt', True)
#       2 # print(3*4*3*3*3*3*3*3*3*4)
# ----> 3 training.train()
#
# <ipython-input-29-fbe23855e030> in train(self)
#     119                     steps+=1
#     120                     # Get the action with forward prop and add the obs, adjs to replay buffer
# --> 121                     q = model(torch.Tensor(np.array([obs])).cuda(), torch.Tensor(np.array([adj])).cuda())[0,0,:]
#     122                     if np.random.rand() < self.epsilon:
#     123                         action = np.random.randint(n_actions)
#
# KeyboardInterrupt:

# %% [markdown]
# https://github.com/jiechuanjiang/pytorch_DGN/blob/main/Surviving/DGN%2BATOC/main.py

# %%
env = GridWorldWithCare(NUM_TASKS)
observation_space = env.len_obs
n_actions = env.n_action
n_tasks = env.n_tasks

buff = ReplayBufferGCare(buffer_size,observation_space,n_actions,n_tasks)
model = MTRL_DGN(n_tasks,observation_space,hidden_dim,n_actions)
model_tar = MTRL_DGN(n_tasks,observation_space,hidden_dim,n_actions)
model = model.cuda()
model_tar = model_tar.cuda()
optimizer = optim.Adam(model.parameters(), lr = 0.001)
# att = MTRL_ATT(observation_space).cuda()
# att_tar = MTRL_ATT(observation_space).cuda()
# att_tar.load_state_dict(att.state_dict())
# optimizer_att = optim.Adam(att.parameters(), lr = 0.001)
criterion = nn.BCELoss()

M_Null = torch.Tensor(np.array([np.eye(n_tasks)]*batch_size)).cuda()
M_ZERO = torch.Tensor(np.zeros((batch_size,n_tasks,n_tasks))).cuda()
# threshold = float(sys.argv[1]) TODO: figure this out
# f = open(sys.argv[1]+'-'+sys.argv[2]+'.txt','w+')
f = open("TRIAL-9-SoftAttention-Concat.txt", "w+")
while i_episode<n_episode:
    if i_episode > 40:
        epsilon -= 0.001
        if epsilon < 0.01:
            epsilon = 0.01
    i_episode+=1
    steps = 0
    obs, adj = env.reset()
    obs = np.resize(obs, (n_tasks, observation_space))
    while steps < max_step:
        steps+=1 
#         cost_all += adj.sum()
#         v_a = np.array(att(torch.Tensor(np.array([obs])).cuda())[0].cpu().data)
#         for i in range(n_tasks):
#             if np.random.rand() < epsilon:
#                 adj[i] = adj[i]*0 if np.random.rand() < 0.5 else adj[i]*1
#             else:
#                 adj[i] = adj[i]*0 if v_a[i][0] < threshold else adj[i]*1
        # Note: above loop is epsilon greedy exploration to give less importance to observations that fall below a certain threshold
        # May not be needed if we use single encoder but could be useful in the case of mixture of encoders
        # Pruning "less imp" neighbours whose obs fall below a certain threshold
#         n_adj = adj*comm_flag
#         cost_comm += n_adj.sum()
#         n_adj = n_adj + np.eye(n_tasks)
#         q_dummy = model(torch.Tensor(np.array([obs])).cuda(), torch.Tensor(np.array([adj])).cuda())
#         print("model output shape", q_dummy.shape)
        q = model(torch.Tensor(np.array([obs])).cuda(), torch.Tensor(np.array([adj])).cuda())[0,0,:]
#         print("Shape of Q: ", q.shape)
        if np.random.rand() < epsilon:
#             print("HERE RANDOM")
            a = np.random.randint(n_actions)
        else:
#             print("HERE FROM MODEL")
            a = q.argmax().item()

        action = a
        
        next_obs, next_adj, reward, terminated = env.step(action)
#         print('action: {}, next_obs: {}\nnext_adj:\n{}'.format(
#             action, next_obs, next_adj
#         ))
        
        next_obs = np.resize(next_obs, (n_tasks, observation_space))
        
        buff.add(np.array(obs),action,reward,np.array(next_obs),adj,next_adj,terminated)
        
        obs = next_obs
        adj = next_adj
        score += reward

    if i_episode%20==0:
        print(score)
        #print(score/2000)
        f.write(str(score)+'\n')
        # Cost (neighbors in adj matrix)after pruning/ Cost before pruning
        f.flush()
        score = 0

#     if i_episode < 40:
#         continue

    for e in range(n_epoch):

        O,A,R,Next_O,Matrix,Next_Matrix,D = buff.getBatch(batch_size)
        O = torch.Tensor(O).cuda()
        Matrix = torch.Tensor(Matrix).cuda()
        Next_O = torch.Tensor(Next_O).cuda()
        Next_Matrix = torch.Tensor(Next_Matrix).cuda()

#         label = model(Next_O, Next_Matrix+M_Null).max(dim = 2)[0] - model(Next_O, M_Null).max(dim = 2)[0]
#         #print("Label", label.shape)
#         label = (label - label.mean())/(label.std()+0.000001) + 0.5
#         label = torch.clamp(label, 0, 1).unsqueeze(-1).detach()
#         #print("Label after clamping", label.shape)
#         #print("ATT output", label_dummy.shape)
#         loss = criterion(a(Next_O), label)
#         optimizer_att.zero_grad()
#         loss.backward()
#         optimizer_att.step()
        # Basically att is learning which obs from the maze help return the max q value

#         V_A_D = att_tar(Next_O).expand(-1,-1,n_ant)
#         Next_Matrix = torch.where(V_A_D > threshold, Next_Matrix, M_ZERO)
#         Next_Matrix = Next_Matrix*comm_flag + M_Null

        q_values = model(O, Matrix)
#         print("Q Vals Before slicing: ", q_values.shape)
        q_values = model(O, Matrix)[:,0, :]
#         print("Q Vals After slicing: ", q_values_final.shape)
        target_q_values = model_tar(Next_O, Next_Matrix).max(dim = 2)[0][:,0]
#         print("Target Q Vals: ", target_q_values.shape)
        target_q_values = np.array(target_q_values.cpu().data)
        expected_q = np.array(q_values.cpu().data)

        for j in range(batch_size):
#             for i in range(n_tasks):
            expected_q[j][A[j][0]] = R[j][0] + (1-D[j][0])*GAMMA*target_q_values[j]

        loss = (q_values - torch.Tensor(expected_q).cuda()).pow(2).mean()
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if e%10 == 0:
            with torch.no_grad():
                for p, p_targ in zip(model.parameters(), model_tar.parameters()):
                    p_targ.data.mul_(tau)
                    p_targ.data.add_((1 - tau) * p.data)
#                 for p, p_targ in zip(att.parameters(), att_tar.parameters()):
#                     p_targ.data.mul_(tau)
#                     p_targ.data.add_((1 - tau) * p.data)
# Out:
# TASK NUMBER  0  DEST:  27 20
# TASK NUMBER  1  DEST:  19 16
# TASK NUMBER  0  DEST:  26 3
# TASK NUMBER  1  DEST:  38 3
# TASK NUMBER  0  DEST:  8 25
# TASK NUMBER  1  DEST:  30 13
# TASK NUMBER  0  DEST:  14 31
# TASK NUMBER  1  DEST:  32 8
# TASK NUMBER  0  DEST:  2 31
# TASK NUMBER  1  DEST:  11 3
# TASK NUMBER  0  DEST:  39 35
# TASK NUMBER  1  DEST:  30 8
# TASK NUMBER  0  DEST:  32 1
# TASK NUMBER  1  DEST:  29 31
# TASK NUMBER  0  DEST:  21 0
# TASK NUMBER  1  DEST:  29 46
# TASK NUMBER  0  DEST:  21 37
# TASK NUMBER  1  DEST:  38 11
# TASK NUMBER  0  DEST:  33 35
# TASK NUMBER  1  DEST:  20 17
# TASK NUMBER  0  DEST:  34 35
# TASK NUMBER  1  DEST:  49 5
# TASK NUMBER  0  DEST:  28 5
# TASK NUMBER  1  DEST:  10 24
# TASK NUMBER  0  DEST:  42 27
# TASK NUMBER  1  DEST:  7 10
# TASK NUMBER  0  DEST:  6 17
# TASK NUMBER  1  DEST:  16 29
# Task  0  completed at step  148
# TASK NUMBER  0  DEST:  33 13
# TASK NUMBER  1  DEST:  23 46
# Task  1  completed at step  559
# TASK NUMBER  0  DEST:  35 44
# TASK NUMBER  1  DEST:  19 16
# TASK NUMBER  0  DEST:  24 1
# TASK NUMBER  1  DEST:  13 13
# TASK NUMBER  0  DEST:  15 46
# TASK NUMBER  1  DEST:  40 18
# 8230.462170060162
# TASK NUMBER  0  DEST:  26 36
# TASK NUMBER  1  DEST:  6 2
# TASK NUMBER  0  DEST:  46 15
# TASK NUMBER  1  DEST:  31 22
# TASK NUMBER  0  DEST:  25 18
# TASK NUMBER  1  DEST:  47 34
# TASK NUMBER  0  DEST:  37 21
# TASK NUMBER  1  DEST:  23 48
# TASK NUMBER  0  DEST:  33 17
# TASK NUMBER  1  DEST:  24 6
# TASK NUMBER  0  DEST:  39 11
# TASK NUMBER  1  DEST:  11 27
# TASK NUMBER  0  DEST:  10 16
# TASK NUMBER  1  DEST:  36 38
# TASK NUMBER  0  DEST:  44 10
# TASK NUMBER  1  DEST:  6 40
# TASK NUMBER  0  DEST:  48 5
# TASK NUMBER  1  DEST:  38 27
# Task  0  completed at step  4995
# TASK NUMBER  0  DEST:  0 22
# TASK NUMBER  1  DEST:  7 12
# TASK NUMBER  0  DEST:  4 16
# TASK NUMBER  1  DEST:  19 1
# Task  1  completed at step  561
# TASK NUMBER  0  DEST:  48 33
# TASK NUMBER  1  DEST:  31 35
# TASK NUMBER  0  DEST:  10 19
# TASK NUMBER  1  DEST:  31 28
# TASK NUMBER  0  DEST:  42 41
# TASK NUMBER  1  DEST:  23 38
# TASK NUMBER  0  DEST:  0 44
# TASK NUMBER  1  DEST:  38 43
# Task  0  completed at step  3532
# TASK NUMBER  0  DEST:  11 26
# TASK NUMBER  1  DEST:  24 36
# TASK NUMBER  0  DEST:  15 7
# TASK NUMBER  1  DEST:  29 21
# TASK NUMBER  0  DEST:  24 34
# TASK NUMBER  1  DEST:  36 23
# TASK NUMBER  0  DEST:  9 6
# TASK NUMBER  1  DEST:  18 3
# Task  1  completed at step  49
# TASK NUMBER  0  DEST:  20 9
# TASK NUMBER  1  DEST:  41 34
# 11695.582467680135
# TASK NUMBER  0  DEST:  29 14
# TASK NUMBER  1  DEST:  26 16
# Task  0  completed at step  2354
# TASK NUMBER  0  DEST:  48 48
# TASK NUMBER  1  DEST:  23 31
# TASK NUMBER  0  DEST:  31 37
# TASK NUMBER  1  DEST:  40 12
# TASK NUMBER  0  DEST:  36 34
# TASK NUMBER  1  DEST:  16 46
# TASK NUMBER  0  DEST:  19 42
# TASK NUMBER  1  DEST:  32 42
# TASK NUMBER  0  DEST:  21 21
# TASK NUMBER  1  DEST:  7 15
# Task  1  completed at step  215
# TASK NUMBER  0  DEST:  39 3
# TASK NUMBER  1  DEST:  1 44
# TASK NUMBER  0  DEST:  41 37
# TASK NUMBER  1  DEST:  6 19
# TASK NUMBER  0  DEST:  38 41
# TASK NUMBER  1  DEST:  40 18
# Task  1  completed at step  3892
# TASK NUMBER  0  DEST:  26 17
# TASK NUMBER  1  DEST:  4 7
# Task  1  completed at step  260
# TASK NUMBER  0  DEST:  11 41
# TASK NUMBER  1  DEST:  24 39
# TASK NUMBER  0  DEST:  19 31
# TASK NUMBER  1  DEST:  35 33
# TASK NUMBER  0  DEST:  22 15
# TASK NUMBER  1  DEST:  15 47
# TASK NUMBER  0  DEST:  24 15
# TASK NUMBER  1  DEST:  33 6
# TASK NUMBER  0  DEST:  48 35
# TASK NUMBER  1  DEST:  36 25
# Task  1  completed at step  365
# TASK NUMBER  0  DEST:  34 47
# TASK NUMBER  1  DEST:  7 25
# Task  1  completed at step  1529
# TASK NUMBER  0  DEST:  48 24
# TASK NUMBER  1  DEST:  32 10
# Task  1  completed at step  639
# TASK NUMBER  0  DEST:  21 19
# TASK NUMBER  1  DEST:  22 48
# TASK NUMBER  0  DEST:  46 33
# TASK NUMBER  1  DEST:  35 18
# Task  1  completed at step  519
# TASK NUMBER  0  DEST:  2 30
# TASK NUMBER  1  DEST:  25 33
# 19864.91632421636
# TASK NUMBER  0  DEST:  4 3
# TASK NUMBER  1  DEST:  6 31
# TASK NUMBER  0  DEST:  3 4
# TASK NUMBER  1  DEST:  44 48
# TASK NUMBER  0  DEST:  37 41
# TASK NUMBER  1  DEST:  16 13
# Task  1  completed at step  1198
# TASK NUMBER  0  DEST:  14 10
# TASK NUMBER  1  DEST:  21 48
# TASK NUMBER  0  DEST:  28 3
# TASK NUMBER  1  DEST:  34 43
# TASK NUMBER  0  DEST:  45 7
# TASK NUMBER  1  DEST:  15 30
# TASK NUMBER  0  DEST:  8 3
# TASK NUMBER  1  DEST:  27 9
# TASK NUMBER  0  DEST:  24 32
# TASK NUMBER  1  DEST:  44 1
# TASK NUMBER  0  DEST:  0 7
# TASK NUMBER  1  DEST:  39 1
# TASK NUMBER  0  DEST:  34 46
# TASK NUMBER  1  DEST:  18 40
# TASK NUMBER  0  DEST:  11 49
# TASK NUMBER  1  DEST:  24 20
# TASK NUMBER  0  DEST:  48 16
# TASK NUMBER  1  DEST:  40 19
# Task  0  completed at step  1533
# TASK NUMBER  0  DEST:  33 5
# TASK NUMBER  1  DEST:  37 47
# Task  1  completed at step  4469
# TASK NUMBER  0  DEST:  9 21
# TASK NUMBER  1  DEST:  48 20
# TASK NUMBER  0  DEST:  0 41
# TASK NUMBER  1  DEST:  20 6
# TASK NUMBER  0  DEST:  33 35
# TASK NUMBER  1  DEST:  0 14
# TASK NUMBER  0  DEST:  27 15
# TASK NUMBER  1  DEST:  20 33
# TASK NUMBER  0  DEST:  32 1
# TASK NUMBER  1  DEST:  41 33
# TASK NUMBER  0  DEST:  23 21
# TASK NUMBER  1  DEST:  49 27
# TASK NUMBER  0  DEST:  14 7
# TASK NUMBER  1  DEST:  40 21
# 15151.655015206592
# TASK NUMBER  0  DEST:  26 22
# TASK NUMBER  1  DEST:  4 24
# Task  1  completed at step  4654
# TASK NUMBER  0  DEST:  25 28
# TASK NUMBER  1  DEST:  38 16
# Task  1  completed at step  531
# TASK NUMBER  0  DEST:  11 16
# TASK NUMBER  1  DEST:  7 29
# TASK NUMBER  0  DEST:  46 21
# TASK NUMBER  1  DEST:  17 44
# TASK NUMBER  0  DEST:  21 33
# TASK NUMBER  1  DEST:  40 41
# Task  1  completed at step  39
# TASK NUMBER  0  DEST:  29 33
# TASK NUMBER  1  DEST:  5 44
# TASK NUMBER  0  DEST:  10 5
# TASK NUMBER  1  DEST:  6 19
# Task  1  completed at step  69
# TASK NUMBER  0  DEST:  2 33
# TASK NUMBER  1  DEST:  17 5
# TASK NUMBER  0  DEST:  40 1
# TASK NUMBER  1  DEST:  41 1
# TASK NUMBER  0  DEST:  11 35
# TASK NUMBER  1  DEST:  6 49
# Task  1  completed at step  794
# TASK NUMBER  0  DEST:  42 28
# TASK NUMBER  1  DEST:  48 14
# Task  1  completed at step  75
# TASK NUMBER  0  DEST:  40 25
# TASK NUMBER  1  DEST:  23 12
# Task  0  completed at step  20
# Task  1  completed at step  360
# TASK NUMBER  0  DEST:  8 11
# TASK NUMBER  1  DEST:  26 35
# TASK NUMBER  0  DEST:  44 24
# TASK NUMBER  1  DEST:  11 12
# TASK NUMBER  0  DEST:  26 47
# TASK NUMBER  1  DEST:  46 39
# TASK NUMBER  0  DEST:  7 0
# TASK NUMBER  1  DEST:  15 41
# TASK NUMBER  0  DEST:  3 47
# TASK NUMBER  1  DEST:  46 23
# TASK NUMBER  0  DEST:  4 11
# TASK NUMBER  1  DEST:  18 6
# Task  0  completed at step  77
# Task  1  completed at step  2002
# TASK NUMBER  0  DEST:  37 13
# TASK NUMBER  1  DEST:  49 47
# TASK NUMBER  0  DEST:  14 36
# TASK NUMBER  1  DEST:  37 30
# Task  1  completed at step  1437
# 24570.936535092835
# TASK NUMBER  0  DEST:  4 7
# TASK NUMBER  1  DEST:  47 49
# TASK NUMBER  0  DEST:  6 18
# TASK NUMBER  1  DEST:  23 7
# Task  1  completed at step  126
# TASK NUMBER  0  DEST:  21 43
# TASK NUMBER  1  DEST:  7 23
# TASK NUMBER  0  DEST:  11 33
# TASK NUMBER  1  DEST:  22 6
# TASK NUMBER  0  DEST:  27 45
# TASK NUMBER  1  DEST:  6 41
# TASK NUMBER  0  DEST:  49 28
# TASK NUMBER  1  DEST:  35 24
# TASK NUMBER  0  DEST:  19 14
# TASK NUMBER  1  DEST:  44 49
# TASK NUMBER  0  DEST:  46 12
# TASK NUMBER  1  DEST:  29 44
# TASK NUMBER  0  DEST:  49 2
# TASK NUMBER  1  DEST:  12 43
# TASK NUMBER  0  DEST:  13 1
# TASK NUMBER  1  DEST:  27 3
# Task  0  completed at step  12
# TASK NUMBER  0  DEST:  34 21
# TASK NUMBER  1  DEST:  0 45
# TASK NUMBER  0  DEST:  1 8
# TASK NUMBER  1  DEST:  5 49
# Task  1  completed at step  3890
# TASK NUMBER  0  DEST:  42 9
# TASK NUMBER  1  DEST:  15 46
# Task  1  completed at step  1207
# TASK NUMBER  0  DEST:  0 45
# TASK NUMBER  1  DEST:  34 27
# TASK NUMBER  0  DEST:  2 48
# TASK NUMBER  1  DEST:  9 40
# TASK NUMBER  0  DEST:  25 21
# TASK NUMBER  1  DEST:  19 23
# Task  1  completed at step  61
# TASK NUMBER  0  DEST:  9 36
# TASK NUMBER  1  DEST:  4 46
# TASK NUMBER  0  DEST:  16 23
# TASK NUMBER  1  DEST:  25 47
# Task  1  completed at step  3514
# TASK NUMBER  0  DEST:  38 9
# TASK NUMBER  1  DEST:  41 23
# Task  1  completed at step  617
# TASK NUMBER  0  DEST:  2 37
# TASK NUMBER  1  DEST:  32 47
# 20971.762072413138
# TASK NUMBER  0  DEST:  42 29
# TASK NUMBER  1  DEST:  3 18
# Task  1  completed at step  85
# TASK NUMBER  0  DEST:  25 45
# TASK NUMBER  1  DEST:  14 27
# TASK NUMBER  0  DEST:  8 15
# TASK NUMBER  1  DEST:  28 43
# TASK NUMBER  0  DEST:  22 13
# TASK NUMBER  1  DEST:  40 26
# Task  1  completed at step  1501
# TASK NUMBER  0  DEST:  32 29
# TASK NUMBER  1  DEST:  29 26
# Task  0  completed at step  1775
# Task  1  completed at step  1859
# TASK NUMBER  0  DEST:  49 42
# TASK NUMBER  1  DEST:  48 49
# TASK NUMBER  0  DEST:  20 46
# TASK NUMBER  1  DEST:  27 15
# TASK NUMBER  0  DEST:  31 30
# TASK NUMBER  1  DEST:  26 49
# TASK NUMBER  0  DEST:  30 11
# TASK NUMBER  1  DEST:  38 46
# Task  1  completed at step  108
# TASK NUMBER  0  DEST:  0 46
# TASK NUMBER  1  DEST:  38 23
# TASK NUMBER  0  DEST:  49 24
# TASK NUMBER  1  DEST:  25 16
# Task  1  completed at step  2980
# TASK NUMBER  0  DEST:  25 22
# TASK NUMBER  1  DEST:  6 47
# TASK NUMBER  0  DEST:  41 40
# TASK NUMBER  1  DEST:  36 33
# TASK NUMBER  0  DEST:  42 47
# TASK NUMBER  1  DEST:  21 21
# TASK NUMBER  0  DEST:  48 27
# TASK NUMBER  1  DEST:  5 10
# Task  0  completed at step  371
# TASK NUMBER  0  DEST:  17 43
# TASK NUMBER  1  DEST:  14 39
# TASK NUMBER  0  DEST:  11 28
# TASK NUMBER  1  DEST:  42 32
# TASK NUMBER  0  DEST:  1 12
# TASK NUMBER  1  DEST:  45 31
# Task  1  completed at step  2261
# TASK NUMBER  0  DEST:  23 22
# TASK NUMBER  1  DEST:  6 35
# Task  1  completed at step  26
# TASK NUMBER  0  DEST:  30 33
# TASK NUMBER  1  DEST:  28 0
# 20842.858327171056
# TASK NUMBER  0  DEST:  21 48
# TASK NUMBER  1  DEST:  22 4
# TASK NUMBER  0  DEST:  1 3
# TASK NUMBER  1  DEST:  3 29
# Task  1  completed at step  900
# TASK NUMBER  0  DEST:  33 48
# TASK NUMBER  1  DEST:  10 13
# TASK NUMBER  0  DEST:  29 12
# TASK NUMBER  1  DEST:  46 16
# TASK NUMBER  0  DEST:  15 43
# TASK NUMBER  1  DEST:  33 4
# Task  1  completed at step  1840
# TASK NUMBER  0  DEST:  19 22
# TASK NUMBER  1  DEST:  23 16
# Task  0  completed at step  752
# Task  1  completed at step  3698
# TASK NUMBER  0  DEST:  16 24
# TASK NUMBER  1  DEST:  40 3
# TASK NUMBER  0  DEST:  0 31
# TASK NUMBER  1  DEST:  41 31
# Task  1  completed at step  25
# TASK NUMBER  0  DEST:  49 35
# TASK NUMBER  1  DEST:  13 37
# TASK NUMBER  0  DEST:  38 32
# TASK NUMBER  1  DEST:  16 6
# TASK NUMBER  0  DEST:  1 24
# TASK NUMBER  1  DEST:  44 6
# TASK NUMBER  0  DEST:  26 38
# TASK NUMBER  1  DEST:  15 22
# TASK NUMBER  0  DEST:  19 30
# TASK NUMBER  1  DEST:  22 5
# TASK NUMBER  0  DEST:  11 48
# TASK NUMBER  1  DEST:  12 46
# TASK NUMBER  0  DEST:  5 45
# TASK NUMBER  1  DEST:  7 40
# Task  0  completed at step  3288
# TASK NUMBER  0  DEST:  8 46
# TASK NUMBER  1  DEST:  6 26
# Task  0  completed at step  567
# TASK NUMBER  0  DEST:  25 20
# TASK NUMBER  1  DEST:  27 46
# TASK NUMBER  0  DEST:  39 7
# TASK NUMBER  1  DEST:  6 48
# Task  1  completed at step  959
# TASK NUMBER  0  DEST:  22 44
# TASK NUMBER  1  DEST:  21 34
# TASK NUMBER  0  DEST:  47 27
# TASK NUMBER  1  DEST:  3 11
# 16445.36834305945
# TASK NUMBER  0  DEST:  28 25
# TASK NUMBER  1  DEST:  41 18
# TASK NUMBER  0  DEST:  41 46
# TASK NUMBER  1  DEST:  3 18
# TASK NUMBER  0  DEST:  31 42
# TASK NUMBER  1  DEST:  0 22
# TASK NUMBER  0  DEST:  16 0
# TASK NUMBER  1  DEST:  37 45
# Task  1  completed at step  458
# TASK NUMBER  0  DEST:  49 6
# TASK NUMBER  1  DEST:  1 35
# TASK NUMBER  0  DEST:  14 8
# TASK NUMBER  1  DEST:  12 30
# Task  1  completed at step  812
# TASK NUMBER  0  DEST:  0 6
# TASK NUMBER  1  DEST:  41 16
# Task  0  completed at step  1
# TASK NUMBER  0  DEST:  42 21
# TASK NUMBER  1  DEST:  1 36
# TASK NUMBER  0  DEST:  25 33
# TASK NUMBER  1  DEST:  18 0
# Task  1  completed at step  413
# TASK NUMBER  0  DEST:  23 43
# TASK NUMBER  1  DEST:  14 44
# TASK NUMBER  0  DEST:  8 44
# TASK NUMBER  1  DEST:  30 17
# TASK NUMBER  0  DEST:  9 34
# TASK NUMBER  1  DEST:  47 20
# TASK NUMBER  0  DEST:  33 8
# TASK NUMBER  1  DEST:  34 33
# Task  1  completed at step  780
# TASK NUMBER  0  DEST:  30 4
# TASK NUMBER  1  DEST:  0 22
# TASK NUMBER  0  DEST:  35 25
# TASK NUMBER  1  DEST:  4 6
# Task  0  completed at step  69
# TASK NUMBER  0  DEST:  4 13
# TASK NUMBER  1  DEST:  6 45
# TASK NUMBER  0  DEST:  8 33
# TASK NUMBER  1  DEST:  2 48
# Task  1  completed at step  132
# TASK NUMBER  0  DEST:  12 47
# TASK NUMBER  1  DEST:  30 12
# TASK NUMBER  0  DEST:  25 47
# TASK NUMBER  1  DEST:  8 35
# TASK NUMBER  0  DEST:  43 40
# TASK NUMBER  1  DEST:  9 14
# 20654.447649328406
# TASK NUMBER  0  DEST:  8 16
# TASK NUMBER  1  DEST:  41 8
# Task  1  completed at step  1179
# TASK NUMBER  0  DEST:  20 32
# TASK NUMBER  1  DEST:  21 32
# Task  1  completed at step  578
# Task  0  completed at step  3343
# TASK NUMBER  0  DEST:  43 12
# TASK NUMBER  1  DEST:  36 10
# TASK NUMBER  0  DEST:  32 42
# TASK NUMBER  1  DEST:  38 49
# Task  1  completed at step  164
# TASK NUMBER  0  DEST:  27 43
# TASK NUMBER  1  DEST:  34 47
# Task  0  completed at step  183
# TASK NUMBER  0  DEST:  33 9
# TASK NUMBER  1  DEST:  12 44
# Task  1  completed at step  57
# TASK NUMBER  0  DEST:  19 16
# TASK NUMBER  1  DEST:  18 40
# Task  1  completed at step  162
# TASK NUMBER  0  DEST:  34 15
# TASK NUMBER  1  DEST:  5 31
# Task  1  completed at step  543
# TASK NUMBER  0  DEST:  4 43
# TASK NUMBER  1  DEST:  38 13
# TASK NUMBER  0  DEST:  38 39
# TASK NUMBER  1  DEST:  42 31
# TASK NUMBER  0  DEST:  7 38
# TASK NUMBER  1  DEST:  23 9
# Task  1  completed at step  63
# TASK NUMBER  0  DEST:  15 14
# TASK NUMBER  1  DEST:  17 0
# TASK NUMBER  0  DEST:  19 33
# TASK NUMBER  1  DEST:  0 6
# TASK NUMBER  0  DEST:  10 41
# TASK NUMBER  1  DEST:  14 48
# Task  1  completed at step  450
# TASK NUMBER  0  DEST:  49 38
# TASK NUMBER  1  DEST:  26 23
# Task  1  completed at step  245
# TASK NUMBER  0  DEST:  12 33
# TASK NUMBER  1  DEST:  5 21
# Task  0  completed at step  179
# Task  1  completed at step  476
# TASK NUMBER  0  DEST:  4 33
# TASK NUMBER  1  DEST:  16 42
# Task  1  completed at step  149
# TASK NUMBER  0  DEST:  16 26
# TASK NUMBER  1  DEST:  21 24
# Task  1  completed at step  2066
# TASK NUMBER  0  DEST:  32 9
# TASK NUMBER  1  DEST:  36 27
# Task  1  completed at step  240
# TASK NUMBER  0  DEST:  9 48
# TASK NUMBER  1  DEST:  26 12
# Task  1  completed at step  1803
# 28693.87881575798
# TASK NUMBER  0  DEST:  13 14
# TASK NUMBER  1  DEST:  15 11
# Task  1  completed at step  576
# Task  0  completed at step  665
# TASK NUMBER  0  DEST:  22 18
# TASK NUMBER  1  DEST:  33 32
# Task  1  completed at step  178
# TASK NUMBER  0  DEST:  32 38
# TASK NUMBER  1  DEST:  45 27
# TASK NUMBER  0  DEST:  11 42
# TASK NUMBER  1  DEST:  2 9
# TASK NUMBER  0  DEST:  18 32
# TASK NUMBER  1  DEST:  1 13
# TASK NUMBER  0  DEST:  8 24
# TASK NUMBER  1  DEST:  49 22
# TASK NUMBER  0  DEST:  35 27
# TASK NUMBER  1  DEST:  42 0
# Task  1  completed at step  121
# TASK NUMBER  0  DEST:  14 49
# TASK NUMBER  1  DEST:  43 8
# Task  1  completed at step  625
# TASK NUMBER  0  DEST:  36 12
# TASK NUMBER  1  DEST:  6 9
# TASK NUMBER  0  DEST:  40 36
# TASK NUMBER  1  DEST:  3 20
# TASK NUMBER  0  DEST:  25 32
# TASK NUMBER  1  DEST:  29 15
# Task  1  completed at step  59
# TASK NUMBER  0  DEST:  2 20
# TASK NUMBER  1  DEST:  23 28
# Task  1  completed at step  62
# TASK NUMBER  0  DEST:  15 39
# TASK NUMBER  1  DEST:  30 9
# Task  1  completed at step  89
# TASK NUMBER  0  DEST:  48 49
# TASK NUMBER  1  DEST:  47 9
# Task  1  completed at step  294
# TASK NUMBER  0  DEST:  3 38
# TASK NUMBER  1  DEST:  46 30
# TASK NUMBER  0  DEST:  22 48
# TASK NUMBER  1  DEST:  24 47
# Task  1  completed at step  311
# TASK NUMBER  0  DEST:  19 9
# TASK NUMBER  1  DEST:  44 5
# Task  0  completed at step  119
# Task  1  completed at step  666
# TASK NUMBER  0  DEST:  29 17
# TASK NUMBER  1  DEST:  26 5
# Task  1  completed at step  490
# TASK NUMBER  0  DEST:  38 0
# TASK NUMBER  1  DEST:  3 15
# TASK NUMBER  0  DEST:  17 37
# TASK NUMBER  1  DEST:  31 48
# Task  1  completed at step  156
# 33399.15793839424
# TASK NUMBER  0  DEST:  45 0
# TASK NUMBER  1  DEST:  29 48
# Task  1  completed at step  135
# TASK NUMBER  0  DEST:  35 6
# TASK NUMBER  1  DEST:  43 37
# Task  1  completed at step  146
# TASK NUMBER  0  DEST:  36 1
# TASK NUMBER  1  DEST:  7 47
# Task  1  completed at step  4398
# TASK NUMBER  0  DEST:  44 17
# TASK NUMBER  1  DEST:  8 29
# Task  1  completed at step  118
# TASK NUMBER  0  DEST:  28 26
# TASK NUMBER  1  DEST:  36 13
# Task  1  completed at step  361
# TASK NUMBER  0  DEST:  5 8
# TASK NUMBER  1  DEST:  39 16
# Task  1  completed at step  59
# TASK NUMBER  0  DEST:  28 48
# TASK NUMBER  1  DEST:  14 17
# Task  1  completed at step  59
# TASK NUMBER  0  DEST:  47 45
# TASK NUMBER  1  DEST:  48 37
# Task  0  completed at step  370
# TASK NUMBER  0  DEST:  24 13
# TASK NUMBER  1  DEST:  6 49
# Task  1  completed at step  546
# TASK NUMBER  0  DEST:  41 46
# TASK NUMBER  1  DEST:  31 26
# Task  1  completed at step  83
# TASK NUMBER  0  DEST:  23 38
# TASK NUMBER  1  DEST:  24 46
# Task  1  completed at step  291
# TASK NUMBER  0  DEST:  35 0
# TASK NUMBER  1  DEST:  8 33
# Task  1  completed at step  692
# TASK NUMBER  0  DEST:  14 40
# TASK NUMBER  1  DEST:  30 32
# Task  1  completed at step  700
# TASK NUMBER  0  DEST:  29 5
# TASK NUMBER  1  DEST:  21 48
# Task  1  completed at step  201
# TASK NUMBER  0  DEST:  1 30
# TASK NUMBER  1  DEST:  0 0
# TASK NUMBER  0  DEST:  16 41
# TASK NUMBER  1  DEST:  14 13
# Task  1  completed at step  195
# TASK NUMBER  0  DEST:  23 3
# TASK NUMBER  1  DEST:  45 41
# Task  1  completed at step  139
# TASK NUMBER  0  DEST:  11 48
# TASK NUMBER  1  DEST:  28 1
# Task  1  completed at step  55
# TASK NUMBER  0  DEST:  14 47
# TASK NUMBER  1  DEST:  12 8
# Task  1  completed at step  96
# TASK NUMBER  0  DEST:  7 14
# TASK NUMBER  1  DEST:  39 24
# Task  1  completed at step  62
# 43745.12080061297
# TASK NUMBER  0  DEST:  46 28
# TASK NUMBER  1  DEST:  15 14
# TASK NUMBER  0  DEST:  43 35
# TASK NUMBER  1  DEST:  38 27
# Task  1  completed at step  1569
# TASK NUMBER  0  DEST:  17 28
# TASK NUMBER  1  DEST:  17 18
# Task  1  completed at step  14
# TASK NUMBER  0  DEST:  34 11
# TASK NUMBER  1  DEST:  30 48
# Task  1  completed at step  80
# TASK NUMBER  0  DEST:  26 3
# TASK NUMBER  1  DEST:  20 25
# Task  1  completed at step  8
# TASK NUMBER  0  DEST:  36 47
# TASK NUMBER  1  DEST:  48 28
# Task  1  completed at step  116
# TASK NUMBER  0  DEST:  45 3
# TASK NUMBER  1  DEST:  21 24
# Task  1  completed at step  56
# TASK NUMBER  0  DEST:  49 16
# TASK NUMBER  1  DEST:  39 2
# Task  1  completed at step  51
# TASK NUMBER  0  DEST:  21 47
# TASK NUMBER  1  DEST:  23 13
# Task  1  completed at step  60
# TASK NUMBER  0  DEST:  3 14
# TASK NUMBER  1  DEST:  21 47
# Task  1  completed at step  42
# TASK NUMBER  0  DEST:  9 38
# TASK NUMBER  1  DEST:  24 11
# Task  1  completed at step  52
# TASK NUMBER  0  DEST:  22 13
# TASK NUMBER  1  DEST:  36 46
# Task  1  completed at step  275
# TASK NUMBER  0  DEST:  26 42
# TASK NUMBER  1  DEST:  24 42
# Task  1  completed at step  195
# Task  0  completed at step  4835
# TASK NUMBER  0  DEST:  26 46
# TASK NUMBER  1  DEST:  29 43
# Task  1  completed at step  1213
# Task  0  completed at step  3463
# TASK NUMBER  0  DEST:  14 9
# TASK NUMBER  1  DEST:  35 13
# Task  1  completed at step  223
# TASK NUMBER  0  DEST:  10 42
# TASK NUMBER  1  DEST:  3 20
# TASK NUMBER  0  DEST:  3 8
# TASK NUMBER  1  DEST:  25 44
# Task  1  completed at step  99
# TASK NUMBER  0  DEST:  9 39
# TASK NUMBER  1  DEST:  20 18
# Task  0  completed at step  9
# Task  1  completed at step  129
# TASK NUMBER  0  DEST:  49 37
# TASK NUMBER  1  DEST:  26 27
# Task  1  completed at step  206
# TASK NUMBER  0  DEST:  7 43
# TASK NUMBER  1  DEST:  11 12
# Task  1  completed at step  37
# 45951.71931418193
# TASK NUMBER  0  DEST:  34 17
# TASK NUMBER  1  DEST:  36 49
# Task  1  completed at step  66
# TASK NUMBER  0  DEST:  37 40
# TASK NUMBER  1  DEST:  29 1
# TASK NUMBER  0  DEST:  6 17
# TASK NUMBER  1  DEST:  44 46
# Task  1  completed at step  75
# TASK NUMBER  0  DEST:  1 31
# TASK NUMBER  1  DEST:  14 1
# Task  1  completed at step  43
# TASK NUMBER  0  DEST:  15 30
# TASK NUMBER  1  DEST:  48 16
